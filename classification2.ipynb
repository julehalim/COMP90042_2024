# %% [markdown]
# # 2024 COMP90042 Project
# *Make sure you change the file name with your group id.*

# %% [markdown]
# # Readme
# *If there is something to be noted for the marker, please mention here.*
#
# *If you are planning to implement a program with Object Oriented Programming style, please put those the bottom of this ipynb file*

# %% [markdown]
# Some things we can try:
# - Ensemble methods, especially for final labelling
# - Different methods of utilizing text created with the transformer (e.g., use cosine similarities to obtain evidences)
# - Compare performance using the text as output vs directly obtaining IDs
# - For classification, usually, transformers might overfit without the use of bigger pre-trained models

# %% [markdown]
# # 1.DataSet Processing
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
## import libraries

# !pip3 install torchtext==0.4.0

# Standard libraries
import math
import string
import pandas as pd
import numpy as np
import json

# Machine learning and deep learning libraries
import tensorflow
import keras
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
from torchtext.data.utils import get_tokenizer
from torchtext.data import Field, LabelField, Example, Dataset, BucketIterator
from torchtext.data.utils import get_tokenizer

# Natural Language Processing (NLP) libraries
import nltk
import spacy
from nltk.corpus import stopwords

# Visualization
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: torchtext==0.4.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (0.4.0)
# Requirement already satisfied: tqdm in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (4.66.2)
# Requirement already satisfied: requests in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (2.31.0)
# Requirement already satisfied: torch in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (2.3.0)
# Requirement already satisfied: numpy in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (1.24.3)
# Requirement already satisfied: six in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (4.11.0)
# Requirement already satisfied: sympy in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (1.12)
# Requirement already satisfied: networkx in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.1)
# Requirement already satisfied: jinja2 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from tqdm->torchtext==0.4.0) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchtext==0.4.0) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchtext==0.4.0) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from jinja2->torch->torchtext==0.4.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)

# %%
## reading in json files

"""
Description of json files
* [train-claims,dev-claims].json: JSON files for the labelled training and development set; 
* evidence.json: JSON file containing a large number of evidence passages (i.e. the “knowledge source”); 
* dev-claims-baseline.json: JSON file containing predictions of a baseline system on the development set;
"""

## relative file paths

## baseline system - will not be used for any training/evaluation
devClaimsBaselineFile='./data/dev-claims-baseline.json'
## use this for model training
trainClaimsFile='./data/train-claims.json'
## use this set for hyperparameter tuning and evaluation metric 
devClaimsFile='./data/dev-claims.json'
## evidence files need to be downloaded through https://drive.google.com/file/d/1JlUzRufknsHzKzvrEjgw8D3n_IRpjzo6/view?usp=sharing as it is to big to be uploaded to github
evidenceFile='./data/evidence.json'

testFile='./data/test-claims-unlabelled.json'

tokenizer=get_tokenizer("basic_english")

# %%
# Load the JSON data
with open(trainClaimsFile, 'r') as file:
    trainClaims=json.load(file)
with open(devClaimsFile, 'r') as file:
    devClaims=json.load(file)
with open(evidenceFile, 'r') as file:
    evidenceData=json.load(file)

## Preprocessing data -- lowercase, tokenize, and stopword removal
stopwords=set(nltk.corpus.stopwords.words('english'))
tokenizer=get_tokenizer('basic_english')
punctuations=string.punctuation

def preprocess(text):
    token=tokenizer(text.lower())
    cleanedTokens=[t for t in token if (t not in stopwords) and (t not in punctuations)]
    return ' '.join(cleanedTokens)

for ids, texts in evidenceData.items():
    evidenceData[ids]=preprocess(texts)

# Function to create DataFrame and merge evidence IDs with Text
def createDF(claims, evidence):
    combinedData=[]
    for claimID, claimText in claims.items():
        # Combine the ID with its corresponding evidences
        evidenceID=claimText['evidences']
        evidenceText=(evidence[i] for i in evidenceID if i in evidence)
        combinedData.append({
            'claim_id': claimID,
            'claim_text': preprocess(claimText['claim_text']),
            'evidence_id': evidenceID,
            'evidence_text': " ".join(evidenceText),
            'claim_label': claimText['claim_label']
        })
    # Create DataFrame
    return pd.DataFrame(combinedData)

# Create CSV Files
trainFullMerged=createDF(trainClaims,evidenceData)
devFullMerged=createDF(devClaims,evidenceData)
trainFullMerged.to_csv("data/trainFullMerged.csv", index=False)
devFullMerged.to_csv("data/devFullMerged.csv", index=False)

# Convert evidence into csv as well
evidenceFinal=pd.DataFrame(list(evidenceData.items()),columns=['evidence_id','evidence_text'])
evidenceFinal.to_csv('data/evidencePreprocessed.csv',index=False)

# Convert unlabelled Data into CSV as well
with open(testFile, 'r') as file:
    testData=json.load(file)
for ids, texts in testData.items():
    claim_text = texts['claim_text']
    testData[ids]=preprocess(claim_text)
testFinal=pd.DataFrame(list(testData.items()), columns=['claim_id', 'claim_text'])
testFinal.to_csv('data/testPreprocessed.csv',index=False)

# %%
## use this for model training
trainClaimsFile='./data/trainFullMerged.csv'
## use this set for hyperparameter tuning and evaluation metric 
devClaimsFile='./data/devFullMerged.csv'
## evidence files need to be downloaded through googledrive (https://drive.google.com/file/d/1OyihwdAWfqHIOueCB4bLBkYg4hTN_OKm/view?usp=sharing)
evidenceFile='./data/evidencePreprocessed.csv'
## test unlabelled dataset
testFile='./data/testPreprocessed.csv'

trainDataframe=pd.read_csv(trainClaimsFile)
devDataframe=pd.read_csv(devClaimsFile)
evidenceDataframe=pd.read_csv(evidenceFile)
testDataframe=pd.read_csv(testFile)

trainDataframe['claim_text']=trainDataframe['claim_text']
trainDataframe['combined_evidence']=trainDataframe['evidence_id']+" "+trainDataframe['evidence_text']
trainDataframe['combined_input'] = trainDataframe['claim_text'] + " [SEP] " + trainDataframe['evidence_text']

devDataframe['claim_text']=devDataframe['claim_text']
devDataframe['combined_evidence']=devDataframe['evidence_id'] +" "+ devDataframe['evidence_text']
devDataframe['combined_input'] = devDataframe['claim_text'] + " [SEP] " + devDataframe['evidence_text']

print(devDataframe['combined_input'])
# Out:
# 0      [south australia] expensive electricity world ...
# 1      3 per cent total annual global emissions carbo...
# 2      means world 1c warmer pre-industrial times [SE...
# 3      “as happens zika may also good model second wo...
# 4      greenland lost tiny fraction ice mass [SEP] ic...
#                              ...
# 149    suddenly label co2 pollutant disservice gas pl...
# 150    natural orbitally driven warming atmospheric c...
# 151    many world’s coral reefs already barren state ...
# 152    recent study led lawrence livermore national l...
# 153    corals may save many creatures attempting movi...
# Name: combined_input, Length: 154, dtype: object

# %%
## Preprocessing data -- lowercase, tokenize, and stopword removal
stopwords=set(nltk.corpus.stopwords.words('english'))
tokenizer=get_tokenizer('basic_english')
punctuations=set(string.punctuation)

def preprocess(text):
    tokens=tokenizer(text)
    cleanedTokens = [token for token in tokens if token not in stopwords and token not in punctuations]
    return cleanedTokens

TEXT = Field(lower=True, init_token='<sos>', eos_token='<eos>', batch_first=False)
LABEL=LabelField(sequential=False)

def createDatasetEncoderInput(dataframe,textTransform,labelTransform):
    field=[('reviewTextInput',textTransform),('evidenceTextOutput',labelTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        reviewTextInput=row['combined_input']
        evidenceTextOutput=row['claim_label']
        examples.append(Example.fromlist([reviewTextInput,evidenceTextOutput], field))
    return Dataset(examples,fields=field)

def createDatasetOutput(dataframe,labelTransform):
    field=[('evidenceTextOutput',labelTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        evidenceTextOutput=row['claim_label']
        examples.append(Example.fromlist([evidenceTextOutput], field))
    return Dataset(examples,fields=field)

def createDatasetTest(dataframe,textTransform):
    field=[('reviewTextInput',textTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        reviewTextInput=row['combined_input']
        examples.append(Example.fromlist([reviewTextInput], field))
    return Dataset(examples,fields=field)

trainTensor = createDatasetEncoderInput(trainDataframe, TEXT,LABEL)
devTensor = createDatasetEncoderInput(devDataframe, TEXT,LABEL)
#evidenceTensor=createDatasetOutput(evidenceDataframe,LABEL)
#testTensor=createDatasetTest(testDataframe,TEXT)

# %%
TEXT.build_vocab(trainTensor)
LABEL.build_vocab(trainTensor)

# %%
# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(LABEL.vocab.stoi)
print(TEXT.vocab.stoi)
# Out:
# defaultdict(None, {'SUPPORTS': 0, 'NOT_ENOUGH_INFO': 1, 'REFUTES': 2, 'DISPUTED': 3})
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x0000028A01A74640>>, {'<unk>': 0, '<pad>': 1, '<sos>': 2, '<eos>': 3, '[sep]': 4, 'global': 5, 'climate': 6, 'warming': 7, 'temperature': 8, 'ice': 9, 'change': 10, 'greenhouse': 11, 'sea': 12, 'carbon': 13, 'years': 14, 'temperatures': 15, '2': 16, 'emissions': 17, 'surface': 18, 'earth': 19, 'since': 20, '0': 21, '1': 22, '°c': 23, 'dioxide': 24, 'rise': 25, 'human': 26, 'gases': 27, 'increased': 28, 'atmosphere': 29, 'average': 30, 'level': 31, 'ocean': 32, 'per': 33, 'year': 34, 'co2': 35, 'increase': 36, 'century': 37, 'water': 38, 'gas': 39, 'scientific': 40, 'changes': 41, 'levels': 42, 'co': 43, 'energy': 44, 'due': 45, 'also': 46, 'heat': 47, 'scientists': 48, '°f': 49, 'period': 50, 'arctic': 51, 'caused': 52, 'data': 53, 'solar': 54, 'would': 55, 'last': 56, '3': 57, 'natural': 58, 'recent': 59, 'effect': 60, 'ipcc': 61, 'report': 62, 'record': 63, '000': 64, 'cause': 65, 'likely': 66, 'may': 67, 'increases': 68, 'rate': 69, 'air': 70, 'trend': 71, '5': 72, 'evidence': 73, 'past': 74, 'atmospheric': 75, 'much': 76, 'consensus': 77, 'methane': 78, 'could': 79, 'effects': 80, 'world': 81, 'weather': 82, 'decades': 83, 'activity': 84, 'fossil': 85, 'rising': 86, 'time': 87, 'concentrations': 88, 'models': 89, 'high': 90, 'increasing': 91, 'one': 92, '4': 93, '–': 94, 'anthropogenic': 95, 'mean': 96, 'observed': 97, 'new': 98, 'system': 99, 'melting': 100, 'causing': 101, 'million': 102, 'degrees': 103, 'cooling': 104, 'events': 105, 'warm': 106, 'extreme': 107, 'higher': 108, 'warmer': 109, 'many': 110, 'states': 111, '7': 112, 'land': 113, 'said': 114, '8': 115, 'fuels': 116, 'united': 117, 'study': 118, '6': 119, 'around': 120, 'oceans': 121, 'activities': 122, 'amount': 123, 'glaciers': 124, 'less': 125, 'power': 126, 'sun': 127, 'current': 128, 'found': 129, 'future': 130, 'research': 131, 'planet': 132, 'result': 133, 'two': 134, 'feedback': 135, 'greenland': 136, 'decade': 137, 'cold': 138, 'mass': 139, 'show': 140, 'significant': 141, 'use': 142, 'influence': 143, 'large': 144, 'including': 145, '2007': 146, 'loss': 147, 'times': 148, 'burning': 149, 'leading': 150, 'major': 151, 'percent': 152, 'radiation': 153, 'sheet': 154, '2017': 155, 'assessment': 156, 'summer': 157, 'used': 158, 'based': 159, '100': 160, 'antarctica': 161, 'area': 162, 'known': 163, 'measurements': 164, 'well': 165, 'antarctic': 166, 'coral': 167, 'human-induced': 168, '50': 169, 'even': 170, 'el': 171, 'satellite': 172, 'ago': 173, 'billion': 174, '30': 175, 'humans': 176, 'low': 177, 'lower': 178, '20th': 179, 'first': 180, 'industrial': 181, 'polar': 182, 'warmest': 183, 'include': 184, 'mainly': 185, 'pacific': 186, 'predicted': 187, 'regions': 188, '10': 189, 'become': 190, 'concentration': 191, 'national': 192, 'science': 193, 'age': 194, 'u': 195, 'areas': 196, 'cm': 197, 'estimated': 198, 'growth': 199, 'northern': 200, '2016': 201, 'however': 202, 'long-term': 203, 'published': 204, 'waves': 205, '9': 206, 'according': 207, 'days': 208, 'north': 209, 'positive': 210, 'records': 211, 'several': 212, 'studies': 213, 'within': 214, '20': 215, 'example': 216, 'tropical': 217, 'great': 218, 'impact': 219, 'reduce': 220, '2012': 221, 'long': 222, 'concluded': 223, 'currently': 224, 'ozone': 225, 'part': 226, 'pollution': 227, 'total': 228, 'cycle': 229, 'parts': 230, 'approximately': 231, 'countries': 232, 'hemisphere': 233, 'impacts': 234, 'occurred': 235, 'panel': 236, 'primarily': 237, 'sheets': 238, 'winter': 239, 'celsius': 240, 'conditions': 241, 'forcing': 242, 'sources': 243, 'state': 244, '2010': 245, 'absorption': 246, 'emission': 247, 'extent': 248, 'literature': 249, 'precipitation': 250, 'rapid': 251, 'intergovernmental': 252, 'ppm': 253, 'release': 254, 'health': 255, 'least': 256, 'little': 257, 'number': 258, 'variability': 259, 'wind': 260, 'annual': 261, 'deforestation': 262, 'expected': 263, 'important': 264, 'like': 265, 'reef':  ...

# %%
def batchify(dataset, bsz):
    #batchify both text and labels
    data = TEXT.process([getattr(x, 'reviewTextInput') for x in dataset.examples])
    label = LABEL.process([getattr(x, 'evidenceTextOutput') for x in dataset.examples])
    nbatch = min(data.size(0), label.size(0)) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    label = label.narrow(0, 0, nbatch * bsz)
    data = data.view(bsz, -1).t().contiguous()
    label = label.view(bsz, -1).t().contiguous()
    min_seq_len = min(data.size(0), label.size(0))
    data = data[:min_seq_len]
    label = label[:min_seq_len]
    return data.to(device), label.to(device)

## test is used for the final predictions
TEST = Field(tokenize=preprocess, lower=True, init_token='<sos>', eos_token='<eos>', batch_first=True)
TEST.build_vocab(trainTensor)
def processTextOnly(dataset):
    data = TEST.process([getattr(x, 'reviewTextInput') for x in dataset.examples])
    return data.to(device)

# Batch sizes
batch_size = 20
eval_batch_size = 35
        
train_data,train_label = batchify(trainTensor, batch_size)
dev_data,dev_label = batchify(devTensor, eval_batch_size)
dev_accuracy_data=processTextOnly(devTensor)

bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

# %% [markdown]
# # 2. Model Implementation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
## this is to obtain seq2seq results
class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        #triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output
    
torch.triu(torch.ones(3, 3))

# Masking
def masking():
  sz = 4
  mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
  mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))

  return mask

masking()

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)
    
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 2 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

# %% [markdown]
# # 3.Testing and Evaluation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
sos_token_id = TEXT.vocab.stoi['<sos>']
eos_token_id = TEXT.vocab.stoi['<eos>']
pad_token_id = TEXT.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index=pad_token_id)
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train():
    model.train() 
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, _ = get_batch(train_data, i) 
        targets, _ = get_batch(train_label, i) 
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets.view(-1))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

best_val_loss = float("inf")
epochs = 150# The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, dev_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  0.07s | valid loss 11.76 | valid ppl 128144.26
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  0.05s | valid loss 10.59 | valid ppl 39906.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  0.05s | valid loss 15.43 | valid ppl 5000840.41
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  0.05s | valid loss 24.84 | valid ppl 61270475174.18
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  0.05s | valid loss 12.63 | valid ppl 305568.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  0.06s | valid loss 11.50 | valid ppl 98507.00
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  0.05s | valid loss 19.23 | valid ppl 224564039.48
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  0.05s | valid loss 12.85 | valid ppl 379994.42
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  0.05s | valid loss 14.68 | valid ppl 2364503.91
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  0.05s | valid loss 15.05 | valid ppl 3427247.14
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time:  0.05s | valid loss 14.23 | valid ppl 1508271.37
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time:  0.05s | valid loss  9.80 | valid ppl 18055.57
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time:  0.05s | valid loss 15.57 | valid ppl 5778239.69
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time:  0.05s | valid loss 18.22 | valid ppl 81529423.13
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time:  0.05s | valid loss 14.73 | valid ppl 2502377.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time:  0.05s | valid loss 16.95 | valid ppl 23002746.76
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time:  0.05s | valid loss 15.17 | valid ppl 3862113.61
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time:  0.05s | valid loss 11.78 | valid ppl 130580.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time:  0.05s | valid loss 12.03 | valid ppl 168511.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time:  0.05s | valid loss 11.11 | valid ppl 66537.77
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time:  0.05s | valid loss 13.55 | valid ppl 768961.64
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time:  0.05s | valid loss 13.16 | valid ppl 518441.12
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time:  0.05s | valid loss 11.53 | valid ppl 101810.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time:  0.05s | valid loss 11.86 | valid ppl 140883.97
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time:  0.05s | valid loss 12.01 | valid ppl 163645.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time:  0.05s | valid loss 11.93 | valid ppl 151896.25
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time:  0.05s | valid loss 12.45 | valid ppl 254459.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time:  0.05s | valid loss 12.44 | valid ppl 253460.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time:  0.05s | valid loss 11.88 | valid ppl 144071.11
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time:  0.05s | valid loss 12.47 | valid ppl 260364.33
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time:  0.05s | valid loss 11.84 | valid ppl 139102.73
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time:  0.05s | valid loss 12.61 | valid ppl 299579.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time:  0.05s | valid loss 11.96 | valid ppl 155860.18
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time:  0.05s | valid loss 12.75 | valid ppl 345617.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time:  0.05s | valid loss 12.20 | valid ppl 198587.12
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time:  0.04s | valid loss 12.88 | valid ppl 393228.77
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time:  0.05s | valid loss 12.18 | valid ppl 195743.57
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time:  0.05s | valid loss 12.93 | valid ppl 414373.73
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time:  0.05s | valid loss 12.34 | valid ppl 228892.60
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time:  0.05s | valid loss 13.10 | valid ppl 487025.71
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time:  0.05s | valid loss 12.57 | valid ppl 287123.84
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time:  0.05s | valid loss 13.26 | valid ppl 572441.39
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time:  0.05s | valid loss 12.67 | valid ppl 317999.34
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time:  0.05s | valid loss 13.32 | valid ppl 611114.16
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time:  0.05s | valid loss 12.77 | valid ppl 353200.36
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time:  0.05s | valid loss 13.44 | valid ppl 685927.43
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time:  0.05s | valid loss 12.93 | valid ppl 411569.21
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time:  0.05s | valid loss 13.57 | valid ppl 782810.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time:  0.05s | valid loss 13.05 | valid ppl 466748.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time:  0.05s | valid loss 13.64 | valid ppl 841145.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time:  0.05s | valid loss 13.17 | valid ppl 524101.30
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time:  0.05s | valid loss 13.72 | valid ppl 912303.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time:  0.05s | valid loss 13.27 | valid ppl 577122.61
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time:  0.05s | valid loss 13.82 | valid ppl 1009505.53
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time:  0.05s | valid loss 13.40 | valid ppl 662751.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time:  0.05s | valid loss 13.90 | valid ppl 1093320.38
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time:  0.05s | valid loss 13.53 | valid ppl 749480.70
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time:  0.06s | valid loss 13.99 | valid ppl 1195191.92
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time:  0.05s | valid loss 13.61 | valid ppl 814677.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time:  0.05s | valid loss 14.05 | valid ppl 1261552.26
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time:  0.05s | valid loss 13.75 | valid ppl 936012.33
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time:  0.05s | valid loss 14.13 | valid ppl 1369166.97
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  63 | time:  0.05s | valid loss 13.84 | valid ppl 1026477.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  64 | time:  0.05s | valid loss 14.21 | valid ppl 1483913.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  65 | time:  0.05s | valid loss 13.93 | valid ppl 1126082.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  66 | time:  0.05s | valid loss 14.25 | valid ppl 1537029.60
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  67 | time:  0.05s | valid loss 14.01 | valid ppl 1218333.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  68 | time:  0.05s | valid loss 14.29 | valid ppl 1602060.77
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  69 | time:  0.05s | valid loss 14.09 | valid ppl 1320702.91
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  70 | time:  0.05s | valid loss 14.33 | valid ppl 1669365.70
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  71 | time:  0.05s | valid loss 14.16 | valid ppl 1404539.48
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  72 | time:  0.05s | valid loss 14.37 | valid ppl 1738586.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  73 | time:  0.05s | valid loss 14.21 | valid ppl 1485791.53
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  74 | time:  0.05s | valid loss 14.41 | valid ppl 1817430.60
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  75 | time:  0.05s | valid loss 14.29 | valid ppl 1600753.47
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  76 | time:  0.05s | valid loss 14.40 | valid ppl 1799691.40
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  77 | time:  0.05s | valid loss 14.36 | valid ppl 1718337.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  78 | time:  0.05s | valid loss 14.42 | valid ppl 1837547.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  79 | time:  0.05s | valid loss 14.40 | valid ppl 1802444.76
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  80 | time:  0.05s | valid loss 14.43 | valid ppl 1856200.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  81 | time:  0.04s | valid loss 14.47 | valid ppl 1918833.36
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  82 | time:  0.05s | valid loss 14.48 | valid ppl 1948173.45
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  83 | time:  0.05s | valid loss 14.48 | valid ppl 1942646.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  84 | time:  0.05s | valid loss 14.52 | valid ppl 2020564.57
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  85 | time:  0.05s | valid loss 14.52 | valid ppl 2020763.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  86 | time:  0.05s | valid loss 14.53 | valid ppl 2050924.20
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  87 | time:  0.05s | valid loss 14.55 | valid ppl 2083418.25
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  88 | time:  0.05s | valid loss 14.56 | valid ppl 2100529.80
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  89 | time:  0.05s | valid loss 14.57 | valid ppl 2118222.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  90 | time:  0.05s | valid loss 14.58 | valid ppl 2142743.59
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  91 | time:  0.05s | valid loss 14.59 | valid ppl 2166472.12
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  92 | time:  0.05s | valid loss 14.59 | valid ppl 2162174.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  93 | time:  0.05s | valid loss 14.60 | valid ppl 2192967.44
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  94 | time:  0.05s | valid loss 14.61 | valid ppl 2209387.36
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  95 | time:  0.05s | valid loss 14.61 | valid ppl 2211271.85
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  96 | time:  0.05s | valid loss 14.62 | valid ppl 2232778.31
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  97 | time:  0.04s | valid loss 14.63 | valid ppl 2251891.73
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  98 | time:  0.05s | valid loss 14.63 | valid ppl 2254880.98
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  99 | time:  0.05s | valid loss 14.64 | valid ppl 2275756.55
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 100 | time:  0.05s | valid loss 14.64 | valid ppl 2285251.97
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 101 | time:  0.05s | valid loss 14.65 | valid ppl 2297156.16
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 102 | time:  0.05s | valid loss 14.65 | valid ppl 2297298.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 103 | time:  0.05s | valid loss 14.66 | valid ppl 2320739.21
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 104 | time:  0.05s | valid loss 14.66 | valid ppl 2338028.86
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 105 | time:  0.05s | valid loss 14.66 | valid ppl 2332808.24
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 106 | time:  0.05s | valid loss 14.67 | valid ppl 2340389.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 107 | time:  0.05s | valid loss 14.68 | valid ppl 2365306.82
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 108 | time:  0.05s | valid loss 14.67 | valid ppl 2359703.46
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 109 | time:  0.05s | valid loss 14.68 | valid ppl 2374039.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 110 | time:  0.05s | valid loss 14.69 | valid ppl 2387814.91
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 111 | time:  0.05s | valid loss 14.69 | valid ppl 2397517.22
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 112 | time:  0.05s | valid loss 14.69 | valid ppl 2409344.38
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 113 | time:  0.05s | valid loss 14.70 | valid ppl 2410960.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 114 | time:  0.05s | valid loss 14.70 | valid ppl 2415342.01
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 115 | time:  0.05s | valid loss 14.70 | valid ppl 2413967.25
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 116 | time:  0.05s | valid loss 14.70 | valid ppl 2421615.53
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 117 | time:  0.05s | valid loss 14.70 | valid ppl 2420996.68
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 118 | time:  0.05s | valid loss 14.70 | valid ppl 2428512.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 119 | time:  0.05s | valid loss 14.70 | valid ppl 2428155.42
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 120 | time:  0.05s | valid loss 14.70 | valid ppl 2428088.27
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 121 | time:  0.05s | valid loss 14.70 | valid ppl 2421541.63
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 122 | time:  0.05s | valid loss 14.70 | valid ppl 2422447.07
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 123 | time:  0.05s | valid loss 14.70 | valid ppl 2423191.08
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 124 | time:  0.05s | valid loss 14.71 | valid ppl 2434311.31
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 125 | time:  0.05s | valid loss 14.71 | valid ppl 2435528.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 126 | time:  0.05s | valid loss 14.71 | valid ppl 2440371.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 127 | time:  0.05s | valid loss 14.71 | valid ppl 2445223.72
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 128 | time:  0.05s | valid loss 14.71 | valid ppl 2452171.12
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 129 | time:  0.05s | valid loss 14.72 | valid ppl 2458974.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 130 | time:  0.05s | valid loss 14.72 | valid ppl 2462743.14
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 131 | time:  0.05s | valid loss 14.72 | valid ppl 2463816.71
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 132 | time:  0.05s | valid loss 14.72 | valid ppl 2465998.18
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 133 | time:  0.05s | valid loss 14.72 | valid ppl 2471127.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 134 | time:  0.05s | valid loss 14.72 | valid ppl 2469208.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 135 | time:  0.05s | valid loss 14.72 | valid ppl 2470960.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 136 | time:  0.05s | valid loss 14.72 | valid ppl 2471349.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 137 | time:  0.05s | valid loss 14.72 | valid ppl 2475243.77
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 138 | time:  0.05s | valid loss 14.72 | valid ppl 2477964.65
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 139 | time:  0.05s | valid loss 14.72 | valid ppl 2478765.89
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 140 | time:  0.05s | valid loss 14.72 | valid ppl 2482856.51
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 141 | time:  0.05s | valid loss 14.72 | valid ppl 2480757.12
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 142 | time:  0.05s | valid loss 14.72 | valid ppl 2479139.42
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 143 | time:  0.05s | valid loss 14.72 | valid ppl 2477515.69
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 144 | time:  0.05s | valid loss 14.72 | valid ppl 2479115.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 145 | time:  0.05s | valid loss 14.72 | valid ppl 2479111.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 146 | time:  0.05s | valid loss 14.72 | valid ppl 2480097.14
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 147 | time:  0.05s | valid loss 14.72 | valid ppl 2482404.29
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 148 | time:  0.05s | valid loss 14.72 | valid ppl 2481829.08
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 149 | time:  0.05s | valid loss 14.73 | valid ppl 2483780.14
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 150 | time:  0.05s | valid loss 14.73 | valid ppl 2485170.96
# -----------------------------------------------------------------------------------------

# %%
test_loss = evaluate(best_model, dev_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

model.eval()
output=model(dev_data)
probabilities=torch.nn.functional.softmax(output,dim=-1)
_,predictedIndex=torch.max(probabilities,dim=-1)

vocab = TEXT.vocab.stoi 
reverseVocab = {index: word for word, index in vocab.items()} 
def tensor_to_text(tensor, index_to_word):
    words = [index_to_word[index.item()] for index in tensor if index in index_to_word]
    return ' '.join(words)
# Out:
# =========================================================================================
# | End of training | test loss 14.73 | test ppl 2485170.96
# =========================================================================================

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

model.eval()
pred=model(dev_accuracy_data)
def create_id_dictionary(dataframe):
    unique_id_per_claim={}
    for claim_id in dataframe['claim_id']:
        unique_id_per_claim[claim_id]=[]
    return unique_id_per_claim

unique_evidence_id=create_id_dictionary(devDataframe)
#print(predicted_text['claim-752'])
# use softmax
probabilities = torch.softmax(pred, dim=-1)
_, predicted_indices = torch.max(probabilities, dim=-1)
predicted_words = [[LABEL.vocab.itos[index] for index in example] for example in predicted_indices]
print(predicted_indices)
predicted_single_words={}
for claim_id in unique_evidence_id:
    predicted_single_words[claim_id] = []
if len(predicted_words) == len(unique_evidence_id):
    for claim_text, sentence in zip(unique_evidence_id, predicted_words):
        formatted_sentence =[word for word in sentence if word not in ("<pad>", "<unk>", "<eos>", "<sos>")]
        predicted_single_words[claim_text].extend(formatted_sentence)

for claim_id in predicted_single_words:
    for word in predicted_single_words[claim_id]:
        if 'evidence-' in word:
            predicted_single_words[claim_id].remove(word)
            unique_evidence_id[claim_id].append(word)

predicted_whole_sentences={}
for claim_id, words in predicted_single_words.items():
    predicted_whole_sentences[claim_id] = ' '.join(words)
    
newDf=evidenceDataframe.fillna(value=' ', inplace=False)
predicted_texts_list = list(predicted_whole_sentences.values())
tfidf_vectorizer = TfidfVectorizer()
evidence_tfidf = tfidf_vectorizer.fit_transform(newDf['evidence_text'])
predicted_tfidf = tfidf_vectorizer.transform(predicted_texts_list)
similarity_matrix = cosine_similarity(predicted_tfidf, evidence_tfidf)


for i, sentence in enumerate(predicted_words):
    print(f"Sentence {i+1}: {' '.join(sentence)}")
predicted_text={}
for claim_id in unique_evidence_id:
    predicted_text[claim_id] = []
if len(predicted_words) == len(unique_evidence_id):
    for claim_text, sentence in zip(unique_evidence_id, predicted_words):
        formatted_sentence =[word for word in sentence]
        predicted_text[claim_text].extend(formatted_sentence)
# Out:
# tensor([[3, 3, 3,  ..., 0, 0, 0],
#         [0, 3, 3,  ..., 0, 0, 0],
#         [0, 3, 3,  ..., 0, 0, 0],
#         ...,
#         [0, 2, 2,  ..., 0, 0, 0],
#         [0, 2, 2,  ..., 0, 0, 0],
#         [0, 2, 2,  ..., 0, 0, 0]])
# Sentence 1: DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 2: SUPPORTS DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 3: SUPPORTS DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 4: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 5: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 6: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 7: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 8: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 9: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 10: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 11: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 12: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 13: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 14: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 15: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 16: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 17: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 18: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 19: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 20: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 21: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 22: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 23: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 24: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 25: SUPPORTS DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS DISPUTED SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 26: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES DISPUTED REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES DISPUTED REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 27: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 28: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# ...
# Sentence 146: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 147: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 148: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 149: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 150: SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 151: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 152: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 153: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS
# Sentence 154: SUPPORTS REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES REFUTES SUPPORTS SUPPORTS REFUTES SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS SUPPORTS

# %%
from collections import Counter

print(predicted_text)
final_label= {claim: Counter(labels).most_common(1)[0][0] for claim, labels in predicted_text.items()}
print(final_label)
# Out:
# {'claim-752': ['DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS'], 'claim-375': ['SUPPORTS', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'DISPUTED', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'DISPUTED', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS', 'SUPPORTS' ...
# {'claim-752': 'SUPPORTS', 'claim-375': 'SUPPORTS', 'claim-1266': 'SUPPORTS', 'claim-871': 'SUPPORTS', 'claim-2164': 'SUPPORTS', 'claim-1607': 'SUPPORTS', 'claim-761': 'SUPPORTS', 'claim-1718': 'SUPPORTS', 'claim-1273': 'SUPPORTS', 'claim-1786': 'SUPPORTS', 'claim-2796': 'SUPPORTS', 'claim-2580': 'SUPPORTS', 'claim-1219': 'SUPPORTS', 'claim-75': 'SUPPORTS', 'claim-2813': 'SUPPORTS', 'claim-2335': 'SUPPORTS', 'claim-161': 'SUPPORTS', 'claim-2243': 'SUPPORTS', 'claim-1256': 'SUPPORTS', 'claim-506': 'SUPPORTS', 'claim-369': 'SUPPORTS', 'claim-2184': 'SUPPORTS', 'claim-1057': 'SUPPORTS', 'claim-104': 'SUPPORTS', 'claim-1975': 'SUPPORTS', 'claim-139': 'SUPPORTS', 'claim-2062': 'SUPPORTS', 'claim-1160': 'SUPPORTS', 'claim-2679': 'SUPPORTS', 'claim-2662': 'SUPPORTS', 'claim-1490': 'SUPPORTS', 'claim-2768': 'SUPPORTS', 'claim-2168': 'SUPPORTS', 'claim-785': 'SUPPORTS', 'claim-2426': 'SUPPORTS', 'claim-1292': 'SUPPORTS', 'claim-993': 'SUPPORTS', 'claim-2593': 'SUPPORTS', 'claim-1567': 'SUPPORTS', 'claim-1834': 'SUPPORTS', 'claim-856': 'SUPPORTS', 'claim-540': 'SUPPORTS', 'claim-757': 'SUPPORTS', 'claim-1407': 'SUPPORTS', 'claim-3070': 'SUPPORTS', 'claim-1745': 'SUPPORTS', 'claim-1515': 'SUPPORTS', 'claim-1519': 'SUPPORTS', 'claim-3069': 'SUPPORTS', 'claim-677': 'SUPPORTS', 'claim-765': 'SUPPORTS', 'claim-2275': 'SUPPORTS', 'claim-1113': 'SUPPORTS', 'claim-2611': 'SUPPORTS', 'claim-2060': 'SUPPORTS', 'claim-2326': 'SUPPORTS', 'claim-1087': 'SUPPORTS', 'claim-2867': 'SUPPORTS', 'claim-2300': 'SUPPORTS', 'claim-2250': 'SUPPORTS', 'claim-2429': 'SUPPORTS', 'claim-3051': 'SUPPORTS', 'claim-1549': 'SUPPORTS', 'claim-261': 'SUPPORTS', 'claim-2230': 'SUPPORTS', 'claim-2579': 'SUPPORTS', 'claim-1416': 'SUPPORTS', 'claim-2497': 'SUPPORTS', 'claim-811': 'SUPPORTS', 'claim-1896': 'SUPPORTS', 'claim-2819': 'SUPPORTS', 'claim-2643': 'SUPPORTS', 'claim-1775': 'SUPPORTS', 'claim-316': 'SUPPORTS', 'claim-896': 'SUPPORTS', 'claim-331': 'SUPPORTS', 'claim-2574': 'SUPPORTS', 'claim-342': 'SUPPORTS', 'claim-2034': 'SUPPORTS', 'claim-578': 'SUPPORTS', 'claim-976': 'SUPPORTS', 'claim-1097': 'SUPPORTS', 'claim-609': 'SUPPORTS', 'claim-173': 'SUPPORTS', 'claim-1222': 'SUPPORTS', 'claim-2441': 'SUPPORTS', 'claim-756': 'SUPPORTS', 'claim-2577': 'SUPPORTS', 'claim-2890': 'SUPPORTS', 'claim-2478': 'SUPPORTS', 'claim-2399': 'SUPPORTS', 'claim-3091': 'SUPPORTS', 'claim-141': 'SUPPORTS', 'claim-1933': 'SUPPORTS', 'claim-1689': 'SUPPORTS', 'claim-443': 'SUPPORTS', 'claim-2037': 'SUPPORTS', 'claim-1734': 'SUPPORTS', 'claim-2093': 'SUPPORTS', 'claim-1400': 'SUPPORTS', 'claim-1638': 'SUPPORTS', 'claim-3075': 'SUPPORTS', 'claim-38': 'SUPPORTS', 'claim-1643': 'SUPPORTS', 'claim-1259': 'SUPPORTS', 'claim-1605': 'SUPPORTS', 'claim-1711': 'SUPPORTS', 'claim-2236': 'SUPPORTS', 'claim-1040': 'SUPPORTS', 'claim-392': 'SUPPORTS', 'claim-368': 'SUPPORTS', 'claim-559': 'SUPPORTS', 'claim-2583': 'SUPPORTS', 'claim-2609': 'SUPPORTS', 'claim-492': 'SUPPORTS', 'claim-1420': 'SUPPORTS', 'claim-1089': 'SUPPORTS', 'claim-1467': 'SUPPORTS', 'claim-444': 'SUPPORTS', 'claim-803': 'SUPPORTS', 'claim-1668': 'SUPPORTS', 'claim-742': 'SUPPORTS', 'claim-846': 'SUPPORTS', 'claim-2119': 'SUPPORTS', 'claim-1167': 'SUPPORTS', 'claim-623': 'SUPPORTS', 'claim-2882': 'SUPPORTS', 'claim-1698': 'SUPPORTS', 'claim-181': 'SUPPORTS', 'claim-281': 'SUPPORTS', 'claim-2809': 'SUPPORTS', 'claim-1928': 'SUPPORTS', 'claim-2787': 'SUPPORTS', 'claim-478': 'SUPPORTS', 'claim-988': 'SUPPORTS', 'claim-266': 'SUPPORTS', 'claim-2282': 'SUPPORTS', 'claim-2895': 'SUPPORTS', 'claim-349': 'SUPPORTS', 'claim-2101': 'SUPPORTS', 'claim-897': 'SUPPORTS', 'claim-3063': 'SUPPORTS', 'claim-386': 'SUPPORTS', 'claim-2691': 'SUPPORTS', 'claim-530': 'SUPPORTS', 'claim-2979': 'SUPPORTS', 'claim-665': 'SUPPORTS', 'claim-199': 'SUPPORTS', 'claim-490': 'SUPPORTS', 'claim-2400': 'SUPPORTS', 'claim-204': 'SUPPORTS', 'claim-1426': 'SUPPORTS', 'claim-698': 'SUPPORTS', 'claim-1021': 'SUPPORTS'}

# %% [markdown]
# ## Object Oriented Programming codes here
#
# *You can use multiple code snippets. Just add more if needed*
