# %% [markdown]
# # 2024 COMP90042 Project
# *Make sure you change the file name with your group id.*

# %% [markdown]
# # Readme
# *If there is something to be noted for the marker, please mention here.*
#
# *If you are planning to implement a program with Object Oriented Programming style, please put those the bottom of this ipynb file*

# %% [markdown]
# # 1.DataSet Processing
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %% [markdown]
# 1.1 Load the dataset

# %%
import json

train_claims = json.load(open("Specifications/data/train-claims.json"))
dev_claims = json.load(open("Specifications/data/dev-claims.json"))
evidences = json.load(open("Specifications/data/evidence.json"))
test_claims = json.load(open("Specifications/data/test-claims-unlabelled.json"))

# %% [markdown]
# 1.2 Elementary Data Analysis

# %%
# For the sack of understanding, just get an idea of the size of the dataset
print(len(test_claims.keys()))
print(len(train_claims.keys()))
print(len(dev_claims.keys()))
print(len(evidences.keys()))
# Out:
# 153
# 1228
# 154
# 1208827

# %%
# other analysis could be written here if have time

# %% [markdown]
# 1.3 Data preprocessing

# %%
# mostly from workshop
import nltk
import re
from nltk.corpus import stopwords
# nltk.download('wordnet')
lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
# nltk.download("stopwords")
stopword = set(stopwords.words('english'))

from nltk.tokenize import word_tokenize

# contraction dict from workshop07
contraction_dict = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have",
                    "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not",
                    "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did",
                    "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have",
                    "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have",
                    "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                    "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us",
                    "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have",
                    "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have",
                    "o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not",
                    "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have",
                    "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have",
                    "so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                    "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                    "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not",
                    "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have",
                    "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have",
                    "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will",
                    "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have",
                    "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have",
                    "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                    "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have"}

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma

# Preprocess with several steps
def pre_process(sent_list):
    output = []
    for sent in sent_list:
        sent = sent.lower() #case-folding
        for word, new_word in contraction_dict.items():
            sent = sent.replace(word, new_word) #dealing with contractions
        # convert all spacing characters to a single space
        sent = re.sub(r'\s', ' ', sent)
        # make sure one white space exists between each words
        sent = re.sub(r' +', ' ', sent)
        sent = re.sub(r'[^\w\s]','',sent) #removing punctuation
        sent_list = word_tokenize(sent) #tokenization
        sent_list = [lemmatize(word) for word in sent_list] # lemmatization
        # sent_list = [x for x in sent_list if len(x) != 1] # single characters are removed as well
        sent_list = [word for word in sent_list if word not in stopword] # stop words removal
        # remove non-english languages
        sent_list = [word for word in sent_list if word.isalnum() or word.isalpha() or word.isnumeric()]
        processed_text = " ".join(sent_list)
        output.append(processed_text)
    return output

# %%
# preprocess all the texts
evidence_ids = list(evidences.keys())
evidence_texts = pre_process(list(evidences.values()))
evidence_dict = dict(zip(evidence_ids, evidence_texts))
for i in range(5):
    print(evidence_texts[i])

train_claim_texts = []
train_evidences = []
train_labels = []
train_ids = []
for claim_id, claim_info in train_claims.items():
    train_claim_texts.append(claim_info['claim_text'])
    train_evidences.append([evidence_dict[id] for id in claim_info["evidences"]])
    train_labels.append(claim_info["claim_label"])
    train_ids.append(claim_id)
train_claim_texts = pre_process(train_claim_texts)
for i in range(5):
    print(train_claim_texts[i])

dev_claim_texts = []
dev_evidences = []
dev_labels = []
dev_ids = []
for claim_id, claim_info in dev_claims.items():
    dev_claim_texts.append(claim_info['claim_text'])
    dev_evidences.append([evidence_dict[id] for id in claim_info["evidences"]])
    dev_labels.append(claim_info["claim_label"])
    dev_ids.append(claim_id)
dev_claim_texts = pre_process(dev_claim_texts)
for i in range(5):
    print(dev_claim_texts[i])

test_claim_texts = []
test_ids = []
for claim_id, claim_info in test_claims.items():
    test_claim_texts.append(claim_info["claim_text"])
    test_ids.append(claim_id)
test_claim_texts = pre_process(test_claim_texts)
for i in range(5):
    print(test_claim_texts[i])
# Out:
# john bennet lawes english entrepreneur agricultural scientist
# lindberg begin professional career age 16 eventually move new york city 1977
# boston lady cambridge vampire weekend
# gerald francis goyer bear october 20 1936 professional ice hockey player play 40 game national hockey league
# detect abnormality oxytocinergic function schizoaffective mania postpartum psychosis ect modify oxytocin release
# scientific evidence co2 pollutant higher co2 concentration actually help ecosystem support plant animal life
# el niño drive record high global temperature suggest rise may manmade emission
# 1946 pdo switch cool phase
# weather channel cofounder john coleman provide evidence convincingly refute concept anthropogenic global warm
# january 2008 cap 12 month period global temperature drop major well respect indicator
# south australia expensive electricity world
# 3 per cent total annual global emission carbon dioxide human australia produce 13 per cent 3 per cent amount emission reduction effect global climate
# mean world 1c warmer preindustrial time
# happen zika may also good model second worry effect disease mutation
# greenland lose tiny fraction ice mass
# contribution waste heat global climate 0028 wm2
# warm weather worsen recent fiveyear drought include driest fouryear period record term statewide precipitation
# greenland lose tiny fraction ice mass
# global reef crisis necessarily mean extinction coral specie
# small amount active substance cause large effect

# %% [markdown]
# TfIDF for similarities

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(use_idf=True, max_features=500000)
# vectorizer.fit(train_claim_texts + evidence_texts)
vectorizer.fit(evidence_texts)

train_emb_list = vectorizer.transform(train_claim_texts)
evi_emb_list = vectorizer.transform(evidence_texts)
dev_emb_list = vectorizer.transform(dev_claim_texts)
test_emb_list = vectorizer.transform(test_claim_texts)

# %%
print(evi_emb_list.get_shape())
print(train_emb_list.get_shape())
# Out:
# (1208827, 500000)
# (1228, 500000)

# %% [markdown]
# # 2. Model Implementation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
import heapq
# retrieve top k similar evidences and for training set, if not all the recorded
# evidences are in top k, put them into the list as well
k = 10
def evidence_candidates(emb_list, claim_ids, claims, train=True):
    candidates = {}
    similarities = cosine_similarity(emb_list, evi_emb_list)
    for i, claim_id in enumerate(claim_ids):
        evidence_sim_dict = {evidence_ids[j]: sim for j, sim in enumerate(similarities[i])}
        # Get top-k evidence IDs using a priority queue
        topk_evidence_sims = heapq.nlargest(k, evidence_sim_dict.items(), key=lambda item: item[1])
        # record top k evidence ids for this claim
        candidates[claim_ids[i]] = [id for id, sim in topk_evidence_sims]
    
    if train:
        for claim_id in claim_ids:
            # all the recorded evidences of a training claim
            for evidence in claims[claim_id]["evidences"]:
                # if the recorded evidence not in top-k
                if evidence not in candidates[claim_id]:
                    # add the evidence into the candidate list
                    candidates[claim_id].append(evidence)
    return candidates

# %% [markdown]
# 2.1 Convert to classification problem

# %%
# if the evidences are recorded in the claim evidences, assign a label 1, otherwise, assign a label 0.
def cls_prepare(evidence_candidates, ids, texts, train=True, dev=False, test=False):
    claim_text = []
    claim_evidence = []
    labels = []
    for claim_id, candidates in evidence_candidates.items():
        # if it's for training set
        if train == True:
            for evidence in candidates:
                # if in the recorded evidences
                if evidence in train_claims[claim_id]["evidences"]:
                    labels.append(1)
                else:
                    labels.append(0)
                num = ids.index(claim_id)
                claim_text.append(texts[num])
                claim_evidence.append(evidence_dict[evidence])
        # for developing set
        elif dev == True:
            for evidence in candidates:
                # if in the recorded evidences
                if evidence in dev_claims[claim_id]["evidences"]:
                    labels.append(1)
                else:
                    labels.append(0)
                num = ids.index(claim_id)
                claim_text.append(texts[num])
                claim_evidence.append(evidence_dict[evidence])
        elif test == True:
            for evidence in candidates:
                num = ids.index(claim_id)
                claim_text.append(texts[num])
                claim_evidence.append(evidence_dict[evidence])
    return claim_text, claim_evidence, labels

# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2.2 Convet the training set and dev set to the form model requires

# %%
train_candidates = evidence_candidates(train_emb_list, train_ids, train_claims, True)
claim_text_train, claim_evidence_train, labels_train = cls_prepare(train_candidates, train_ids, train_claim_texts, train=True, dev=False, test=False)

dev_candidates = evidence_candidates(dev_emb_list, dev_ids, dev_claims, False)
claim_text_dev, claim_evidence_dev, labels_dev = cls_prepare(dev_candidates, dev_ids, dev_claim_texts, train=False, dev=True, test=False)

test_candidates = evidence_candidates(test_emb_list, test_ids, test_claims, False)
claim_text_test, claim_evidence_test, _ = cls_prepare(test_candidates, test_ids, test_claim_texts, train=False, dev=False, test=True)

# %%
import collections
print(collections.Counter(np.array(labels_train)))
print(collections.Counter(np.array(labels_dev)))
# Out:
# Counter({0: 11639, 1: 4122})
# Counter({0: 1460, 1: 80})

# %%
# Create a vocabulary that is used to store the appeared words and give them indices
class Vocab:
    # min_freq as the threshold for throwing away the tokens
    # reserved_tokens as the start or the end tokens of the sentence
    def __init__(self, tokens=None, min_freq=0, reserved_tokens=None):
        if tokens is None:
            tokens = []
        if reserved_tokens is None:
            reserved_tokens = []
        # construct a dictionary for counting the frequency of each token
        counter = count_corpus(tokens)
        # sort the token frequencies
        self.token_freqs = sorted(counter.items(), key=lambda x: x[1],
                                  reverse=True)
        self.unk, uniq_tokens = 0, ['<unk>'] + reserved_tokens
        uniq_tokens += [token for token, freq in self.token_freqs
                        if freq >= min_freq and token not in uniq_tokens]
        self.idx_to_token, self.token_to_idx = [], dict()
        for token in uniq_tokens:
            self.idx_to_token.append(token)
            self.token_to_idx[token] = len(self.idx_to_token) - 1
    
    def __len__(self):
        return len(self.idx_to_token)
    
    # for getting the indices for given tokens
    def __getitem__(self, tokens):
        if not isinstance(tokens, (list, tuple)):
            return self.token_to_idx.get(tokens, self.unk)
        return [self.__getitem__(token) for token in tokens]
    
    # for getting the tokens given the indices
    def to_tokens(self, indices):
        if not isinstance(indices, (list, tuple)):
            return self.idx_to_token[indices]
        return [self.idx_to_token[index] for index in indices]

def count_corpus(tokens):
    if len(tokens) == 0 or isinstance(tokens[0], list):
        tokens = [token for line in tokens for token in line]
    return collections.Counter(tokens)

# %%
def tokenize(claim_data):
    tokens = []
    for data in claim_data:
        tokens.append(word_tokenize(data))
    return tokens

# %%
tok_train_claim_text = tokenize(claim_text_train)
tok_train_claim_evidence = tokenize(claim_evidence_train)
tok_dev_claim_text = tokenize(claim_text_dev)
tok_dev_claim_evidence = tokenize(claim_evidence_dev)
tok_test_claim_text = tokenize(claim_text_test)
tok_test_claim_evidence = tokenize(claim_evidence_test)

# %%
vocab1 = Vocab(tok_train_claim_text + tok_train_claim_evidence)
print(list(vocab1.token_to_idx.items())[:10])
# Out:
# [('<unk>', 0), ('warm', 1), ('climate', 2), ('global', 3), ('temperature', 4), ('change', 5), ('ice', 6), ('year', 7), ('increase', 8), ('co2', 9)]

# %%
print(vocab1.__len__())
# Out:
# 11654

# %%
train_seqs1 = vocab1[tok_train_claim_text]
train_seqs2 = vocab1[tok_train_claim_evidence]
dev_seqs1 = vocab1[tok_dev_claim_text]
dev_seqs2 = vocab1[tok_dev_claim_evidence]
test_seqs1 = vocab1[tok_test_claim_text]
test_seqs2 = vocab1[tok_test_claim_evidence]

# %%
train_seqs1 = keras.preprocessing.sequence.pad_sequences(train_seqs1, padding="post")
train_seqs2 = keras.preprocessing.sequence.pad_sequences(train_seqs2, padding="post")
dev_seqs1 = keras.preprocessing.sequence.pad_sequences(dev_seqs1, padding="post")
dev_seqs2 = keras.preprocessing.sequence.pad_sequences(dev_seqs2, padding="post")
test_seqs1 = keras.preprocessing.sequence.pad_sequences(test_seqs1, padding="post")
test_seqs2 = keras.preprocessing.sequence.pad_sequences(test_seqs2, padding="post")

# %% [markdown]
# 2.3 Build the model

# %%
vocab_size = vocab1.__len__() + 1
output_dim = 200

# %%
seq_model1 = keras.Sequential([
    keras.layers.Embedding(input_dim=vocab_size, output_dim=output_dim),
    keras.layers.Dropout(0.1),
    keras.layers.Bidirectional(keras.layers.LSTM(100, return_sequences=True, dropout=0.1)),
    keras.layers.Bidirectional(keras.layers.LSTM(100, dropout=0.1)),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dropout(0.1),
])

# This is for Tfidf vectorizer, no further embeddings needed
input_tfidf1 = keras.layers.Input(shape=(None, ))
input_tfidf2 = keras.layers.Input(shape=(None, ))
output1 = seq_model1(input_tfidf1)
output2 = seq_model1(input_tfidf2)
sim = keras.layers.Dot(axes=1, normalize=True)([output1, output2])
label1_prob = keras.activations.sigmoid(sim)
model1 = keras.Model(inputs=[input_tfidf1, input_tfidf2], outputs=label1_prob)

model1.compile(loss=keras.losses.BinaryCrossentropy(),
              optimizer=keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])
model1.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 100)       │  2,832,700 │ input_layer[0][0… │
# │ (Sequential)        │                   │            │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dot (Dot)           │ (None, 1)         │          0 │ sequential[0][0], │
# │                     │                   │            │ sequential[1][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sigmoid (Sigmoid)   │ (None, 1)         │          0 │ dot[0][0]         │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,832,700 (10.81 MB)
#  Trainable params: 2,832,700 (10.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
seq_model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, None, 200)      │     2,331,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, None, 200)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, None, 200)      │       240,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 200)            │       240,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │        20,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100)            │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,832,700 (10.81 MB)
#  Trainable params: 2,832,700 (10.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 2.4 Train the model

# %%
history = model1.fit([train_seqs1, train_seqs2], 
          np.array(labels_train), epochs=5, 
          validation_data=([dev_seqs1, dev_seqs2], 
                           np.array(labels_dev)), batch_size=500, class_weight={0: 1, 1: 3})
dev_loss, dev_acc = model1.evaluate([dev_seqs1, dev_seqs2], np.array(labels_dev))
print('Dev Loss:', dev_loss)
print('Dev Accuracy:', dev_acc)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2619 - loss: 1.0731 - val_accuracy: 0.3130 - val_loss: 0.9456
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.3085 - loss: 1.0359 - val_accuracy: 0.7312 - val_loss: 0.7996
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.4130 - loss: 1.0315 - val_accuracy: 0.6526 - val_loss: 0.8492
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.4473 - loss: 1.0249 - val_accuracy: 0.5805 - val_loss: 0.8904
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.4483 - loss: 1.0261 - val_accuracy: 0.6390 - val_loss: 0.8429
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.6468 - loss: 0.8421
# Dev Loss: 0.8429452180862427
# Dev Accuracy: 0.6389610171318054

# %%
def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.ylim(None, 1)
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')
plt.ylim(0, None)
# Out:
# (0.0, 1.072219568490982)

# %% [markdown]
# 2.5 Evidence Retrieval

# %%
# Task 1
top_k_evidence = 1

# e.g. evidence_retrival(dev_seqs1, dev_seqs2, 1000, dev_claims, dev_evidences)
def evidence_retrival(input_seqs1, input_seqs2, batch_size, claims, claim_candidates):
    test_claim_dict = {}
    predictions = model1.predict([input_seqs1, input_seqs2], batch_size=batch_size)
    for claim_id, claim_info in claims.items():
        top_k_predictions = sorted(enumerate(predictions[:k]), key=lambda x: x[1], reverse=True)[:top_k_evidence]
        top_k_evidence_num = [(index, value) for index, value in top_k_predictions]
        test_claim_dict[claim_id] = []
        for i in range(top_k_evidence):
            evidence_id = claim_candidates[claim_id][top_k_evidence_num[i][0]]
            prediction = top_k_evidence_num[i][1]
            evidence = evidences[evidence_id]
            test_claim_dict[claim_id].append((claim_info["claim_text"], evidence_id, evidence, prediction))
        predictions = predictions[k:]
    return test_claim_dict

# %%
dev_claim_dict = evidence_retrival(dev_seqs1, dev_seqs2, 50, dev_claims, dev_candidates)
test_claim_dict = evidence_retrival(test_seqs1, test_seqs2, 50, test_claims, test_candidates)
test_claim_dict
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step
# {'claim-2967': [('The contribution of waste heat to the global climate is 0.028 W/m2.',
#    'evidence-308923',
#    'Global forcing from waste heat was 0.028 W/m2 in 2005.',
#    array([0.5], dtype=float32))],
#  'claim-979': [('“Warm weather worsened the most recent five-year drought, which included the driest four-year period on record in terms of statewide precipitation.',
#    'evidence-957389',
#    'Between 2011 and 2014, California experienced the driest period in its recorded history and more than 100 million trees died in the drought, creating areas of dead, dry wood.',
#    array([0.722166], dtype=float32))],
#  'claim-1609': [('Greenland has only lost a tiny fraction of its ice mass.',
#    'evidence-1200633',
#    'Land ice sheets in both Antarctica and Greenland have been losing mass since 2002 and have seen an acceleration of ice mass loss since 2009.',
#    array([0.5], dtype=float32))],
#  'claim-1020': [('“The global reef crisis does not necessarily mean extinction for coral species.',
#    'evidence-642301',
#    'The coastal area features coral reefs with 450 species of coral and over 1200 species of fish.',
#    array([0.6592158], dtype=float32))],
#  'claim-2599': [('Small amounts of very active substances can cause large effects.',
#    'evidence-834109',
#    'While these substances are present as very small trace impurities, enough coal is burned that significant amounts of these substances are released.',
#    array([0.5], dtype=float32))],
#  'claim-2110': [("They changed the name from 'global warming' to 'climate change'",
#    'evidence-72690',
#    'Climate change',
#    array([0.5], dtype=float32))],
#  'claim-1135': [('Scientists confirm a mass bleaching event on the Great Barrier Reef this year has killed more corals than ever before, with more than two thirds destroyed across large swathes of the biodiverse site.',
#    'evidence-828180',
#    "An effect called coral bleaching can be seen on the Great Barrier Reef in Australia, where ocean acidification's effects are already taking place.",
#    array([0.7191757], dtype=float32))],
#  'claim-712': [('“Instead of a three-foot increase in ocean levels by the end of the century, six feet was more likely, according to DeConto and Pollard’s findings.',
#    'evidence-961837',
#    'Sluice boxes can be as short as a few feet, or more than ten feet (a common term for one that is over six feet +/- is a "Long Tom").',
#    array([0.7152914], dtype=float32))],
#  'claim-1307': [('a new study by scientists at the Australian Research Council finds that the ongoing bleaching event is mainly due to human-caused global warming, and that if global warming proceeds as currently expected, “large parts” of the Great Barrier Reef could die by the mid-2030s.',
#    'evidence-51798',
#    'In 2016 GALLUP found that 64% of Americans are worried about global warming, 59% believed that global warming is already happening and 65% is convinced that global warming is caused by human activities.',
#    array([0.71403044], dtype=float32))],
#  'claim-148': [('Previous IPCC reports tended to assume that clouds would have a neutral impact because the warming and cooling feedbacks would cancel each other out.',
#    'evidence-1091739',
#    'While turbines installed in water would have a cooling effect, the net impact on global surface temperatures would be an increase of .',
#    array([0.72741497], dtype=float32))],
#  'claim-903': [('Growers regularly pump CO2 into greenhouses, raising levels to three times that of the natural environment, to produce stronger, greener, healthier plants.”',
#    'evidence-12425',
#    'To increase yield further, some sealed greenhouses inject CO2 into their environment to help improve growth and plant fertility.',
#    array([0.7124248], dtype=float32))],
#  'claim-2942': [('It’s usually taken to be the fact that as carbon dioxide concentrations in the atmosphere increase, the 1 per cent of CO2 that’s the heavier carbon isotope ratio c13 declines in proportion.',
#    'evidence-572332',
#    "Carbon dioxide removal is different from reducing emissions, as the former produces an outlet of carbon dioxide from Earth's atmosphere, whereas the latter decreases the inlet of carbon dioxide to the atmosphere.",
#    array([0.72856116], dtype=float32))],
#  'claim-1001': [('‘This study goes beyond statistical correlations and explores a specific process that can plausibly explain how enhanced high-latitude warming trends may trigger remote weather impacts,’ he said.',
#    'evidence-1122793',
#    'Trend sceptics or deniers (who deny there is global warming), [and] argue that no significant climate warming is taking place at all, claiming that the warming trend measured by weather stations is an artefact due to urbanisation around those stations ("urban heat island effect").',
#    array([0.72607017], dtype=float32))],
#  'claim-1034': [('Your odds of correctly guessing the outcome of a flipped coin are 1 in 2, but your odds of guessing correctly twice in a row are only 1 in 4 —',
#    'evidence-348061',
#    'An important property is that an eavesdropper or man in the middle can not obtain enough information to be able to brute force guess a password without further interactions with the parties for each (few) guesses.',
#    array([0.7164439], dtype=float32))],
#  'claim-1009': [('‘Arctic ice conditions have been tracking at record low conditions since October, persisting for six consecutive months’',
#    'evidence-482300',
#    'Arctic sea ice extent ice hit an all-time low in September 2012, when the ice was determined to cover only 24% of the Arctic Ocean, offsetting the previous low of 29% in 2007.',
#    array([0.72854537], dtype=float32))],
#  'claim-770': [('[CO2] has increased 43 percent above the pre-industrial level so far',
#    'evidence-668884',
#    'CO2).',
#    array([0.5], dtype=float32))],
#  'claim-3074': [('Fourth Assessment Report (AR4), in which the likely range is given as 2.0°C to 4.5°C, with a best estimate of 3.0°C" (Pat Michaels)',
#    'evidence-526818',
#    'In its 2007 Fourth Assessment Report, IPCC said that climate sensitivity is "likely to be in the range 2 to 4.5\xa0°C with a best estimate of about 3\xa0°C".',
#    array([0.72056216], dtype=float32))],
#  'claim-1761': [('Multiple lines of evidence make it very clear that the rise in atmospheric CO2 is due to human emissions.',
#    'evidence-889101',
#    'Multiple lines of evidence support attribution of recent climate change to human activities:',
#    array([0.71685344], dtype=float32))],
#  'claim-1475': [("More than 500 scientists and professionals in climate and related fields have sent a 'European Climate Declaration' to the Secretary-General of the United Nations.",
#    'evidence-709490',
#    'While scientists knew of past climate change such as the ice ages, the concept of climate as unchanging was useful in the development of a general theory of what determines climate.',
#    array([0.72053665], dtype=float32))],
#  'claim-477': [('Scientists say halting deforestation ‘just as urgent’ as reducing emissions',
#    'evidence-1128272',
#    'Fourth, by reducing carbon emissions that are caused from deforestation and degradation.',
#    array([0.5], dtype=float32))],
#  'claim-1378': [('Antarctica is gaining land-based ice, according to a new study by NASA scientists published in the Journal of Glaciology',
#    'evidence-693807',
#    'In the terminology of glaciology, ice age implies the presence of extensive ice sheets in both northern and southern hemispheres.',
#    array([0.72337794], dtype=float32))],
#  'claim-503': [('“During the sunless winter, a heatwave raised concerns that the polar vortex may be eroding.',
#    'evidence-7898',
#    'The polar vortex Beginning on January 2, 2014, sudden stratospheric warming (SSW)[dubious – discuss] led to the breakdown of the semi-permanent feature across the Arctic known as the polar vortex.',
#    array([0.5], dtype=float32))],
#  'claim-2751': [('The argument that solving the global warming problem by reducing human greenhouse gas emissions is "too hard" generally stems from the belief that (i) our technology is not sufficiently advanced to achieve significant emissions reductions,',
#    'evidence-693067',
#    'Countries that have ratified this protocol have committed to reduce their emissions of carbon dioxide and five other greenhouse gases, or engage in emissions trading if they maintain or increase emissions of these gases.',
#    array([0.7212915], dtype=float32))],
#  'claim-2575': [('Over the last 30-40 years 80% of coral in the Caribbean have been destroyed and 50% in Indonesia and the Pacific.',
#    'evidence-728670',
#    'In the last 30–40 years, heat waves with high humidity have become more frequent and severe.',
#    array([0.71621203], dtype=float32))],
#  'claim-30': [("the bushfires [in Australia] were caused by arsonists and a series of lightning strikes, not 'climate change'",
#    'evidence-780092',
#    '"Climate change is one factor affecting how fires in Australia burn, regardless of whether arsonists or lightning started them".',
#    array([0.71522963], dtype=float32))],
#  'claim-2994': [("'Mauna Loa has been producing a readout which supports Manning's predetermined goal by showing steady growth in atmospheric CO2 concentrations since 1959.",
#    'evidence-386428',
#    'Figure 4 shows seasonal and annual changes in CO2 concentration measured at Mauna Loa, Hawaii from 1987 to 1990.',
#    array([0.71506965], dtype=float32))],
#  'claim-55': [('[T]he raw data, the actual thermometer data[...] shows that the US has been cooling for 80 to 90 years.',
#    'evidence-945472',
#    'In computing and data management, data mapping is the process of creating data element mappings between two distinct data models.',
#    array([0.72471], dtype=float32))],
#  'claim-1271': [('Greenland ice sheet … would balloon sea levels by around 7m should it disintegrate',
#    'evidence-1040612',
#    'The Greenland ice sheet occupies about 82% of the surface of Greenland, and if melted would cause sea levels to rise by 7.2 metres.',
#    array([0.5], dtype=float32))],
#  'claim-2248': [('Climate sensitivity can be calculated empirically by comparing past temperature change to natural forcings at the time.',
#    'evidence-1008952',
#    'Climate sensitivity is often evaluated in terms of the change in equilibrium temperature due to radiative forcing caused by the greenhouse effect.',
#    array([0.71814966], dtype=float32))],
#  'claim-532': [('Never mind that the emissions of carbon dioxide to make and maintain a wind or solar industrial complex are far greater than they will ever save.',
#    'evidence-572332',
#    "Carbon dioxide removal is different from reducing emissions, as the former produces an outlet of carbon dioxide from Earth's atmosphere, whereas the latter decreases the inlet of carbon dioxide to the atmosphere.",
#    array([0.7217165], dtype=float32))],
#  'claim-556': [('The April low temperatures here are now about 6 degrees Fahrenheit warmer than they used to be.',
#    'evidence-128472',
#    'Temperatures 2 degrees Fahrenheit (1 degree Celsius) above average can cause bleaching.',
#    array([0.73100764], dtype=float32))],
#  'claim-1173': [('[…]until we develop a practical, cost-competitive alternative to fossil fuels, it is unlikely that renewable energy will ever make up more than 15-20% of global energy requirements.',
#    'evidence-254529',
#    'New energy industries include the renewable energy industry, comprising alternative and sustainable manufacture, distribution, and sale of alternative fuels.',
#    array([0.7249744], dtype=float32))],
#  'claim-539': [('We note that the Earth has never in its history had a quasi-stable state that is around 2C warmer than the preindustrial and suggest that there is substantial risk that the system, itself, will ‘want’ to continue warming because of all of these other processes – even if we stop emissions,” she said.',
#    'evidence-1172137',
#    'For example, the emissions reductions proposed by Nordhaus (2010) might lead to global warming (in the year 2100) of around 3\xa0°C, relative to pre-industrial levels.',
#    array([0.72106785], dtype=float32))],
#  'claim-893': [('While France and other G7 countries lamented the U.S. exit from the Paris climate accord, America’s air is already cleaner than that of any other country in the G7, except Canada with its scant population.',
#    'evidence-34493',
#    'G7 ministers also meet throughout the year, such as the G7 finance ministers (who meet four times a year), G7 foreign ministers, or G7 environment ministers.',
#    array([0.7231543], dtype=float32))],
#  'claim-2857': [('Weather is chaotic because air is light, it has low friction and viscosity, it expands strongly when in contact with hot surfaces and it conducts heat poorly.',
#    'evidence-72528',
#    'The metal must have a low viscosity to be usable, and to reach this low viscosity the material needs a globular primary surrounded by the liquid phase.',
#    array([0.7211682], dtype=float32))],
#  'claim-109': [('Local and regional sea levels continue to exhibit typical natural variability—in some places rising and in others falling.',
#    'evidence-315990',
#    'The sea level rose quickly after that, stabilizing at the current level about 4,000 years ago, leaving the mainland of South Florida just above sea level.',
#    array([0.7261071], dtype=float32))],
#  'claim-2476': [("The global dimming trend reversed around 1990 - 15 years after the global warming trend began in the mid 1970's.",
#    'evidence-315033',
#    'Climate change refers to a broad range of global phenomena ...[which] include the increased temperature trends described by global warming."',
#    array([0.7214329], dtype=float32))],
#  'claim-3038': [('Clearly, other factors besides atmospheric carbon influence earth temperatures and global warming."',
#    'evidence-34759',
#    'Singer argues there is no evidence that global warming is attributable to human-caused increases in atmospheric carbon dioxide, and that humanity would benefit if temperatures do rise.',
#    array([0.7164088], dtype=float32))],
#  'claim-3127': [('"Skeptics hope that Postma’s alternative thermal model will lead  to the birth of a new climatology, one that actually follows the laws of  physics and properly physical modeling techniques...',
#    'evidence-1166652',
#    'An alternative framework for statistical hypothesis testing is to specify a set of statistical models, one for each candidate hypothesis, and then use model selection techniques to choose the most appropriate model.',
#    array([0.72476256], dtype=float32))],
#  'claim-474': [('Sea ice continued its declining trend, both in the Arctic and Antarctic.',
#    'evidence-559069',
#    'Accelerated decline in the Arctic sea ice.',
#    array([0.5], dtype=float32))],
#  'claim-2464': [('While natural forcings can account for much of the early 20th Century warming, humans played a role as well.',
#    'evidence-1076603',
#    'This is the case for the conclusions that the Earth system is warming and that much of this warming is very likely due to human activities.',
#    array([0.70861125], dtype=float32))],
#  'claim-2427': [('By that time CO2 emissions had already risen from the expanded use  of coal that had powered the industrial revolution, and emissions only  increased slowly from 3.5gigatonnes in 1910 to under 4gigatonnes by the  end of the Second World War.',
#    'evidence-527316',
#    'For emissions trading where greenhouse gases are regulated, one emissions permit is considered equivalent to one metric ton of carbon dioxide (CO2) emissions.',
#    array([0.71164346], dtype=float32))],
#  'claim-2167': [('Royal Society embraces skepticism',
#    'evidence-402677',
#    'He was also a fellow of the Royal Society.',
#    array([0.7310586], dtype=float32))],
#  'claim-812': [('The human contribution can be up to 30 percent or so of the total rainfall coming out of the storm',
#    'evidence-250928',
#    "The central case estimate is that aviation's contribution could grow to five percent of the total contribution by 2050 if action is not taken to tackle these emissions, though the highest scenario is 15 percent.",
#    array([0.66954744], dtype=float32))],
#  'claim-2590': [("This argument originates from Angstrom's work in 1901.",
#    'evidence-507814',
#    'Some common schemes are argument from goal-based reasoning, argument from negative consequences, argument from positive consequences, inference to the best explanation (abductive reasoning), argument from sign, argument from analogy, argument from precedent, argument from an established rule, argument from evidence to a hypothesis, argument from cause to effect, argument from correlation to cause, argument from sunk costs, argument from threat, argument from perception, argument from witness testimony, argument from expert opinion, argument from ignorance, argument from commitment, direct ad hominem argument, argument from inconsistency of commitments, slippery slope argument.',
#    array([0.5], dtype=float32))],
#  'claim-404': [('Actual weather records over the past 100 years show no correlation between rising carbon dioxide levels and local temperatures.',
#    'evidence-725977',
#    'On the other hand, any doubling of the percentage of carbon dioxide in the air would raise the temperature of the earth\'s surface by 4°; and if the carbon dioxide were increased fourfold, the temperature would rise by 8°."',
#    array([0.72839487], dtype=float32))],
#  'claim-2977': [('According to the study, as carbon levels have risen, the cold air at high altitudes over the tropics has actually grown colder.',
#    'evidence-846997',
#    'The presence of the lake produces a vacuum of sorts during the growing season : warm air over the lake rises, sucking colder air off the land and creating offshore breezes.',
#    array([0.72656554], dtype=float32))],
#  'claim-2673': [('They changed the name from “global warming” to “climate change” after the term global warming just wasn’t working (it was too cold)!',
#    'evidence-1106221',
#    'He has given many TV and radio interviews, and is a speaker on climate change and global warming, and global environmental changes.',
#    array([0.72829473], dtype=float32))],
#  'claim-2509': [('In 1905, PDO switched to a warm phase.',
#    'evidence-667390',
#    '1976/1977: PDO changed to a "warm" phase.',
#    array([0.5], dtype=float32))],
#  'claim-138': [('As a result, half of the people surveyed around the world last year said they thought climate change would make humanity extinct.',
#    'evidence-1178287',
#    'Abrupt climate change, tipping points in the climate system: Climate change could result in global, large-scale changes.',
#    array([0.72068745], dtype=float32))],
#  'claim-952': [('The Alaskan tundra is warming so quickly it has become a net emitter of carbon dioxide ahead of schedule, a new study finds',
#    'evidence-6913',
#    'Fossil fueled power stations are major emitters of carbon dioxide (CO2), a greenhouse gas which is a major contributor to global warming.',
#    array([0.7235601], dtype=float32))],
#  'claim-1691': [('Sea level rise is now increasing faster than predicted due to unexpectedly rapid ice melting.',
#    'evidence-923525',
#    'Therefore, when a mass of floating ice melts, sea levels will increase; however, this effect is small enough that if all extant sea ice and floating ice shelves were to melt, the corresponding sea level rise is estimated to be ~4\xa0cm.',
#    array([0.7101001], dtype=float32))],
#  'claim-1741': [('Volcanoes have had no warming effect in recent global warming - if anything, a cooling effect.',
#    'evidence-886906',
#    'The effects of global warming include its effects on human health.',
#    array([0.5], dtype=float32))],
#  'claim-1202': [('\xa0The discrepancy between model-predicted warming and (lower) real-world observations has inspired new respect for natural climate variability relative to greenhouse-gas forcing.\xa0',
#    'evidence-681843',
#    'This internal variability is a result of complex interactions between components of the climate system, such as the coupling between the atmosphere and ocean (see also the later section on Internal climate variability and global warming).',
#    array([0.72415036], dtype=float32))],
#  'claim-1028': [('A second coat of paint has much less of an effect, while adding a third or fourth coat has almost no impact at all.”',
#    'evidence-644769',
#    'The coatings being developed can be the paint itself, or a clear coat added on top of existing paint or building facades.',
#    array([0.7069508], dtype=float32))],
#  'claim-28': [('Volcanoes Melting West Antarctic Glaciers, Not Global Warming',
#    'evidence-1088478',
#    'The effect of global warming is already being registered in melting glaciers, melting mountain ice caps, and rising sea levels.',
#    array([0.5], dtype=float32))],
#  'claim-275': [('until temperature increases began to slow down after 1998 and remained relatively stable for a period of 15 years',
#    'evidence-1190921',
#    'Enrollments have generally remained stable, with numbers in the secondary section increasing slightly since the previous year.',
#    array([0.72334594], dtype=float32))],
#  'claim-350': [('Since 1965, more parts of the U.S. have seen a decrease in flooding than have seen an increase.',
#    'evidence-245108',
#    'See more at : http://www.omharmonics.com/blog/how-music-affects-the-brain/#sthash.icpaf4wl.dpuf',
#    array([0.5], dtype=float32))],
#  'claim-2204': [('All the indicators show that global warming is still happening.',
#    'evidence-368794',
#    'It shows a general warming in global temperatures.',
#    array([0.5], dtype=float32))],
#  'claim-1604': [('CO2 increase is natural, not human-caused.',
#    'evidence-668884',
#    'CO2).',
#    array([0.5], dtype=float32))],
#  'claim-3119': [('CO2 constitutes 80% of the non-condensing greenhouse gas forcing.',
#    'evidence-556098',
#    "It is one of the largest sources of greenhouse gases, responsible for 18% of the world's greenhouse gas emissions as measured in CO2 equivalents.",
#    array([0.5], dtype=float32))],
#  'claim-2150': [('Adapting to global warming is cheaper than preventing it',
#    'evidence-403673',
#    'Global Warming of 1.5\xa0°C.',
#    array([0.5], dtype=float32))],
#  'claim-21': [('Sea level rise has been slow and a constant, pre-dating industrialization',
#    'evidence-520022',
#    'The rate of rise started to slow down about 8,200\xa0years before present; the sea level was almost constant in the last 2,500 years, before the recent rising trend that started at the end of the 19th century or in the beginning of the 20th.',
#    array([0.5], dtype=float32))],
#  'claim-2013': [('U.S. Sen. Ron Johnson voted to let oil and gas companies emit "unlimited carbon pollution into our air"',
#    'evidence-886517',
#    'The 1955 Air Pollution Control Act was the first U.S. federal legislation that pertained to air pollution; it also provided funds for federal government research of air pollution.',
#    array([0.7147098], dtype=float32))],
#  'claim-467': [('This is the South Pole ice, 90% of Earth’s ice, and it’s getting thicker.',
#    'evidence-1017204',
#    'The ice shelf was at (), approximately south of the North Pole.',
#    array([0.5], dtype=float32))],
#  'claim-2754': [('"There are many urgent priorities that need the attention of Congress, and it is not for me as an invited guest in your country to say what they are.',
#    'evidence-309446',
#    'It often invites guest lecturers from other countries.',
#    array([0.5], dtype=float32))],
#  'claim-2797': [('Global brightening is caused by changes in cloud cover, reflective aerosols and absorbing aerosols.',
#    'evidence-1000246',
#    'The converse is true of absorbing aerosol, with the greatest radiative forcing arising from a highly absorbing aerosol over a surface of high albedo.',
#    array([0.7227314], dtype=float32))],
#  'claim-1771': [('Peer-reviewed research, physics, and math all tell us that a grand solar minimum would have no more than a 0.3°C cooling effect, barely enough to put a dent in human-caused global warming.',
#    'evidence-1082770',
#    'It also creates a cooling effect and this may have partially masked the effect of greenhouse gases on global warming.',
#    array([0.7227779], dtype=float32))],
#  'claim-1908': [('In reality, gas produced by fracking is worse for the climate than coal.',
#    'evidence-1065464',
#    'Meanwhile, Bittman discovers that extracting natural gas through fracking delays our transition to renewable energy and that fracking wells leak a large amount of methane, a powerful greenhouse gas, which makes fracked natural gas as dirty as, or dirtier than, burning coal.',
#    array([0.5], dtype=float32))],
#  'claim-2000': [('There is not a single candidate in the Republican primary that thinks we should do anything about climate change.',
#    'evidence-874144',
#    'Hamilton argues that to believe anything else is to deny the climate change truth and engage in wishful thinking.',
#    array([0.66861314], dtype=float32))],
#  'claim-2084': [("Hurricanes aren't linked to global warming",
#    'evidence-415989',
#    'In his book Storm World: Hurricanes, Politics, and the Battle over Global Warming, Chris Mooney discusses tensions between two different approaches to analyzing global warming and its effect on hurricanes.',
#    array([0.5], dtype=float32))],
#  'claim-1237': [('the last sea-level high point, … occurred between the last two ice ages, about 125,000 years ago.',
#    'evidence-15429',
#    'After the last ice age, which ended in the Black Forest about 10,000 years ago, it was left behind.',
#    array([0.71976745], dtype=float32))],
#  'claim-400': [('The idea that climate change is producing heat records across the Earth is among the most egregious manipulations of data in the absurd global warming debate.',
#    'evidence-957593',
#    'The current scientific consensus on climate change is that the Earth underwent global warming throughout the 20th century and continues to warm.',
#    array([0.724325], dtype=float32))],
#  'claim-1508': [('global warming ceased around the end of the twentieth century and was followed (since 1997) by 19 years of stable temperature.',
#    'evidence-1092088',
#    'Since the start of the 20th century, the global mean surface temperature of the Earth has increased by more than 0.7°C and the rate of warming has been largest in the last 30 years.',
#    array([0.72271216], dtype=float32))],
#  'claim-520': [('Just 1.25 per cent of the carbon dioxide in the atmosphere-ocean system has been released by \xadhumans in the past 250 years.',
#    'evidence-833215',
#    'Oraons (14 per cent), Mundas (7.8 per cent), Bhumij (7.6 per cent) and',
#    array([0.72023], dtype=float32))],
#  'claim-3064': [('No warming since at least 1995, no melting glaciers and now no rising sea levels.',
#    'evidence-98543',
#    'Since at least the start of the 20th century, the average global sea level has been rising.',
#    array([0.69621515], dtype=float32))],
#  'claim-1588': [("Melting ice isn't warming the Arctic.",
#    'evidence-1043067',
#    'New warning on Arctic sea ice melt.',
#    array([0.5], dtype=float32))],
#  'claim-1488': [('New Study Confirms EVs Considerably Worse For Climate Than Diesel Cars.',
#    'evidence-431982',
#    'Exposure compensation range : -2 to +2 EV in 1/3 EV steps',
#    array([0.7310586], dtype=float32))],
#  'claim-2733': [('A number of independent studies using near-global satellite data find positive feedback and high climate sensitivity.',
#    'evidence-152168',
#    'There are many feedback mechanisms in the climate system that can either amplify (a positive feedback) or diminish (a negative feedback) the effects of a change in climate forcing.',
#    array([0.71443385], dtype=float32))],
#  'claim-809': [('In the early 20th century, state and federal governments began aggressively fighting wildfires and trying to keep them as small as possible.',
#    'evidence-1087915',
#    'First Commonwealth has long served the Central Pennsylvania region, but began aggressively expanding into the Western part of the state in the early 2000s (decade), particularly Pittsburgh.',
#    array([0.725093], dtype=float32))],
#  'claim-763': [('And some plants – like algae which use carbon for photosynthesis – may even benefit.',
#    'evidence-826833',
#    'They may belong to one of several groups of multicellular algae : the red algae, green algae, and brown algae.',
#    array([0.7251265], dtype=float32))],
#  'claim-454': [('Man-made greenhouse gases play only an insignificant role.”',
#    'evidence-199466',
#    'In international rankings it is below the world average but not insignificant.',
#    array([0.5], dtype=float32))],
#  'claim-1853': [('Barack Obama supports proposals "to devote billions of dollars annually to state game and fish agencies and federal land management agencies to help them ensure that fish and wildlife survive the impacts of climate change."',
#    'evidence-972641',
#    "Among the responsibilities of the FWS are enforcing federal wildlife laws, protecting endangered species, managing migratory birds, restoring nationally significant fisheries, conserving and restoring wildlife habitat, such as wetlands, helping foreign governments with their international conservation efforts, and distributing money to states ' fish and wildlife agencies through the Wildlife Sport Fish and Restoration program.",
#    array([0.7231364], dtype=float32))],
#  'claim-2838': [("The data is being reported by the University of Illinois's Arctic Climate Research Center, and is derived from satellite observations of the Northern and Southern hemisphere polar regions (Daily Tech).",
#    'evidence-117846',
#    'SEARCH activities are supported by a collaborative grant from the National Science Foundation Division of Polar Programs, Arctic Sciences Section to the International Arctic Research Center, and the Arctic Research Consortium of the US.',
#    array([0.7222381], dtype=float32))],
#  'claim-2028': [('cutting speed limits could slow climate change',
#    'evidence-278964',
#    'This could help limit climate change in Turkey.',
#    array([0.5], dtype=float32))],
#  'claim-2434': [('The IPCC blames human emissions of carbon dioxide for the last  warming.',
#    'evidence-1117137',
#    'There is a scientific consensus linking human activities to global warming due to industrial carbon dioxide emissions.',
#    array([0.6837003], dtype=float32))],
#  'claim-298': [('Only very few peer-reviewed papers even go so far as to say that recent warming is chiefly anthropogenic.',
#    'evidence-844208',
#    'In June\xa02011, Gray wrote a paper directed at the American Meteorological Society, criticizing their advocation of anthropogenic global warming.',
#    array([0.7235191], dtype=float32))],
#  'claim-338': [('Rapid assessment of average temperatures in France between 26-28 June showed a “substantial” increase in the likelihood of the heatwave happening as a result of human-caused global warming, experts at the World Weather Attribution group said.',
#    'evidence-895823',
#    'However, speaking more properly, "global warming" denotes the mainly human-caused increase in global surface temperatures and its projected continuation, but "climate change" includes both "global warming" and its effects, such as changes in precipitation and impacts that differ by region.',
#    array([0.7192269], dtype=float32))],
#  'claim-1672': [('Global temperature is still rising and 2010 was the hottest recorded.',
#    'evidence-922640',
#    'The temperature was the hottest measured in 68 years.',
#    array([0.5], dtype=float32))],
#  'claim-2840': [('Arctic sea ice is also falling at an accelerated rate.',
#    'evidence-559069',
#    'Accelerated decline in the Arctic sea ice.',
#    array([0.5], dtype=float32))],
#  'claim-1425': [('Each year sees the disappearance of thousands of plant and animal species which we will never know, which our children will never see, because they have been lost for ever.',
#    'evidence-204609',
#    'Never had',
#    array([0.5], dtype=float32))],
#  'claim-1985': [('The North Pole is melting "a bit" but the South Pole is getting bigger.',
#    'evidence-232707',
#    "The talk was entitled : ``Poles Apart - The environment near a planet 's poles''",
#    array([0.7310586], dtype=float32))],
#  'claim-1156': [('The costs of emissions regulations, which will be paid by everyone, will be punishingly high and will provide no benefits to most people anywhere in the world.',
#    'evidence-1142116',
#    'This is because the people who bear emission reduction costs or benefits are often different from those who pay or benefit from adaptation measures.',
#    array([0.72363496], dtype=float32))],
#  'claim-2870': [("Ironically, it's those who are mispresenting Hulme's paper that are the ones being misleading.",
#    'evidence-1034945',
#    'Ironically, 2GZ was once one of the regional stations that Laws worked at before becoming a national radio icon.',
#    array([0.7310586], dtype=float32))],
#  'claim-2898': [('The report suggests significantly smaller overall  ice-mass losses than previous estimates.',
#    'evidence-947921',
#    'These people contribute significantly to the overall amount of airmiles flown within a given society.',
#    array([0.6067371], dtype=float32))],
#  'claim-2329': [('We know the Northwest Passage had been open before."',
#    'evidence-866503',
#    "The commercial survivors are -- in addition to the Passage des Panoramas -- the Galerie Vivienne, the Passage Choiseul, the Galerie Colbert, the Passage des Princes, the Passage du Grand Cerf, the Passage du Caire, the Passage Lemoine, the Passage Jouffroy, the Passage Basfour, the Passage du Bourg-L'abbé, and the Passage du Ponceau.",
#    array([0.5], dtype=float32))],
#  'claim-1998': [('There is a link between climate change and the NSW bushfires.',
#    'evidence-772442',
#    'The false claims are, in some cases, used to undermine the link between the current bushfires and the longer, more intense fire seasons brought about by climate change."',
#    array([0.5], dtype=float32))],
#  'claim-2209': [('Surface temperatures can show short-term cooling when heat is exchanged between the atmosphere and the ocean, which has a much greater heat capacity than the air.',
#    'evidence-763705',
#    'This technology is practiced not only for domestic heating (low temperature) but also for industrial process heat, which is often high temperature heat.',
#    array([0.72435266], dtype=float32))],
#  'claim-1582': [("Tuvalu sea level isn't rising.",
#    'evidence-988277',
#    'Sea level rise will continue over many centuries.',
#    array([0.7310586], dtype=float32))],
#  'claim-3072': [('"a paper...in Science magazine concludes that the climate sensitivity—how much the earth’s average temperature will rise as a result of a doubling of the atmospheric concentration of carbon dioxide—likely (that is, with a 66% probability) lies in the range 1.7°C to 2.6°C, with a median value of 2.3°C.',
#    'evidence-1196020',
#    "The equilibrium climate sensitivity (ECS) is the temperature increase that would result from sustained doubling of the concentration of carbon dioxide in Earth's atmosphere, after the Earth's energy budget and the climate system reach radiative equilibrium.",
#    array([0.72141314], dtype=float32))],
#  'claim-381': [('[subsidies for wind and solar] add to emissions because coal-fired elec\xadtricity needs to be on standby for when there is no wind or sunshine.',
#    'evidence-851967',
#    'The electricity is generated from wind, solar and biomass, and most of the producers are located on farms or are larger wind parks.',
#    array([0.72360784], dtype=float32))],
#  'claim-398': [('nothing we can do to stop the Earth’s naturally occurring climate cycles.',
#    'evidence-535128',
#    "``Naturally'' (Kalapana song)",
#    array([0.5], dtype=float32))],
#  'claim-1560': [('Sea level rise predictions are exaggerated.',
#    'evidence-988277',
#    'Sea level rise will continue over many centuries.',
#    array([0.7310586], dtype=float32))],
#  'claim-2246': [('"His [Dr Spencer\'s] latest research demonstrates that – in the short term, at any rate –  the temperature feedbacks that the IPCC imagines will greatly amplify  any initial warming caused by CO2 are net-negative, attenuating the  warming they are supposed to enhance.',
#    'evidence-338987',
#    'The main positive feedback in global warming is the tendency of warming to increase the amount of water vapor in the atmosphere, which in turn leads to further warming.',
#    array([0.70906097], dtype=float32))],
#  'claim-2774': [('Actual reconstructions "diverge" from the instrumental series in the last part of 20th century.',
#    'evidence-1131132',
#    'This was the last World Series to feature players born in the 20th century.',
#    array([0.5], dtype=float32))],
#  'claim-972': [('“Arctic land stores about twice as much carbon as the atmosphere.',
#    'evidence-248795',
#    'Permafrost contains almost twice as much carbon as is present in the atmosphere.',
#    array([0.5], dtype=float32))],
#  'claim-1531': [('Earth’s climate is now changing faster than at any point in the history of modern civilization, primarily as a result of human activities.',
#    'evidence-809426',
#    "Anthropogenic climate change is caused by human activity, as opposed to changes in climate that may have resulted as part of Earth's natural processes.",
#    array([0.7299435], dtype=float32))],
#  'claim-2592': [('"A July 6, 2007 study published in the journal Science about Greenland by an international team of scientists found DNA “evidence that suggests the frozen shield covering the immense island survived the Earth’s last period of global warming,” according to a Boston Globe Article. \xa0...',
#    'evidence-877733',
#    'A 2012 analysis of published research on global warming and climate change between 1991 and 2012 found that of the 13,950 articles in peer-reviewed journals, only 24 rejected anthropogenic global warming.',
#    array([0.6436708], dtype=float32))],
#  'claim-2468': [('"Satellite measurements indicate an absence of significant global warming since 1979, the very period that human carbon dioxide emissions have been increasing rapidly.',
#    'evidence-801082',
#    'Not only do increasing carbon dioxide concentrations lead to increases in global surface temperature, but increasing global temperatures also cause increasing concentrations of carbon dioxide.',
#    array([0.72179615], dtype=float32))],
#  'claim-463': [('“So now we’re able to explain from natural factors how we’ve had the 20th Century warming.',
#    'evidence-957593',
#    'The current scientific consensus on climate change is that the Earth underwent global warming throughout the 20th century and continues to warm.',
#    array([0.5741231], dtype=float32))],
#  'claim-616': [('The effect of long-term warming is to make it harder to count on snowmelt runoff in wet times',
#    'evidence-999756',
#    "Snowmelt runoff from the Earth's mountains fills the rivers and recharges the aquifers that over a billion people depend on for their water resources.",
#    array([0.72815156], dtype=float32))],
#  'claim-1240': [('“Ice-free means the central basin of the Arctic will be ice-free',
#    'evidence-586254',
#    'Many scientists have attempted to estimate when the Arctic will be "ice-free".',
#    array([0.5], dtype=float32))],
#  'claim-2951': [('The two most cited composites are PMOD and ACRIM.',
#    'evidence-491726',
#    'Differences between ACRIM and PMOD TSI composites are evident, but the most significant is the solar minimum-to-minimum trends during solar cycles 21-23.',
#    array([0.5], dtype=float32))],
#  'claim-1977': [('The climate-change agreement between the United States and China "requires the Chinese to do nothing at all for 16 years."',
#    'evidence-341698',
#    'Han (, Old Chinese: "*") was an ancient Chinese state during the Warring States period of ancient China.',
#    array([0.6796147], dtype=float32))],
#  'claim-942': [('‘We could be decades too fast, or decades too slow,’said one of them, Robert M. DeConto of the University of Massachusetts, Amherst.',
#    'evidence-90819',
#    'The 1980 Amherst, Massachusetts water shortage was a water crisis in Amherst, Massachusetts that amongst other things, closed the University of Massachusetts Amherst for three days.',
#    array([0.71798784], dtype=float32))],
#  'claim-2755': [('Global warming is an increasingly urgent problem.',
#    'evidence-403673',
#    'Global Warming of 1.5\xa0°C.',
#    array([0.5], dtype=float32))],
#  'claim-1230': [('On the Pacific Coast, a climate pattern that had pushed billions of gallons of water toward Asia is now ending, so that in coming decades the sea is likely to rise quickly off states like Oregon and California.',
#    'evidence-968192',
#    "Africa's population is expected to rise from the current one billion to four billion by 2100, and Asia could add another billion in the same period.",
#    array([0.72621006], dtype=float32))],
#  'claim-3123': [('Given that a doubling of carbon dioxide would change the surface heat flux by only two watts per square meter, it is evident that a small change in cloud cover can strongly affect the response to carbon dioxide."',
#    'evidence-725977',
#    'On the other hand, any doubling of the percentage of carbon dioxide in the air would raise the temperature of the earth\'s surface by 4°; and if the carbon dioxide were increased fourfold, the temperature would rise by 8°."',
#    array([0.7250519], dtype=float32))],
#  'claim-1684': [('The 2nd law of thermodynamics is consistent with the greenhouse effect which is directly observed.',
#    'evidence-256785',
#    'Hansen testified that "Global warming has reached a level such that we can ascribe with a high degree of confidence a cause and effect relationship between the greenhouse effect and observed warming...It is already happening now" and "The greenhouse effect has been detected and it is changing our climate now...We already reached the point where the greenhouse effect is important."',
#    array([0.57532936], dtype=float32))],
#  'claim-839': [('“Even if we meet the Paris goals of two degrees warming, cities like Karachi and Kolkata will become close to uninhabitable, annually encountering deadly heat waves like those that crippled them in 2015.',
#    'evidence-482130',
#    'The famous heat wave events of Chicago in 1995 and the European heat wave of 2003 regions will experience longer, more frequent and more intense heat waves in the latter 21st century.',
#    array([0.7241073], dtype=float32))],
#  'claim-2423': [('Arctic sea ice has been steadily thinning, even in the last few years while the surface ice (eg - sea ice extent) increased slightly.',
#    'evidence-482300',
#    'Arctic sea ice extent ice hit an all-time low in September 2012, when the ice was determined to cover only 24% of the Arctic Ocean, offsetting the previous low of 29% in 2007.',
#    array([0.72629845], dtype=float32))],
#  'claim-1243': [('by that I mean the central Arctic will be ice-free.',
#    'evidence-586254',
#    'Many scientists have attempted to estimate when the Arctic will be "ice-free".',
#    array([0.5], dtype=float32))],
#  'claim-494': [('The Massachusetts Bay Colony in 1635 experienced a Category 3 or 4 storm, with up to a 20-foot storm surge.',
#    'evidence-298897',
#    'Storm of the Century (1993) - A large storm system that affected the eastern third of the North America',
#    array([0.71518767], dtype=float32))],
#  'claim-1458': [('Glaciers are retreating almost everywhere around the world — including in the Alps, Himalayas, Andes, Rockies, Alaska and Africa.',
#    'evidence-603102',
#    'Similarly, of the glaciers in the Italian Alps, only about a third were in retreat in 1980, while by 1999, 89% of these glaciers were retreating.',
#    array([0.7158316], dtype=float32))],
#  'claim-461': [('Temperatures cooled from about 1940 to 1975, and then they rose from about ’75 to about 2005 or so, and since then they’ve been flat or cooling.',
#    'evidence-634493',
#    'There are four main mechanisms for cooling the air to its dew point: adiabatic cooling, conductive cooling, radiational cooling, and evaporative cooling.',
#    array([0.72255], dtype=float32))],
#  'claim-1304': [('in a letter to The Times from Lord Krebs and company, essentially telling the newspaper to stop reporting less-than-negative climate stories.',
#    'evidence-717267',
#    "Dr. Krebs' son, Stanley Krebs, was the husband of Marjorie Main.",
#    array([0.5], dtype=float32))],
#  'claim-2564': [('This small warming is  likely a result of the natural alterations in global ocean currents  which are driven by ocean salinity variations.',
#    'evidence-881306',
#    'In the deep ocean, the predominant driving force is differences in density, caused by salinity and temperature variations (increasing salinity and lowering the temperature of a fluid both increase its density).',
#    array([0.7248284], dtype=float32))],
#  'claim-2121': [('Infrared Iris will reduce global warming',
#    'evidence-106151',
#    'Iris assadiana is a species in the genus Iris, it is also in the subgenus of Iris.',
#    array([0.5], dtype=float32))],
#  'claim-2631': [('The temperatures are expected to change by as much as 10 Fahrenheit degrees at different places of the globe.',
#    'evidence-547651',
#    'At the poles, tropospheric temperature only decreases from an average of 0\xa0°C (32-degree fahrenheit) at sea level to about −45\xa0°C (-49-degree fahrenheit) at the tropopause.',
#    array([0.7256116], dtype=float32))],
#  'claim-1141': [('“While record low sea ice is nothing new in the Arctic, this is a surprising turn of events for the Antarctic.',
#    'evidence-1013303',
#    'The net change is a slight increase in the area of sea ice in the Antarctic seas (unlike the Arctic Ocean, which is showing a much stronger decrease in the area of sea ice).',
#    array([0.71864146], dtype=float32))],
#  'claim-2398': [('While there are direct ways in which CO2 is a pollutant (acidification of the ocean), its primary impact is its greenhouse warming effect.',
#    'evidence-1167418',
#    'Effects of global warming on oceans provides information on the various effects that global warming has on oceans.',
#    array([0.7233885], dtype=float32))],
#  'claim-1048': [('While transient weather variability is playing a key role here, the widespread record warmth across the U.S. so far this year is part of a long-term trend toward more warm temperature records versus cold ones.',
#    'evidence-367175',
#    'The geological record, however, shows a continually relatively warm surface during the complete early temperature record of Earth with the exception of one cold glacial phase about 2.4 billion years ago.',
#    array([0.72638166], dtype=float32))],
#  'claim-2783': [('The study indicates far less future global warming will occur than United Nations computer models have predicted, and supports prior studies indicating increases in atmospheric carbon dioxide trap far less heat than alarmists have claimed.',
#    'evidence-669520',
#    'Current studies indicate that the increase in greenhouse gases, most notably , is mostly responsible for the observed warming.',
#    array([0.6990401], dtype=float32))],
#  'claim-1003': [('A recent study in Nature Geoscience, for instance, called into question whether the Arctic’s melting, and in particular its sea ice loss, has been causing winter cooling over Eurasia, another idea that has been swept up in the debate over the jet stream and weather extremes.”',
#    'evidence-118577',
#    'The effects of global warming in the Arctic include rising temperatures, loss of sea ice, and melting of the Greenland ice sheet.',
#    array([0.6840989], dtype=float32))],
#  'claim-1872': [('Donald Trump claims Global Warming is a hoax',
#    'evidence-1160675',
#    '"Fact: Trump claimed climate change is a hoax created by China".',
#    array([0.5], dtype=float32))],
#  'claim-1842': [('A video shows Koko the gorilla spontaneously using sign language to issue a warning about climate change.',
#    'evidence-47367',
#    "Hanabiko ``Koko'' (born July 4, 1971) is a female western lowland gorilla who is known for having learned a large number of hand signs from a modified version of American Sign Language (ASL).",
#    array([0.71406794], dtype=float32))],
#  'claim-2411': [('Note that computer models are just concatenations of calculations you could do on a hand-held calculator, so they are theoretical and cannot be part of any evidence."',
#    'evidence-519547',
#    "``Well the first thing that comes to my mind when I saw a gameboy show was Kraftwerk 's Computer World Tour from 1981, where four of them played various handheld devices during the song ` Pocket Calculator '.",
#    array([0.6766792], dtype=float32))],
#  'claim-2428': [('It was the post war  industrialization that caused the rapid rise in global CO2 emissions,  but by 1945 when this began, the Earth was already in a cooling phase  that started around 1942 and continued until 1975.',
#    'evidence-1205623',
#    'the CO2 concentration already released into the atmosphere since the beginning of industrialization, which has risen from well below 300 PPM to more than 415 PPM (2019).',
#    array([0.7206699], dtype=float32))],
#  'claim-1198': [('” ‘You see, gas in America is incredibly cheap, because of fracking,’ he says.',
#    'evidence-658428',
#    'It is also, at times, incredibly funny.',
#    array([0.5], dtype=float32))],
#  'claim-678': [('In the process, the cows will emit much greenhouse gas, and they will consume far more calories in beans than they will yield in meat, meaning far more clearcutting of forests to farm cattle feed than would be necessary if the beans above were simply eaten by people.”',
#    'evidence-8569',
#    'People were not as wealthy as today, consumed fewer calories and ate less meat, so less water was needed to produce their food.',
#    array([0.712983], dtype=float32))],
#  'claim-2105': [('Excess CO2 from human emissions has a long residence time of over 100 years',
#    'evidence-1162945',
#    'Coal, being mostly carbon, emits a lot of CO2 when burnt: it has a high CO2 emission intensity.',
#    array([0.704233], dtype=float32))],
#  'claim-648': [('‘there will not be enough nitrogen available to sustain the high carbon uptake scenarios.’',
#    'evidence-291276',
#    'Nitrogen is not readily available in soil because N, a gaseous form of nitrogen, is very stable and unavailable directly to higher plants.',
#    array([0.681265], dtype=float32))],
#  'claim-822': [('Climate policy must compete with other long-term threats for always-scarce resources.”',
#    'evidence-352226',
#    'resources.',
#    array([0.5], dtype=float32))],
#  'claim-2561': [('Observed sea levels are actually tracking at the upper range of the IPCC projections.',
#    'evidence-284557',
#    'In a statement of 29 October 2012 the IPCC clarified that the "prize was awarded to the IPCC as an organisation, and not to any individual involved with the IPCC.',
#    array([0.6972332], dtype=float32))],
#  'claim-2219': [('The increase in temperatures since 1975 is a consistent feature of all reconstructions.',
#    'evidence-548766',
#    'Due to the increase in temperature of the soil, CO2 levels in our atmosphere increase, and as such the mean average temperature of the Earth is rising.',
#    array([0.632987], dtype=float32))],
#  'claim-1343': [('roughly three-quarters of the tidal flood days now occurring in towns along the East Coast would not be happening in the absence of the rise in the sea level caused by human emissions.',
#    'evidence-667089',
#    'Increasingly, climate change is threatening human communities around the world in a variety of ways such as rising sea levels, increasingly frequent large storms, tidal surges and flooding damage.',
#    array([0.7289357], dtype=float32))],
#  'claim-1351': [('a marginally significant warming trend in the data over the past several years, erasing the temperature plateau that vexed climate alarmists have found difficult to explain.',
#    'evidence-1174955',
#    'In March 2015, he said that some people are "global warming alarmists" and, citing satellite temperature measurements, said that there had been no significant warming in 18 years.',
#    array([0.7191817], dtype=float32))],
#  'claim-2347': [('In truth, the overwhelming majority of climate-research funding comes from the federal government and left-wing foundations.',
#    'evidence-572553',
#    'It is funded by the state and federal governments.',
#    array([0.5], dtype=float32))],
#  'claim-293': [('When the measuring equipment gets old and needs replacing, it often requires re-calibration.',
#    'evidence-915220',
#    'Equipment.',
#    array([0.5], dtype=float32))],
#  'claim-910': [('The cement, iron and steel, and petroleum refining industries could see their production cut by 21% 19%, and 11% respectively.”',
#    'evidence-309027',
#    'Petroleum refining in the United States in 2013 produced 18.9 million barrels per day of refined petroleum products, more than any other country.',
#    array([0.72503346], dtype=float32))],
#  'claim-2815': [('A new peer-reviewed study on Surface Warming and the Solar Cycle found that times of high solar activity are on average 0.2°C warmer than times of low solar activity, and that there is a polar amplification of the warming.',
#    'evidence-700183',
#    'Given that records of solar activity are accurate, solar activity may have contributed to part of the modern warming that peaked in the 1930s, in addition to the 60-year temperature cycles that result in roughly 0.5\xa0°C of warming during the increasing temperature phase.',
#    array([0.725333], dtype=float32))],
#  'claim-1652': [('The strong CO2 effect has been observed by many different measurements.',
#    'evidence-668884',
#    'CO2).',
#    array([0.5], dtype=float32))],
#  'claim-1212': [('(In technical lingo, the so-called social cost of carbon would be negative.)”',
#    'evidence-162296',
#    'Lingo Livery Stable (which houses an Oregon Trail exhibit) and the newly built Lingo Tack Shop',
#    array([0.5], dtype=float32))]}

# %%
train_claim_dict = evidence_retrival(train_seqs1, train_seqs2, 50, train_claims, train_candidates)
# Out:
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 52s 165ms/step

# %%
# Add evidences predicted from computing the similarity directly without putting into the model
topk_sim = 4
dev_evidences_predict = [[t[1] for t in value] for key, value in dev_claim_dict.items()]
for id, v in dev_candidates.items():
    i = dev_ids.index(id)
    dev_evidences_predict[i].extend([evidence for evidence in v[:topk_sim] if evidence not in dev_evidences_predict[i]])

test_evidences_predict = [[t[1] for t in value] for key, value in test_claim_dict.items()]
for id, v in test_candidates.items():
    i = test_ids.index(id)
    test_evidences_predict[i].extend([evidence for evidence in v[:topk_sim] if evidence not in test_evidences_predict[i]])
print(test_evidences_predict)
# Out:
# [['evidence-308923', 'evidence-22107', 'evidence-213569', 'evidence-257116'], ['evidence-957389', 'evidence-178433', 'evidence-1077548', 'evidence-200293'], ['evidence-1200633', 'evidence-962481', 'evidence-776422', 'evidence-399454'], ['evidence-642301', 'evidence-161852', 'evidence-205895', 'evidence-670186'], ['evidence-834109', 'evidence-253763', 'evidence-851510', 'evidence-432221'], ['evidence-72690', 'evidence-506409', 'evidence-292357', 'evidence-695091'], ['evidence-828180', 'evidence-670186', 'evidence-323266', 'evidence-1183711', 'evidence-688029'], ['evidence-961837', 'evidence-1104813', 'evidence-822729', 'evidence-890095', 'evidence-213946'], ['evidence-51798', 'evidence-417371', 'evidence-403673', 'evidence-311208', 'evidence-57888'], ['evidence-1091739', 'evidence-37274', 'evidence-369911', 'evidence-1044935', 'evidence-448411'], ['evidence-12425', 'evidence-668884', 'evidence-578065', 'evidence-307967'], ['evidence-572332', 'evidence-661699', 'evidence-173055', 'evidence-946483', 'evidence-82903'], ['evidence-1122793', 'evidence-895046', 'evidence-277435', 'evidence-289014', 'evidence-348048'], ['evidence-348061', 'evidence-1074949', 'evidence-23786', 'evidence-322382', 'evidence-442571'], ['evidence-482300', 'evidence-105873', 'evidence-717237', 'evidence-31096'], ['evidence-668884', 'evidence-1005062', 'evidence-62228', 'evidence-38305'], ['evidence-526818', 'evidence-607214', 'evidence-1040995', 'evidence-483878'], ['evidence-889101', 'evidence-668884', 'evidence-979052', 'evidence-493616', 'evidence-335886'], ['evidence-709490', 'evidence-322303', 'evidence-381173', 'evidence-776286', 'evidence-916512'], ['evidence-1128272', 'evidence-417856', 'evidence-773242', 'evidence-425896'], ['evidence-693807', 'evidence-475376', 'evidence-529248', 'evidence-932031'], ['evidence-7898', 'evidence-1047253', 'evidence-760329', 'evidence-562979'], ['evidence-693067', 'evidence-1144825', 'evidence-960067', 'evidence-1166589', 'evidence-5044'], ['evidence-728670', 'evidence-836657', 'evidence-593512', 'evidence-243551', 'evidence-342232'], ['evidence-780092', 'evidence-968437', 'evidence-793815', 'evidence-1148869'], ['evidence-386428', 'evidence-685709', 'evidence-845045', 'evidence-489159'], ['evidence-945472', 'evidence-396425', 'evidence-226306', 'evidence-1145327'], ['evidence-1040612', 'evidence-173281', 'evidence-188525', 'evidence-1099491'], ['evidence-1008952', 'evidence-78884', 'evidence-494418', 'evidence-110839', 'evidence-206645'], ['evidence-572332', 'evidence-693063', 'evidence-56623', 'evidence-873593', 'evidence-348822'], ['evidence-128472', 'evidence-556196', 'evidence-1088556', 'evidence-1196923'], ['evidence-254529', 'evidence-489429', 'evidence-127142', 'evidence-366836', 'evidence-987493'], ['evidence-1172137', 'evidence-953997', 'evidence-694262', 'evidence-866495', 'evidence-801457'], ['evidence-34493', 'evidence-45714', 'evidence-574518', 'evidence-398722'], ['evidence-72528', 'evidence-903495', 'evidence-972046', 'evidence-1116015'], ['evidence-315990', 'evidence-988277', 'evidence-668284', 'evidence-189414', 'evidence-63254'], ['evidence-315033', 'evidence-513478', 'evidence-367687', 'evidence-403673', 'evidence-513415'], ['evidence-34759', 'evidence-1006052', 'evidence-368794', 'evidence-268112', 'evidence-915569'], ['evidence-1166652', 'evidence-107893', 'evidence-422407', 'evidence-474588', 'evidence-438175'], ['evidence-559069', 'evidence-360300', 'evidence-298127', 'evidence-1172097'], ['evidence-1076603', 'evidence-269246', 'evidence-576285', 'evidence-526112', 'evidence-1044216'], ['evidence-527316', 'evidence-329503', 'evidence-1023546', 'evidence-743151', 'evidence-395981'], ['evidence-402677', 'evidence-725190', 'evidence-974626', 'evidence-780416', 'evidence-412424'], ['evidence-250928', 'evidence-390114', 'evidence-474459', 'evidence-63839'], ['evidence-507814', 'evidence-652349', 'evidence-603887', 'evidence-877965'], ['evidence-725977', 'evidence-683138', 'evidence-973268', 'eviden ...

# %%
train_evidences_predict = [[t[1] for t in value] for key, value in train_claim_dict.items()]
for id, v in train_candidates.items():
    i = train_ids.index(id)
    train_evidences_predict[i].extend([evidence for evidence in v[:topk_sim] if evidence not in train_evidences_predict[i]])

# %%
max_num_evi = max([len(predicts) for predicts in dev_evidences_predict])
max_num_evi
# Out:
# 5

# %% [markdown]
# 2.6 Claim classification

# %%
# e.g. cls_transform(train_claim_texts, train_labels, train_evidences)
def cls_transform(claim_texts, labels, set_evidences, test=False):
    x = []
    y = []
    class_labels = {"SUPPORTS": 0, "REFUTES": 1, "NOT_ENOUGH_INFO": 2, "DISPUTED": 3}
    dataset = []
    for text in claim_texts:
        dataset_dict = {}
        index = claim_texts.index(text)
        if test == False:
            dataset_dict["label"] = class_labels[labels[index]]
        dataset_dict["text"] = "<sep>".join([text] + set_evidences[index])
        dataset.append(dataset_dict)
    for data in dataset:
        x.append(data["text"])
        if test == False:
            y.append(data["label"])
    return x, y

# %%
train_x, train_y = cls_transform(train_claim_texts, train_labels, train_evidences, test=False)
dev_x, dev_y = cls_transform(dev_claim_texts, dev_labels, dev_evidences_predict, test=False)
test_x, _ = cls_transform(test_claim_texts, [], test_evidences_predict, test=True)

# %%
print(collections.Counter(train_y))
print(collections.Counter(dev_y))
# Out:
# Counter({0: 518, 2: 388, 1: 198, 3: 124})
# Counter({0: 68, 2: 41, 1: 27, 3: 18})

# %%
tok_train_x = tokenize(train_x)
tok_dev_x = tokenize(dev_x)
tok_test_x = tokenize(test_x)
vocab2 = Vocab(tok_train_x)
print(list(vocab2.token_to_idx.items())[:10])
print(vocab2.__len__())
# Out:
# [('<unk>', 0), ('sep', 1), ('<', 2), ('>', 3), ('warm', 4), ('temperature', 5), ('climate', 6), ('global', 7), ('change', 8), ('increase', 9)]
# 8153

# %%
train_indlist = vocab2[tok_train_x]
dev_indlist = vocab2[tok_dev_x]
test_indlist = vocab2[tok_test_x]

# %%
train_indlist = keras.preprocessing.sequence.pad_sequences(train_indlist, padding="post")
dev_indlist = keras.preprocessing.sequence.pad_sequences(dev_indlist, padding="post")
test_indlist = keras.preprocessing.sequence.pad_sequences(test_indlist, padding="post")

# %%
seq_model2 = keras.Sequential([
    keras.layers.Embedding(input_dim=vocab2.__len__() + 1, output_dim=output_dim),
    keras.layers.Dropout(0.1),
    keras.layers.Bidirectional(keras.layers.LSTM(100, return_sequences=True, dropout=0.1)),
    keras.layers.Bidirectional(keras.layers.LSTM(100, dropout=0.1)),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dropout(0.1),
    keras.layers.Dense(4, activation='softmax')
])

seq_model2.compile(loss=keras.losses.SparseCategoricalCrossentropy(),
              optimizer=keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

# %%
seq_model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = seq_model2.fit(train_indlist, np.array(train_y), epochs=5, 
          validation_data=(dev_indlist, np.array(dev_y)))
dev_loss, dev_acc = seq_model2.evaluate(dev_indlist, np.array(dev_y))
print('Dev Loss:', dev_loss)
print('Dev Accuracy:', dev_acc)
# Out:
# Epoch 1/5
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 521ms/step - accuracy: 0.3692 - loss: 1.3571 - val_accuracy: 0.4416 - val_loss: 1.2755
# Epoch 2/5
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 20s 508ms/step - accuracy: 0.4145 - loss: 1.2628 - val_accuracy: 0.4416 - val_loss: 1.2756
# Epoch 3/5
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 578ms/step - accuracy: 0.4260 - loss: 1.2659 - val_accuracy: 0.4416 - val_loss: 1.2785
# Epoch 4/5
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 26s 653ms/step - accuracy: 0.4486 - loss: 1.2057 - val_accuracy: 0.4351 - val_loss: 1.5325
# Epoch 5/5
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 25s 641ms/step - accuracy: 0.6478 - loss: 0.9279 - val_accuracy: 0.4351 - val_loss: 1.7576
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4805 - loss: 1.6933
# Dev Loss: 1.7575798034667969
# Dev Accuracy: 0.4350649416446686

# %%
cls_predictions_dev = seq_model2.predict(dev_indlist)
cls_predictions_test = seq_model2.predict(test_indlist)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
cls_predictions_dev = cls_predictions_dev.tolist()
cls_predictions_test = cls_predictions_test.tolist()

# %%
# class_labels = {"SUPPORTS": 0, "REFUTES": 1, "NOT_ENOUGH_INFO": 2, "DISPUTED": 3}
final_dict_dev = {}
for prediction in cls_predictions_dev:
    order = cls_predictions_dev.index(prediction)
    max_value, max_index = max((value, index) for index, value in enumerate(prediction))
    if max_index == 0:
        final_dict_dev[dev_ids[order]] = {"claim_text": dev_claims[dev_ids[order]]["claim_text"], "claim_label": "SUPPORTS", "evidences": dev_evidences_predict[order]}
    elif max_index == 1:
        final_dict_dev[dev_ids[order]] = {"claim_text": dev_claims[dev_ids[order]]["claim_text"], "claim_label": "REFUTES", "evidences": dev_evidences_predict[order]}
    elif max_index == 2:
        final_dict_dev[dev_ids[order]] = {"claim_text": dev_claims[dev_ids[order]]["claim_text"], "claim_label": "NOT_ENOUGH_INFO", "evidences": dev_evidences_predict[order]}
    elif max_index == 3:
        final_dict_dev[dev_ids[order]] = {"claim_text": dev_claims[dev_ids[order]]["claim_text"], "claim_label": "DISPUTED", "evidences": dev_evidences_predict[order]}
final_dict_dev
# Out:
# {'claim-752': {'claim_text': '[South Australia] has the most expensive electricity in the world.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-421845',
#    'evidence-684667',
#    'evidence-554677',
#    'evidence-240255']},
#  'claim-375': {'claim_text': 'when 3 per cent of total annual global emissions of carbon dioxide are from humans and Australia prod\xaduces 1.3 per cent of this 3 per cent, then no amount of emissions reductio\xadn here will have any effect on global climate.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-402802',
#    'evidence-1140012',
#    'evidence-78654',
#    'evidence-839069']},
#  'claim-1266': {'claim_text': 'This means that the world is now 1C warmer than it was in pre-industrial times',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-694262',
#    'evidence-937622',
#    'evidence-100779',
#    'evidence-38305']},
#  'claim-871': {'claim_text': '“As it happens, Zika may also be a good model of the second worrying effect — disease mutation.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-336512',
#    'evidence-472751',
#    'evidence-617077',
#    'evidence-9054']},
#  'claim-2164': {'claim_text': 'Greenland has only lost a tiny fraction of its ice mass',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1200633',
#    'evidence-962481',
#    'evidence-776422',
#    'evidence-399454']},
#  'claim-1607': {'claim_text': "CO2 limits won't cool the planet.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-668884',
#    'evidence-1079843',
#    'evidence-247680',
#    'evidence-634493']},
#  'claim-761': {'claim_text': '[Riebesell] is a world authority on the topic and has typically communicated cautiously about the effects of acidification.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-868602',
#    'evidence-687210',
#    'evidence-108363',
#    'evidence-828180']},
#  'claim-1718': {'claim_text': 'The actual data show high northern latitudes are warmer today than in 1940.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-945644',
#    'evidence-1104838',
#    'evidence-459999',
#    'evidence-802686']},
#  'claim-1273': {'claim_text': 'The rapid changes in the climate may have profound consequences for humans and other species… Severe drought caused food shortages for millions of people in Ethiopia, with a lack of rainfall resulting in “intense and widespread” forest fires in Indonesia that belched out a vast quantity of greenhouse gas',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-236252',
#    'evidence-107843',
#    'evidence-895576',
#    'evidence-658407',
#    'evidence-789848']},
#  'claim-1786': {'claim_text': 'CFCs contribute to global waerming at a small level.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-231901',
#    'evidence-752246',
#    'evidence-928190',
#    'evidence-446603']},
#  'claim-2796': {'claim_text': 'Had he used the currently accepted value of approximately 3°C warming for a doubling of atmospheric CO2, Hansen would have correctly projected the ensuing global warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-206486',
#    'evidence-247680',
#    'evidence-21628',
#    'evidence-403673',
#    'evidence-447328']},
#  'claim-2580': {'claim_text': 'Volcanoes emit around 0.3 billion tonnes of CO2 per year.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-425667',
#    'evidence-208053',
#    'evidence-67343',
#    'evidence-668884']},
#  'claim-1219': {'claim_text': 'Global warming is driving major melting on the surface of Greenland’s glaciers and is speeding up their travel into the sea.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1088478',
#    'evidence-797505',
#    'evidence-118577',
#    'evidence-1040612']},
#  'claim-75': {'claim_text': 'The science is clear, climate change is making extreme weather events, including tornadoes, worse.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-566907',
#    'evidence-421870',
#    'evidence-93223',
#    'evidence-1186875',
#    'evidence-113679']},
#  'claim-2813': {'claim_text': 'In fact, the authors go on to estimate climate sensitivity from their findings, calculate a value between 2.3 to 4.1°C.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-75407',
#    'evidence-320029',
#    'evidence-700426',
#    'evidence-494418',
#    'evidence-577698']},
#  'claim-2335': {'claim_text': 'Satellite measurements of infrared spectra over the past 40 years observe less energy escaping to space at the wavelengths associated with CO2.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-489609',
#    'evidence-442589',
#    'evidence-668884',
#    'evidence-1149425',
#    'evidence-511610']},
#  'claim-161': {'claim_text': 'Extreme melting and changes to the climate like this has released pressure on to the continent, allowing the ground to rise up.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-169769',
#    'evidence-72690',
#    'evidence-1034813',
#    'evidence-242363']},
#  'claim-2243': {'claim_text': 'The CO2 amplifies the warming and mixes through the atmosphere, spreading warming throughout the planet.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-991415',
#    'evidence-247680',
#    'evidence-21628',
#    'evidence-29528',
#    'evidence-493211']},
#  'claim-1256': {'claim_text': '‘Next year or the year after, the Arctic will be free of ice’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-111881',
#    'evidence-1136104',
#    'evidence-192938',
#    'evidence-1150857']},
#  'claim-506': {'claim_text': 'More than 100 climate models over the past 30 years did not predict what actually happened because it was assumed carbon dioxide had the pivotal role in driving climate change and that the effects of clouds, back-radiation and the sun were trivial.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-222883',
#    'evidence-1199931',
#    'evidence-100394',
#    'evidence-776286',
#    'evidence-72690']},
#  'claim-369': {'claim_text': 'By 2050 there’s a scientific consensus that we reached the tipping point for ice sheets in Greenland and the West Antarctic',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-892023',
#    'evidence-1020001',
#    'evidence-283135',
#    'evidence-411817',
#    'evidence-571920']},
#  'claim-2184': {'claim_text': 'We have had ice ages and warmer periods when alligators were found in Spitzbergen.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-469323',
#    'evidence-1058575',
#    'evidence-213076',
#    'evidence-229004']},
#  'claim-1057': {'claim_text': '“Moreover, the ocean already contains so-called oxygen minimum zones, generally found in the middle depths.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-75640',
#    'evidence-69294',
#    'evidence-1174820',
#    'evidence-986203']},
#  'claim-104': {'claim_text': 'Increases in atmospheric CO2 followed increases in temperature.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-548766',
#    'evidence-66273',
#    'evidence-493616',
#    'evidence-382866']},
#  'claim-1975': {'claim_text': 'The claim that 97 percent of scientists believe humans are causing climate change has been debunked by the "head" of the United Nations Intergovernmental Panel on Climate Change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-107836',
#    'evidence-72690',
#    'evidence-918989',
#    'evidence-438173',
#    'evidence-979538']},
#  'claim-139': {'claim_text': 'And in January, one out of five British children told pollsters they were having nightmares about climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1072657',
#    'evidence-757581',
#    'evidence-298597',
#    'evidence-72690']},
#  'claim-2062': {'claim_text': 'Global warming is increasing the magnitude and frequency of droughts and floods.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-744317',
#    'evidence-11661',
#    'evidence-884516',
#    'evidence-268112']},
#  'claim-1160': {'claim_text': 'With more CO2 in the atmosphere, the challenge [feeding 2.5 billion more people] can and will be met.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-32852',
#    'evidence-668884',
#    'evidence-985452',
#    'evidence-173055',
#    'evidence-406857']},
#  'claim-2679': {'claim_text': '"The solubility of carbon dioxide in water is listed in the Handbook of Chemistry and Physics as a declining function of temperature. ...',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-445095',
#    'evidence-826839',
#    'evidence-393408',
#    'evidence-731175',
#    'evidence-411794']},
#  'claim-2662': {'claim_text': '"...there is the contention by Wolfgang Knorr of the Department of Earth Sciences at the University of Bristol in England that carbon dioxide levels in the atmosphere are about where they were 160 years ago." (as quoted by Ken Ward Jr.)',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-572332',
#    'evidence-889119',
#    'evidence-946483',
#    'evidence-82903']},
#  'claim-1490': {'claim_text': 'the concentration of carbon dioxide in Earth’s atmosphere has climbed to a level last seen more than 3 million years ago — before humans even appeared on the rocky ball we call home.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-572332',
#    'evidence-551522',
#    'evidence-1153298',
#    'evidence-889119']},
#  'claim-2768': {'claim_text': 'The long term trend from albedo is that of cooling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-367687',
#    'evidence-352954',
#    'evidence-1131955',
#    'evidence-893127']},
#  'claim-2168': {'claim_text': 'IPCC graph showing accelerating trends is misleading',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-203134',
#    'evidence-870125',
#    'evidence-367687',
#    'evidence-5337']},
#  'claim-785': {'claim_text': 'In many other cases, though — hurricanes, for example — the linkage to global warming for particular trends is uncertain or disputed.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-519752',
#    'evidence-415989',
#    'evidence-367687',
#    'evidence-403673',
#    'evidence-496023']},
#  'claim-2426': {'claim_text': '"Twentieth century global warming did not start until  1910.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-354405',
#    'evidence-403673',
#    'evidence-57888',
#    'evidence-386149']},
#  'claim-1292': {'claim_text': 'Any reasonable person can recognize both positives and negatives among the policy proposals of both Tories and Labour.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-981832',
#    'evidence-67889',
#    'evidence-104688',
#    'evidence-726883',
#    'evidence-852941']},
#  'claim-993': {'claim_text': 'While there has been a mean rise of a little more than 3mm per year worldwide since the 1990s, in the last decade, the NOAA Virginia Key tide gauge just south of Miami Beach has measured a 9mm rise annually.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-779703',
#    'evidence-594365',
#    'evidence-314342',
#    'evidence-470669',
#    'evidence-1108581']},
#  'claim-2593': {'claim_text': '[T]he study indicates “Greenland’s ice may be less susceptible to the massive meltdown predicted by computer models of climate change, the main author ... said in an interview. ...',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-483852',
#    'evidence-947243',
#    'evidence-830717',
#    'evidence-242556']},
#  'claim-1567': {'claim_text': 'IPCC overestimate temperature rise.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-744246',
#    'evidence-658225',
#    'evidence-950248',
#    'evidence-284557']},
#  'claim-1834': {'claim_text': 'A 14 August 1912 article from a New Zealand newspaper contained a brief story about how burning coal might produce future warming by adding carbon dioxide to the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-855683',
#    'evidence-173323',
#    'evidence-946483',
#    'evidence-572332']},
#  'claim-856': {'claim_text': 'as the pathbreaking work by Rosamond Naylor and David Battisti has shown, the tropics are already too hot to efficiently grow grain, and those places where grain is produced today are already at optimal growing temperature — which means even a small warming will push them down the slope of declining productivity.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-12277',
#    'evidence-1076795',
#    'evidence-308523',
#    'evidence-898579']},
#  'claim-540': {'claim_text': 'The heatwave we now have in Europe is not something that was expected with just 1C of warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-698828',
#    'evidence-594449',
#    'evidence-1048366',
#    'evidence-313382']},
#  'claim-757': {'claim_text': 'The grasslands, crops, forests and territorial waters of Australia absorb more carbon dioxide than Australia emits.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-977413',
#    'evidence-748871',
#    'evidence-14364',
#    'evidence-744771']},
#  'claim-1407': {'claim_text': '“In their award winning book, ‘Taken By Storm’ (2007), Canadian researchers Christopher Essex and Ross McKitrick explain: ‘Temperature is not an amount of something [like height or weight].',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-241467',
#    'evidence-594449',
#    'evidence-803272',
#    'evidence-292040',
#    'evidence-599222']},
#  'claim-3070': {'claim_text': 'So this is a government which is proposing to put at risk our manufacturing industry, to penalise struggling families, to make a tough situation worse for millions of households right around Australia.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1097109',
#    'evidence-149691',
#    'evidence-996206',
#    'evidence-1158798']},
#  'claim-1745': {'claim_text': 'The IPCC simply updated their temperature history graphs to show the best data available at the time.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-949961',
#    'evidence-45045',
#    'evidence-870125',
#    'evidence-1089880']},
#  'claim-1515': {'claim_text': 'no one really knows if last year 2016 was a global temperature record.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-842114',
#    'evidence-603115',
#    'evidence-64048',
#    'evidence-898202']},
#  'claim-1519': {'claim_text': 'The Earth’s climate is changing in response to increasing concentrations of greenhouse gases (GHGs) and particulate matter in the atmosphere, largely as the result of human activities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1113206',
#    'evidence-338219',
#    'evidence-87345',
#    'evidence-90017',
#    'evidence-683927']},
#  'claim-3069': {'claim_text': 'Continued greenhouse gas emissions at or above current rates would cause further warming and induce many changes in the global climate system during the 21st century that would very likely be larger than those observed during the 20th century.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1072231',
#    'evidence-36994',
#    'evidence-259826',
#    'evidence-939303',
#    'evidence-957593']},
#  'claim-677': {'claim_text': '“Which is to say that these beans will be eaten by cows, and the cows will convert the beans to meat, and the humans will eat the meat.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-425813',
#    'evidence-15885',
#    'evidence-2791',
#    'evidence-474026']},
#  'claim-765': {'claim_text': 'The broader term covers changes beyond warmer temperatures, such as shifting rainfall patterns.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-315589',
#    'evidence-998774',
#    'evidence-496267',
#    'evidence-325870']},
#  'claim-2275': {'claim_text': '[…] Constant 24-7  media coverage of every significant storm worldwide just makes it seem  that way.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-177696',
#    'evidence-468059',
#    'evidence-882874',
#    'evidence-1076900',
#    'evidence-384379']},
#  'claim-1113': {'claim_text': 'This means the jet stream meanders more, with big loops bringing warm air to the frozen north and cold air into warmer southern climes.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-818829',
#    'evidence-459315',
#    'evidence-46734',
#    'evidence-991759']},
#  'claim-2611': {'claim_text': 'The final amount of extra CO2 that remains in the atmosphere stays there on a time scale of centuries.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-662931',
#    'evidence-668884',
#    'evidence-1050099',
#    'evidence-36206',
#    'evidence-922269']},
#  'claim-2060': {'claim_text': 'Global warming is causing more hurricanes and stronger hurricanes.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-986235',
#    'evidence-235887',
#    'evidence-323280',
#    'evidence-302241']},
#  'claim-2326': {'claim_text': '"In 2007, the Northern Hemisphere reached a record low in ice coverage and the Northwest Passage was opened.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1055581',
#    'evidence-357997',
#    'evidence-118071',
#    'evidence-956029',
#    'evidence-773103']},
#  'claim-1087': {'claim_text': 'The particular signature of warming in 2016 was also revealing in another way, Overpeck said, noting that the stratosphere… saw record cold temperatures last year',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-262130',
#    'evidence-789440',
#    'evidence-918733',
#    'evidence-475775',
#    'evidence-660476']},
#  'claim-2867': {'claim_text': "Skeptics who oppose scientific findings that threaten their world view are far closer to Galileo's belief-based critics in the Catholic Church.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-626622',
#    'evidence-913019',
#    'evidence-976029',
#    'evidence-856227']},
#  'claim-2300': {'claim_text': '"Austria is today seeing its earliest snowfall in history with 30 to 40 centimetres already predicted in the mountains.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1053558',
#    'evidence-432475',
#    'evidence-967332',
#    'evidence-776430']},
#  'claim-2250': {'claim_text': "Some global warming 'skeptics' argue that the Earth's climate sensitivity is so low that a doubling of atmospheric CO2 will result in a surface temperature change on the order of 1°C or less, and that therefore global warming is nothing to worry about.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-51798',
#    'evidence-417371',
#    'evidence-268112',
#    'evidence-403673',
#    'evidence-368794']},
#  'claim-2429': {'claim_text': 'With 32 years of  rapidly increasing global temperatures and only a minor increase in  global CO2 emissions, followed by 33 years of slowly cooling global  temperatures with rapid increases in global CO2 emissions, it was  deceitful for the IPCC to make any claim that CO2 emissions were  primarily responsible for observed 20th century global warming."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-764373',
#    'evidence-268112',
#    'evidence-98914',
#    'evidence-272735']},
#  'claim-3051': {'claim_text': 'Once natural influences, in particular the impact of El Niño and La Niña, are removed from the recent termperature record, there is no evidence of a significant change in the human contribution to climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1188266',
#    'evidence-975177',
#    'evidence-1088730',
#    'evidence-1081418',
#    'evidence-253691']},
#  'claim-1549': {'claim_text': "There's no empirical evidence for climate change.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-352745',
#    'evidence-72690',
#    'evidence-702736',
#    'evidence-894450']},
#  'claim-261': {'claim_text': 'in 1995 one scientist at the IPCC – Jonathan Overpeck – wrote an email to a colleague claiming ‘we have to get rid of the Medieval Warm Period.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-790948',
#    'evidence-320887',
#    'evidence-789440',
#    'evidence-1205335']},
#  'claim-2230': {'claim_text': '[Ice] is expanding in much of Antarctica, contrary to the widespread public belief that global warming is melting the continental ice cap.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-118577',
#    'evidence-1088478',
#    'evidence-1192872',
#    'evidence-728645',
#    'evidence-797505']},
#  'claim-2579': {'claim_text': 'Over the past 250 years, humans have added just one part of CO2 in 10,000 to the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1153657',
#    'evidence-668884',
#    'evidence-752115',
#    'evidence-662931',
#    'evidence-156413']},
#  'claim-1416': {'claim_text': 'In recent decades this warming has been accompanied by a constant rise in the sea level and, it would appear, by an increase of extreme weather events, even if a scientifically determinable cause cannot be assigned to each particular phenomenon.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-298450',
#    'evidence-1160292',
#    'evidence-1065735',
#    'evidence-68691',
#    'evidence-408089']},
#  'claim-2497': {'claim_text': "Without the forests' humidity, previously moisture-laden winds blew dry.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1051806',
#    'evidence-952597',
#    'evidence-168050',
#    'evidence-117389']},
#  'claim-811': {'claim_text': 'But [climate scientists] say that aspects of the case of Hurricane Harvey—and the recent history of tropical cyclones worldwide—suggest global warming is making a bad situation worse.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-604477',
#    'evidence-917625',
#    'evidence-752896',
#    'evidence-344540']},
#  'claim-1896': {'claim_text': 'Greg Hunt CSIRO research shows carbon emissions can be reduced by 20 per cent over 40 years using nature, soils and trees.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-851919',
#    'evidence-1140012',
#    'evidence-402802',
#    'evidence-79910',
#    'evidence-649250']},
#  'claim-2819': {'claim_text': 'More importantly, the OISM list only contains 39 scientists who specialise in climate science.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-12467',
#    'evidence-124062',
#    'evidence-42757',
#    'evidence-880742',
#    'evidence-886881']},
#  'claim-2643': {'claim_text': 'The "decline" refers to a decline in northern tree-rings, not global temperature, and is openly discussed in papers and the IPCC reports.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-224185',
#    'evidence-152765',
#    'evidence-494273',
#    'evidence-753102']},
#  'claim-1775': {'claim_text': 'Venus very likely underwent a runaway or ‘moist’ greenhouse phase earlier in its history, and today is kept hot by a dense CO2 atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-175982',
#    'evidence-791159',
#    'evidence-1018829',
#    'evidence-668884']},
#  'claim-316': {'claim_text': 'the models predicted seven times as much warming as has been observed',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-483852',
#    'evidence-1040115',
#    'evidence-928328',
#    'evidence-1127656']},
#  'claim-896': {'claim_text': 'According to the WHO, exposure to particulate matter increases the risk of acute lower respiratory infection, chronic obstructive pulmonary disease, heart disease, stroke and lung cancer.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-12306',
#    'evidence-416776',
#    'evidence-534239',
#    'evidence-600182',
#    'evidence-440442']},
#  'claim-331': {'claim_text': 'But each serial adjustment has tended to make the early years colder, which increases the warming trend.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-598663',
#    'evidence-367687',
#    'evidence-861649',
#    'evidence-436729',
#    'evidence-513415']},
#  'claim-2574': {'claim_text': 'On a world scale coral reefs are in decline.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-580567',
#    'evidence-1161994',
#    'evidence-205895',
#    'evidence-670186']},
#  'claim-342': {'claim_text': 'While members of the media may nod along to such claims [about changes in weather extremes], the evidence paints a different story',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-315751',
#    'evidence-488357',
#    'evidence-882689',
#    'evidence-1051137']},
#  'claim-2034': {'claim_text': 'Latest IPCC Reports (AR5) have shown global mean temperature forecasts from the 2005 IPCC report exceeded actual readings.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-354829',
#    'evidence-1060242',
#    'evidence-64378',
#    'evidence-1033370']},
#  'claim-578': {'claim_text': '‘If we do nothing to reduce our greenhouse gas emissions, the kind of extreme heat we saw this past summer will be the norm when my young son is a grown man.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-347614',
#    'evidence-1147532',
#    'evidence-457839',
#    'evidence-5044',
#    'evidence-1118112']},
#  'claim-976': {'claim_text': 'The gas builds up in the soil, forming mounds called ‘pingoes.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-45761',
#    'evidence-57254',
#    'evidence-698942',
#    'evidence-578726']},
#  'claim-1097': {'claim_text': '“[…]The impact on calcification, metabolism, growth, fertility and survival of calcifying marine species when pH is lowered up to 0.3 units […] is beneficial, not damaging.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-61132',
#    'evidence-895158',
#    'evidence-1075985',
#    'evidence-196811']},
#  'claim-609': {'claim_text': 'That’s because as Antarctica’s mass shrinks, the ice sheet’s gravitational pull on the ocean relaxes somewhat, and the seas travel back across the globe to pile up far away — with U.S. coasts being one prime destination.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1200633',
#    'evidence-1044474',
#    'evidence-93169',
#    'evidence-702708']},
#  'claim-173': {'claim_text': 'If there were [carbon emissions], we could not see because most carbon is black.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1091994',
#    'evidence-411018',
#    'evidence-798295',
#    'evidence-831442']},
#  'claim-1222': {'claim_text': 'The melting Greenland ice sheet is already a major contributor to rising sea level and if it was eventually lost entirely, the oceans would rise by six metres around the world, flooding many of the world’s largest cities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-7473',
#    'evidence-173281',
#    'evidence-1040612',
#    'evidence-808139']},
#  'claim-2441': {'claim_text': 'Furthermore, it is physically incorrect to state that the planet is simply "recovering" from the Little Ice Age.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1181162',
#    'evidence-461050',
#    'evidence-233437',
#    'evidence-409966',
#    'evidence-626258']},
#  'claim-756': {'claim_text': 'Australia’s signed a suicide note [with the Paris Accord] yet didn’t seem to notice that China, India, Indonesia and the US did not commit to reducing their large carbon dioxide emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-693067',
#    'evidence-1146875',
#    'evidence-832604',
#    'evidence-901598',
#    'evidence-79910']},
#  'claim-2577': {'claim_text': '"Three recent articles give us reason to question the alarmists’ claims  that coral reefs are in deep trouble due to the buildup of greenhouse  gases." (World Climate Report)',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-716355',
#    'evidence-1161994',
#    'evidence-205895',
#    'evidence-850174',
#    'evidence-670186']},
#  'claim-2890': {'claim_text': 'Heat is continuing to build up in the subsurface ocean.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1144500',
#    'evidence-142817',
#    'evidence-744635',
#    'evidence-297323']},
#  'claim-2478': {'claim_text': '(Kerr 2007) points out that the sunlight-reflecting haze that cools much of the planet seems to have thinned over the past decade or so.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1016598',
#    'evidence-94145',
#    'evidence-799025',
#    'evidence-822464']},
#  'claim-2399': {'claim_text': 'While the greenhouse effect is a natural occurence, too much warming has severe negative impacts on agriculture, health and environment.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-465048',
#    'evidence-378292',
#    'evidence-886906',
#    'evidence-807379',
#    'evidence-1122962']},
#  'claim-3091': {'claim_text': 'Global Warming history completely coincides with the history of artificial satellites and the use of microwave frequencies from outer space.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-234550',
#    'evidence-520355',
#    'evidence-396323',
#    'evidence-462309',
#    'evidence-719923']},
#  'claim-141': {'claim_text': 'Greenpeace didn’t save the whales, switching from whale oil to petroleum and palm oil did',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-889004',
#    'evidence-825791',
#    'evidence-117612',
#    'evidence-905673']},
#  'claim-1933': {'claim_text': 'Newt Gingrich "teamed with Nancy Pelosi and Al Gore on global warming."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-423215',
#    'evidence-804264',
#    'evidence-574489',
#    'evidence-562327']},
#  'claim-1689': {'claim_text': 'Evidence is building that net cloud feedback is likely positive and unlikely to be strongly negative.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1023925',
#    'evidence-208863',
#    'evidence-1106565',
#    'evidence-881780',
#    'evidence-1202569']},
#  'claim-443': {'claim_text': '“Today climate scientists are obsessed with the level of carbon dioxide in the atmosphere, a very very small part of the overall picture.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1153298',
#    'evidence-946483',
#    'evidence-82903',
#    'evidence-572332',
#    'evidence-56623']},
#  'claim-2037': {'claim_text': 'The rate of renewable energy installations in the EU in 2018 was less than half the maximum level achieved in 2010.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-868516',
#    'evidence-363747',
#    'evidence-45069',
#    'evidence-489429',
#    'evidence-164038']},
#  'claim-1734': {'claim_text': 'Jim Hansen had several possible scenarios; his mid-level scenario B was right.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-901245',
#    'evidence-755597',
#    'evidence-820593',
#    'evidence-14006']},
#  'claim-2093': {'claim_text': 'Through its impacts on the climate, CO2 presents a danger to public health and welfare, and thus qualifies as an air pollutant',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-716299',
#    'evidence-668884',
#    'evidence-637628',
#    'evidence-1107977',
#    'evidence-1193645']},
#  'claim-1400': {'claim_text': 'The late 1970s marked the end of a 30-year cooling trend.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-233764',
#    'evidence-367687',
#    'evidence-893127',
#    'evidence-513415']},
#  'claim-1638': {'claim_text': 'Worry about global warming impacts in the next 100 years, not an ice age in over 10,000 years.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-842114',
#    'evidence-461050',
#    'evidence-51798',
#    'evidence-920909',
#    'evidence-15429']},
#  'claim-3075': {'claim_text': "Multiple lines of evidence indicate Greenland's ice loss is accelerating and will contribute sea level rise in the order of metres over the next few centuries.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1056186',
#    'evidence-820522',
#    'evidence-1040612',
#    'evidence-630900',
#    'evidence-59240']},
#  'claim-38': {'claim_text': 'Scientists studying Antarctica sea ice warn a rise in accumulation could spark the next ice age.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1052064',
#    'evidence-869213',
#    'evidence-597766',
#    'evidence-915752',
#    'evidence-1043067']},
#  'claim-1643': {'claim_text': "Al Gore's book is quite accurate, and far more accurate than contrarian books.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-702249',
#    'evidence-682398',
#    'evidence-530425',
#    'evidence-935494']},
#  'claim-1259': {'claim_text': 'While the north-east, midwest and upper great plains have experienced a 30% increase in heavy rainfall episodes – considered once-in-every-five year downpours – parts of the west, particularly California, have been parched by drought.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-393334',
#    'evidence-926240',
#    'evidence-228018',
#    'evidence-887288']},
#  'claim-1605': {'claim_text': 'Scientists retracted claim that sea levels are rising.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-988277',
#    'evidence-630900',
#    'evidence-93169',
#    'evidence-894712']},
#  'claim-1711': {'claim_text': "Global warming' and 'climate change' mean different things and have both been used for decades.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1055133',
#    'evidence-59188',
#    'evidence-292357',
#    'evidence-695091',
#    'evidence-779966']},
#  'claim-2236': {'claim_text': 'The majority of peer reviewed research at the time predicted warming due to increasing CO2.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-66273',
#    'evidence-247680',
#    'evidence-668884',
#    'evidence-493616',
#    'evidence-178206']},
#  'claim-1040': {'claim_text': 'While evidence that the earth’s orbital variations impact radiation levels and thus global temperatures does not of course mean that man is not in some way impacting the climate, studies like these highlight that the role man plays on the planet is dwarfed by natural phenomena utterly out of our control.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1137996',
#    'evidence-180997',
#    'evidence-912955',
#    'evidence-949470']},
#  'claim-392': {'claim_text': 'a study that totally debunks the whole concept of man-made Global Warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-467952',
#    'evidence-874622',
#    'evidence-521030',
#    'evidence-1111305']},
#  'claim-368': {'claim_text': 'The most recent IPCC report lays out a future if we limit global heating to 1.5°C instead of the Paris Agreement’s 2°C.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1004397',
#    'evidence-828546',
#    'evidence-924647',
#    'evidence-76487',
#    'evidence-400626']},
#  'claim-559': {'claim_text': 'And there is a lot of evidence that climate change is diminishing biodiversity, which can be seen in these alpine meadows as well.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-702736',
#    'evidence-1047048',
#    'evidence-1020506',
#    'evidence-379897',
#    'evidence-72690']},
#  'claim-2583': {'claim_text': '"Each unit of CO2 you put into the atmosphere has less and less of a warming impact.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-247680',
#    'evidence-1184683',
#    'evidence-668884',
#    'evidence-954785']},
#  'claim-2609': {'claim_text': 'Individual carbon dioxide molecules have a short life time of around 5 years in the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-475329',
#    'evidence-946483',
#    'evidence-82903',
#    'evidence-572332',
#    'evidence-56623']},
#  'claim-492': {'claim_text': 'But like most claims regarding global warming, the real effect is small, probably temporary, and most likely due to natural weather patterns',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-626239',
#    'evidence-1187712',
#    'evidence-546948',
#    'evidence-886906']},
#  'claim-1420': {'claim_text': 'Concentrated in the atmosphere, these gases do not allow the warmth of the sun’s rays reflected by the earth to be dispersed in space.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-698104',
#    'evidence-613972',
#    'evidence-889119',
#    'evidence-857025',
#    'evidence-913623']},
#  'claim-1089': {'claim_text': 'Last year’s warmth was manifested across the planet, from the warm tropical ocean waters off the coast of northeastern Australia, where the Great Barrier Reef experienced its worst coral bleaching event on record and large scale coral death, to the Arctic, where sea ice hit regular monthly record lows and overall temperatures were also the warmest on record, at least from January through September 2016.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1150203',
#    'evidence-1183711',
#    'evidence-670186',
#    'evidence-408859',
#    'evidence-386915']},
#  'claim-1467': {'claim_text': 'The amount of carbon dioxide absorbed by the upper layer of the oceans is increasing by about 2 billion tons per year.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-488727',
#    'evidence-425667',
#    'evidence-352796',
#    'evidence-100394']},
#  'claim-444': {'claim_text': 'Carbon dioxide is a trace gas.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-889119',
#    'evidence-21184',
#    'evidence-409517',
#    'evidence-742111']},
#  'claim-803': {'claim_text': 'The team of climate scientists notes that in failing to predict the warming ‘hiatus’ in the beginning of the 21st century, the Intergovernmental Panel on Climate Change (IPCC) models overestimated temperature increases…',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-968233',
#    'evidence-918989',
#    'evidence-465117',
#    'evidence-230078']},
#  'claim-1668': {'claim_text': 'Thick arctic sea ice is in rapid retreat.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1181544',
#    'evidence-1034941',
#    'evidence-869213',
#    'evidence-192938']},
#  'claim-742': {'claim_text': 'Global human emissions are only 3 per cent of total annual emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1144825',
#    'evidence-329503',
#    'evidence-1023546',
#    'evidence-631053',
#    'evidence-1166589']},
#  'claim-846': {'claim_text': 'In other words, we have, trapped in Arctic permafrost, twice as much carbon as is currently wrecking the atmosphere of the planet, all of it scheduled to be released at a date that keeps getting moved up, partially in the form of a gas that multiplies its warming power 86 times over.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-867263',
#    'evidence-248795',
#    'evidence-626991',
#    'evidence-94074',
#    'evidence-409873']},
#  'claim-2119': {'claim_text': 'Lindzen and Choi find low climate sensitivity',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-494418',
#    'evidence-1176011',
#    'evidence-127999',
#    'evidence-750559']},
#  'claim-1167': {'claim_text': 'Lake-bottom sediments in Florida tell us that recent major hurricane activity in the Gulf of Mexico has been less frequent than in centuries past.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-512318',
#    'evidence-1150262',
#    'evidence-280914',
#    'evidence-709729']},
#  'claim-623': {'claim_text': 'The noted oceanographer Walter Munk referred to sea-level rise as an “enigma”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-446509',
#    'evidence-451718',
#    'evidence-538528',
#    'evidence-1192617']},
#  'claim-2882': {'claim_text': 'Trenberth\'s views are clarified in the paper "An imperative for climate change planning: tracking Earth\'s global energy".',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-520753',
#    'evidence-363958',
#    'evidence-724005',
#    'evidence-1034813',
#    'evidence-760691']},
#  'claim-1698': {'claim_text': 'Around 97% of climate experts agree that humans are causing global warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-503460',
#    'evidence-600618',
#    'evidence-1086865',
#    'evidence-793124']},
#  'claim-181': {'claim_text': 'Reefs need carbon dioxide; it’s their basic food.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-84444',
#    'evidence-475329',
#    'evidence-641208',
#    'evidence-56623']},
#  'claim-281': {'claim_text': 'In an interview with the BBC after the scandal broke, Dr Jones admitted there had been no statistically significant global warming since 1995',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1160759',
#    'evidence-222306',
#    'evidence-826177',
#    'evidence-712356']},
#  'claim-2809': {'claim_text': 'The motions of the massive oceans where heat is moved between deep layers and the surface provides variability on time scales from years to centuries.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-875252',
#    'evidence-9480',
#    'evidence-478812',
#    'evidence-762946',
#    'evidence-1010647']},
#  'claim-1928': {'claim_text': 'NASA Finds Antarctica is Gaining Ice,',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-529248',
#    'evidence-189793',
#    'evidence-419029',
#    'evidence-323436']},
#  'claim-2787': {'claim_text': "Hansen's 1988 results are evidence that the actual climate sensitivity is about 3°C for a doubling of atmospheric CO2.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-66273',
#    'evidence-494418',
#    'evidence-668884',
#    'evidence-158204']},
#  'claim-478': {'claim_text': 'Protecting and restoring forests would reduce 18% of emissions by 2030',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-328157',
#    'evidence-773242',
#    'evidence-837089',
#    'evidence-227800']},
#  'claim-988': {'claim_text': 'The unlikely scenarios are now, all of a sudden, becoming more probable than they once were thought to be,’ says Sweet.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-200360',
#    'evidence-623095',
#    'evidence-725565',
#    'evidence-203844']},
#  'claim-266': {'claim_text': 'The IPCC no longer includes the ‘Hockey stick’ chart in its reports.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1033370',
#    'evidence-794055',
#    'evidence-906065',
#    'evidence-1060242']},
#  'claim-2282': {'claim_text': 'While there are isolated cases of growing glaciers, the overwhelming trend in glaciers worldwide is retreat.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-848882',
#    'evidence-271778',
#    'evidence-1118685',
#    'evidence-909612']},
#  'claim-2895': {'claim_text': 'The latest  measurements involve the use of satellite gravimetry, estimating  the mass of terrain beneath by detecting slight changes in gravity as a  satellite passes overhead.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-812408',
#    'evidence-1112245',
#    'evidence-941196',
#    'evidence-371380',
#    'evidence-478347']},
#  'claim-349': {'claim_text': 'Nor is there evidence of an increase in floods globally.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-362138',
#    'evidence-688827',
#    'evidence-476824',
#    'evidence-244058']},
#  'claim-2101': {'claim_text': 'Clouds provide negative feedback',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-486549',
#    'evidence-666837',
#    'evidence-208863',
#    'evidence-1106565']},
#  'claim-897': {'claim_text': 'The report […] found that the United States was one of the most pollution-free nations in the world.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-301357',
#    'evidence-1006425',
#    'evidence-969926',
#    'evidence-780081']},
#  'claim-3063': {'claim_text': "'Another global warming myth comes crashing down.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-403673',
#    'evidence-57888',
#    'evidence-35625',
#    'evidence-330314']},
#  'claim-386': {'claim_text': 'Renew\xadables such as wind turbines are environmentally disastrous because they pollute a huge land area, slice and dice birds and bats, kill insects that are bird food, create health problems for humans who live within kilometres of them, leave toxins around the turbine site and despoil the landscape.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1088059',
#    'evidence-693024',
#    'evidence-763336',
#    'evidence-285002']},
#  'claim-2691': {'claim_text': "There are a myriad of other radiative forcings that affect the planet's energy imbalance.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1074121',
#    'evidence-230286',
#    'evidence-990446',
#    'evidence-374021']},
#  'claim-530': {'claim_text': 'South Australia is winning: it has the most unreliable grid in the world outside Africa and the most expensive electricity.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1113231',
#    'evidence-614037',
#    'evidence-1114895',
#    'evidence-478809']},
#  'claim-2979': {'claim_text': 'Water vapor helps trap heat, and is a far the strongest of the major greenhouse gases, contributing 36–72 percent of the greenhouse effect.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-986681',
#    'evidence-481206',
#    'evidence-274044',
#    'evidence-1062917']},
#  'claim-665': {'claim_text': 'many scientists were surprised when other researchers subsequently found that ringed and bearded seals (the primary prey of polar bears) north of the Bering Strait especially thrived with a longer open-water season, which is particularly conducive to fishing',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-578925',
#    'evidence-1105120',
#    'evidence-116567',
#    'evidence-143437']},
#  'claim-199': {'claim_text': 'In the past, warming has never been a threat to life on Earth.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-384274',
#    'evidence-262618',
#    'evidence-204609',
#    'evidence-760486']},
#  'claim-490': {'claim_text': 'IPCC report warning last week the world is “nowhere near on track” to meet its Paris commitments',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-284557',
#    'evidence-970429',
#    'evidence-1060242',
#    'evidence-64378',
#    'evidence-216761']},
#  'claim-2400': {'claim_text': '\'To suddenly label CO2 as a "pollutant" is a disservice to a gas that has played an enormous role in the development and sustainability of all life on this wonderful Earth.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-55991',
#    'evidence-668884',
#    'evidence-885542',
#    'evidence-808385']},
#  'claim-204': {'claim_text': 'after a natural orbitally driven warming, atmospheric carbon dioxide content increases 800 years later',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-143580',
#    'evidence-855683',
#    'evidence-69387',
#    'evidence-584709']},
#  'claim-1426': {'claim_text': 'Many of the world’s coral reefs are already barren or in a state of constant decline.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-580567',
#    'evidence-744921',
#    'evidence-1161994',
#    'evidence-205895']},
#  'claim-698': {'claim_text': 'A recent study led by Lawrence Livermore National Laboratory climate scientist Ben Santer found that while the models ran hot, the ‘overestimation’ was ‘partly due to systematic deficiencies in some of the post-2000 external forcings used in the model simulations.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-525568',
#    'evidence-366949',
#    'evidence-624586',
#    'evidence-281542',
#    'evidence-198990']},
#  'claim-1021': {'claim_text': 'The corals may save themselves, as many other creatures are attempting to do, by moving toward the poles as the Earth warms, establishing new reefs in cooler water.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1109959',
#    'evidence-1175280',
#    'evidence-1154331',
#    'evidence-205895']}}

# %%
final_dict_test = {}
for prediction in cls_predictions_test:
    order = cls_predictions_test.index(prediction)
    max_value, max_index = max((value, index) for index, value in enumerate(prediction))
    if max_index == 0:
        final_dict_test[test_ids[order]] = {"claim_text": test_claims[test_ids[order]]["claim_text"], "claim_label": "SUPPORTS", "evidences": test_evidences_predict[order]}
    elif max_index == 1:
        final_dict_test[test_ids[order]] = {"claim_text": test_claims[test_ids[order]]["claim_text"], "claim_label": "REFUTES", "evidences": test_evidences_predict[order]}
    elif max_index == 2:
        final_dict_test[test_ids[order]] = {"claim_text": test_claims[test_ids[order]]["claim_text"], "claim_label": "NOT_ENOUGH_INFO", "evidences": test_evidences_predict[order]}
    elif max_index == 3:
        final_dict_test[test_ids[order]] = {"claim_text": test_claims[test_ids[order]]["claim_text"], "claim_label": "DISPUTED", "evidences": test_evidences_predict[order]}
final_dict_test
# Out:
# {'claim-2967': {'claim_text': 'The contribution of waste heat to the global climate is 0.028 W/m2.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-308923',
#    'evidence-22107',
#    'evidence-213569',
#    'evidence-257116']},
#  'claim-979': {'claim_text': '“Warm weather worsened the most recent five-year drought, which included the driest four-year period on record in terms of statewide precipitation.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-957389',
#    'evidence-178433',
#    'evidence-1077548',
#    'evidence-200293']},
#  'claim-1609': {'claim_text': 'Greenland has only lost a tiny fraction of its ice mass.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1200633',
#    'evidence-962481',
#    'evidence-776422',
#    'evidence-399454']},
#  'claim-1020': {'claim_text': '“The global reef crisis does not necessarily mean extinction for coral species.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-642301',
#    'evidence-161852',
#    'evidence-205895',
#    'evidence-670186']},
#  'claim-2599': {'claim_text': 'Small amounts of very active substances can cause large effects.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-834109',
#    'evidence-253763',
#    'evidence-851510',
#    'evidence-432221']},
#  'claim-2110': {'claim_text': "They changed the name from 'global warming' to 'climate change'",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-72690',
#    'evidence-506409',
#    'evidence-292357',
#    'evidence-695091']},
#  'claim-1135': {'claim_text': 'Scientists confirm a mass bleaching event on the Great Barrier Reef this year has killed more corals than ever before, with more than two thirds destroyed across large swathes of the biodiverse site.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-828180',
#    'evidence-670186',
#    'evidence-323266',
#    'evidence-1183711',
#    'evidence-688029']},
#  'claim-712': {'claim_text': '“Instead of a three-foot increase in ocean levels by the end of the century, six feet was more likely, according to DeConto and Pollard’s findings.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-961837',
#    'evidence-1104813',
#    'evidence-822729',
#    'evidence-890095',
#    'evidence-213946']},
#  'claim-1307': {'claim_text': 'a new study by scientists at the Australian Research Council finds that the ongoing bleaching event is mainly due to human-caused global warming, and that if global warming proceeds as currently expected, “large parts” of the Great Barrier Reef could die by the mid-2030s.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-51798',
#    'evidence-417371',
#    'evidence-403673',
#    'evidence-311208',
#    'evidence-57888']},
#  'claim-148': {'claim_text': 'Previous IPCC reports tended to assume that clouds would have a neutral impact because the warming and cooling feedbacks would cancel each other out.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1091739',
#    'evidence-37274',
#    'evidence-369911',
#    'evidence-1044935',
#    'evidence-448411']},
#  'claim-903': {'claim_text': 'Growers regularly pump CO2 into greenhouses, raising levels to three times that of the natural environment, to produce stronger, greener, healthier plants.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-12425',
#    'evidence-668884',
#    'evidence-578065',
#    'evidence-307967']},
#  'claim-2942': {'claim_text': 'It’s usually taken to be the fact that as carbon dioxide concentrations in the atmosphere increase, the 1 per cent of CO2 that’s the heavier carbon isotope ratio c13 declines in proportion.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-572332',
#    'evidence-661699',
#    'evidence-173055',
#    'evidence-946483',
#    'evidence-82903']},
#  'claim-1001': {'claim_text': '‘This study goes beyond statistical correlations and explores a specific process that can plausibly explain how enhanced high-latitude warming trends may trigger remote weather impacts,’ he said.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1122793',
#    'evidence-895046',
#    'evidence-277435',
#    'evidence-289014',
#    'evidence-348048']},
#  'claim-1034': {'claim_text': 'Your odds of correctly guessing the outcome of a flipped coin are 1 in 2, but your odds of guessing correctly twice in a row are only 1 in 4 —',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-348061',
#    'evidence-1074949',
#    'evidence-23786',
#    'evidence-322382',
#    'evidence-442571']},
#  'claim-1009': {'claim_text': '‘Arctic ice conditions have been tracking at record low conditions since October, persisting for six consecutive months’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-482300',
#    'evidence-105873',
#    'evidence-717237',
#    'evidence-31096']},
#  'claim-770': {'claim_text': '[CO2] has increased 43 percent above the pre-industrial level so far',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-668884',
#    'evidence-1005062',
#    'evidence-62228',
#    'evidence-38305']},
#  'claim-3074': {'claim_text': 'Fourth Assessment Report (AR4), in which the likely range is given as 2.0°C to 4.5°C, with a best estimate of 3.0°C" (Pat Michaels)',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-526818',
#    'evidence-607214',
#    'evidence-1040995',
#    'evidence-483878']},
#  'claim-1761': {'claim_text': 'Multiple lines of evidence make it very clear that the rise in atmospheric CO2 is due to human emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-889101',
#    'evidence-668884',
#    'evidence-979052',
#    'evidence-493616',
#    'evidence-335886']},
#  'claim-1475': {'claim_text': "More than 500 scientists and professionals in climate and related fields have sent a 'European Climate Declaration' to the Secretary-General of the United Nations.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-709490',
#    'evidence-322303',
#    'evidence-381173',
#    'evidence-776286',
#    'evidence-916512']},
#  'claim-477': {'claim_text': 'Scientists say halting deforestation ‘just as urgent’ as reducing emissions',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1128272',
#    'evidence-417856',
#    'evidence-773242',
#    'evidence-425896']},
#  'claim-1378': {'claim_text': 'Antarctica is gaining land-based ice, according to a new study by NASA scientists published in the Journal of Glaciology',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-693807',
#    'evidence-475376',
#    'evidence-529248',
#    'evidence-932031']},
#  'claim-503': {'claim_text': '“During the sunless winter, a heatwave raised concerns that the polar vortex may be eroding.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-7898',
#    'evidence-1047253',
#    'evidence-760329',
#    'evidence-562979']},
#  'claim-2751': {'claim_text': 'The argument that solving the global warming problem by reducing human greenhouse gas emissions is "too hard" generally stems from the belief that (i) our technology is not sufficiently advanced to achieve significant emissions reductions,',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-693067',
#    'evidence-1144825',
#    'evidence-960067',
#    'evidence-1166589',
#    'evidence-5044']},
#  'claim-2575': {'claim_text': 'Over the last 30-40 years 80% of coral in the Caribbean have been destroyed and 50% in Indonesia and the Pacific.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-728670',
#    'evidence-836657',
#    'evidence-593512',
#    'evidence-243551',
#    'evidence-342232']},
#  'claim-30': {'claim_text': "the bushfires [in Australia] were caused by arsonists and a series of lightning strikes, not 'climate change'",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-780092',
#    'evidence-968437',
#    'evidence-793815',
#    'evidence-1148869']},
#  'claim-2994': {'claim_text': "'Mauna Loa has been producing a readout which supports Manning's predetermined goal by showing steady growth in atmospheric CO2 concentrations since 1959.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-386428',
#    'evidence-685709',
#    'evidence-845045',
#    'evidence-489159']},
#  'claim-55': {'claim_text': '[T]he raw data, the actual thermometer data[...] shows that the US has been cooling for 80 to 90 years.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-945472',
#    'evidence-396425',
#    'evidence-226306',
#    'evidence-1145327']},
#  'claim-1271': {'claim_text': 'Greenland ice sheet … would balloon sea levels by around 7m should it disintegrate',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1040612',
#    'evidence-173281',
#    'evidence-188525',
#    'evidence-1099491']},
#  'claim-2248': {'claim_text': 'Climate sensitivity can be calculated empirically by comparing past temperature change to natural forcings at the time.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1008952',
#    'evidence-78884',
#    'evidence-494418',
#    'evidence-110839',
#    'evidence-206645']},
#  'claim-532': {'claim_text': 'Never mind that the emissions of carbon dioxide to make and maintain a wind or solar industrial complex are far greater than they will ever save.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-572332',
#    'evidence-693063',
#    'evidence-56623',
#    'evidence-873593',
#    'evidence-348822']},
#  'claim-556': {'claim_text': 'The April low temperatures here are now about 6 degrees Fahrenheit warmer than they used to be.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-128472',
#    'evidence-556196',
#    'evidence-1088556',
#    'evidence-1196923']},
#  'claim-1173': {'claim_text': '[…]until we develop a practical, cost-competitive alternative to fossil fuels, it is unlikely that renewable energy will ever make up more than 15-20% of global energy requirements.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-254529',
#    'evidence-489429',
#    'evidence-127142',
#    'evidence-366836',
#    'evidence-987493']},
#  'claim-539': {'claim_text': 'We note that the Earth has never in its history had a quasi-stable state that is around 2C warmer than the preindustrial and suggest that there is substantial risk that the system, itself, will ‘want’ to continue warming because of all of these other processes – even if we stop emissions,” she said.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1172137',
#    'evidence-953997',
#    'evidence-694262',
#    'evidence-866495',
#    'evidence-801457']},
#  'claim-893': {'claim_text': 'While France and other G7 countries lamented the U.S. exit from the Paris climate accord, America’s air is already cleaner than that of any other country in the G7, except Canada with its scant population.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-34493',
#    'evidence-45714',
#    'evidence-574518',
#    'evidence-398722']},
#  'claim-2857': {'claim_text': 'Weather is chaotic because air is light, it has low friction and viscosity, it expands strongly when in contact with hot surfaces and it conducts heat poorly.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-72528',
#    'evidence-903495',
#    'evidence-972046',
#    'evidence-1116015']},
#  'claim-109': {'claim_text': 'Local and regional sea levels continue to exhibit typical natural variability—in some places rising and in others falling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-315990',
#    'evidence-988277',
#    'evidence-668284',
#    'evidence-189414',
#    'evidence-63254']},
#  'claim-2476': {'claim_text': "The global dimming trend reversed around 1990 - 15 years after the global warming trend began in the mid 1970's.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-315033',
#    'evidence-513478',
#    'evidence-367687',
#    'evidence-403673',
#    'evidence-513415']},
#  'claim-3038': {'claim_text': 'Clearly, other factors besides atmospheric carbon influence earth temperatures and global warming."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-34759',
#    'evidence-1006052',
#    'evidence-368794',
#    'evidence-268112',
#    'evidence-915569']},
#  'claim-3127': {'claim_text': '"Skeptics hope that Postma’s alternative thermal model will lead  to the birth of a new climatology, one that actually follows the laws of  physics and properly physical modeling techniques...',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1166652',
#    'evidence-107893',
#    'evidence-422407',
#    'evidence-474588',
#    'evidence-438175']},
#  'claim-474': {'claim_text': 'Sea ice continued its declining trend, both in the Arctic and Antarctic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-559069',
#    'evidence-360300',
#    'evidence-298127',
#    'evidence-1172097']},
#  'claim-2464': {'claim_text': 'While natural forcings can account for much of the early 20th Century warming, humans played a role as well.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1076603',
#    'evidence-269246',
#    'evidence-576285',
#    'evidence-526112',
#    'evidence-1044216']},
#  'claim-2427': {'claim_text': 'By that time CO2 emissions had already risen from the expanded use  of coal that had powered the industrial revolution, and emissions only  increased slowly from 3.5gigatonnes in 1910 to under 4gigatonnes by the  end of the Second World War.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-527316',
#    'evidence-329503',
#    'evidence-1023546',
#    'evidence-743151',
#    'evidence-395981']},
#  'claim-2167': {'claim_text': 'Royal Society embraces skepticism',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-402677',
#    'evidence-725190',
#    'evidence-974626',
#    'evidence-780416',
#    'evidence-412424']},
#  'claim-812': {'claim_text': 'The human contribution can be up to 30 percent or so of the total rainfall coming out of the storm',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-250928',
#    'evidence-390114',
#    'evidence-474459',
#    'evidence-63839']},
#  'claim-2590': {'claim_text': "This argument originates from Angstrom's work in 1901.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-507814',
#    'evidence-652349',
#    'evidence-603887',
#    'evidence-877965']},
#  'claim-404': {'claim_text': 'Actual weather records over the past 100 years show no correlation between rising carbon dioxide levels and local temperatures.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-725977',
#    'evidence-683138',
#    'evidence-973268',
#    'evidence-1153298']},
#  'claim-2977': {'claim_text': 'According to the study, as carbon levels have risen, the cold air at high altitudes over the tropics has actually grown colder.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-846997',
#    'evidence-427368',
#    'evidence-216481',
#    'evidence-786845',
#    'evidence-1106539']},
#  'claim-2673': {'claim_text': 'They changed the name from “global warming” to “climate change” after the term global warming just wasn’t working (it was too cold)!',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1106221',
#    'evidence-292357',
#    'evidence-533511',
#    'evidence-417371']},
#  'claim-2509': {'claim_text': 'In 1905, PDO switched to a warm phase.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-667390',
#    'evidence-84969',
#    'evidence-32728',
#    'evidence-420577']},
#  'claim-138': {'claim_text': 'As a result, half of the people surveyed around the world last year said they thought climate change would make humanity extinct.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1178287',
#    'evidence-638716',
#    'evidence-1034813',
#    'evidence-72690',
#    'evidence-438742']},
#  'claim-952': {'claim_text': 'The Alaskan tundra is warming so quickly it has become a net emitter of carbon dioxide ahead of schedule, a new study finds',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-6913',
#    'evidence-966395',
#    'evidence-855683',
#    'evidence-1153298']},
#  'claim-1691': {'claim_text': 'Sea level rise is now increasing faster than predicted due to unexpectedly rapid ice melting.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-923525',
#    'evidence-808139',
#    'evidence-435467',
#    'evidence-739706',
#    'evidence-618094']},
#  'claim-1741': {'claim_text': 'Volcanoes have had no warming effect in recent global warming - if anything, a cooling effect.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-886906',
#    'evidence-1167418',
#    'evidence-1082770',
#    'evidence-720736']},
#  'claim-1202': {'claim_text': '\xa0The discrepancy between model-predicted warming and (lower) real-world observations has inspired new respect for natural climate variability relative to greenhouse-gas forcing.\xa0',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-681843',
#    'evidence-1124041',
#    'evidence-708206',
#    'evidence-585919']},
#  'claim-1028': {'claim_text': 'A second coat of paint has much less of an effect, while adding a third or fourth coat has almost no impact at all.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-644769',
#    'evidence-264237',
#    'evidence-672143',
#    'evidence-182278']},
#  'claim-28': {'claim_text': 'Volcanoes Melting West Antarctic Glaciers, Not Global Warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1088478',
#    'evidence-894521',
#    'evidence-171206',
#    'evidence-797505']},
#  'claim-275': {'claim_text': 'until temperature increases began to slow down after 1998 and remained relatively stable for a period of 15 years',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1190921',
#    'evidence-820417',
#    'evidence-1072749',
#    'evidence-185284',
#    'evidence-341447']},
#  'claim-350': {'claim_text': 'Since 1965, more parts of the U.S. have seen a decrease in flooding than have seen an increase.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-245108',
#    'evidence-264155',
#    'evidence-984802',
#    'evidence-318421']},
#  'claim-2204': {'claim_text': 'All the indicators show that global warming is still happening.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-368794',
#    'evidence-51798',
#    'evidence-403673',
#    'evidence-9054']},
#  'claim-1604': {'claim_text': 'CO2 increase is natural, not human-caused.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-668884',
#    'evidence-985452',
#    'evidence-66273',
#    'evidence-221841']},
#  'claim-3119': {'claim_text': 'CO2 constitutes 80% of the non-condensing greenhouse gas forcing.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-556098',
#    'evidence-668884',
#    'evidence-578065',
#    'evidence-272735']},
#  'claim-2150': {'claim_text': 'Adapting to global warming is cheaper than preventing it',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-403673',
#    'evidence-341424',
#    'evidence-478628',
#    'evidence-57888']},
#  'claim-21': {'claim_text': 'Sea level rise has been slow and a constant, pre-dating industrialization',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-520022',
#    'evidence-988277',
#    'evidence-630900',
#    'evidence-93169']},
#  'claim-2013': {'claim_text': 'U.S. Sen. Ron Johnson voted to let oil and gas companies emit "unlimited carbon pollution into our air"',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-886517',
#    'evidence-1043523',
#    'evidence-1111307',
#    'evidence-695571',
#    'evidence-384523']},
#  'claim-467': {'claim_text': 'This is the South Pole ice, 90% of Earth’s ice, and it’s getting thicker.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1017204',
#    'evidence-634139',
#    'evidence-906399',
#    'evidence-953716']},
#  'claim-2754': {'claim_text': '"There are many urgent priorities that need the attention of Congress, and it is not for me as an invited guest in your country to say what they are.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-309446',
#    'evidence-1138505',
#    'evidence-977922',
#    'evidence-7424']},
#  'claim-2797': {'claim_text': 'Global brightening is caused by changes in cloud cover, reflective aerosols and absorbing aerosols.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1000246',
#    'evidence-390174',
#    'evidence-644779',
#    'evidence-318485']},
#  'claim-1771': {'claim_text': 'Peer-reviewed research, physics, and math all tell us that a grand solar minimum would have no more than a 0.3°C cooling effect, barely enough to put a dent in human-caused global warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1082770',
#    'evidence-814320',
#    'evidence-417371',
#    'evidence-895823']},
#  'claim-1908': {'claim_text': 'In reality, gas produced by fracking is worse for the climate than coal.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1065464',
#    'evidence-590620',
#    'evidence-351939',
#    'evidence-796018']},
#  'claim-2000': {'claim_text': 'There is not a single candidate in the Republican primary that thinks we should do anything about climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-874144',
#    'evidence-72690',
#    'evidence-963179',
#    'evidence-82794',
#    'evidence-1034813']},
#  'claim-2084': {'claim_text': "Hurricanes aren't linked to global warming",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-415989',
#    'evidence-403673',
#    'evidence-57888',
#    'evidence-853782']},
#  'claim-1237': {'claim_text': 'the last sea-level high point, … occurred between the last two ice ages, about 125,000 years ago.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-15429',
#    'evidence-1059229',
#    'evidence-373203',
#    'evidence-634307']},
#  'claim-400': {'claim_text': 'The idea that climate change is producing heat records across the Earth is among the most egregious manipulations of data in the absurd global warming debate.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-957593',
#    'evidence-35625',
#    'evidence-880073',
#    'evidence-292357',
#    'evidence-532524']},
#  'claim-1508': {'claim_text': 'global warming ceased around the end of the twentieth century and was followed (since 1997) by 19 years of stable temperature.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1092088',
#    'evidence-368794',
#    'evidence-268112',
#    'evidence-354405',
#    'evidence-1086865']},
#  'claim-520': {'claim_text': 'Just 1.25 per cent of the carbon dioxide in the atmosphere-ocean system has been released by \xadhumans in the past 250 years.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-833215',
#    'evidence-1140012',
#    'evidence-78654',
#    'evidence-946483',
#    'evidence-839069']},
#  'claim-3064': {'claim_text': 'No warming since at least 1995, no melting glaciers and now no rising sea levels.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-98543',
#    'evidence-1088478',
#    'evidence-797505',
#    'evidence-808139',
#    'evidence-1022509']},
#  'claim-1588': {'claim_text': "Melting ice isn't warming the Arctic.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1043067',
#    'evidence-118577',
#    'evidence-1030127',
#    'evidence-1034941']},
#  'claim-1488': {'claim_text': 'New Study Confirms EVs Considerably Worse For Climate Than Diesel Cars.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-431982',
#    'evidence-254130',
#    'evidence-796688',
#    'evidence-765914']},
#  'claim-2733': {'claim_text': 'A number of independent studies using near-global satellite data find positive feedback and high climate sensitivity.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-152168',
#    'evidence-1003105',
#    'evidence-771272',
#    'evidence-711945',
#    'evidence-494418']},
#  'claim-809': {'claim_text': 'In the early 20th century, state and federal governments began aggressively fighting wildfires and trying to keep them as small as possible.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1087915',
#    'evidence-576285',
#    'evidence-422302',
#    'evidence-572553',
#    'evidence-1145188']},
#  'claim-763': {'claim_text': 'And some plants – like algae which use carbon for photosynthesis – may even benefit.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-826833',
#    'evidence-199385',
#    'evidence-879668',
#    'evidence-674731',
#    'evidence-1186170']},
#  'claim-454': {'claim_text': 'Man-made greenhouse gases play only an insignificant role.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-199466',
#    'evidence-1175329',
#    'evidence-661772',
#    'evidence-868081']},
#  'claim-1853': {'claim_text': 'Barack Obama supports proposals "to devote billions of dollars annually to state game and fish agencies and federal land management agencies to help them ensure that fish and wildlife survive the impacts of climate change."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-972641',
#    'evidence-656837',
#    'evidence-123057',
#    'evidence-863739']},
#  'claim-2838': {'claim_text': "The data is being reported by the University of Illinois's Arctic Climate Research Center, and is derived from satellite observations of the Northern and Southern hemisphere polar regions (Daily Tech).",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-117846',
#    'evidence-501093',
#    'evidence-118071',
#    'evidence-570183']},
#  'claim-2028': {'claim_text': 'cutting speed limits could slow climate change',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-278964',
#    'evidence-1006823',
#    'evidence-72690',
#    'evidence-1178287']},
#  'claim-2434': {'claim_text': 'The IPCC blames human emissions of carbon dioxide for the last  warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1117137',
#    'evidence-874622',
#    'evidence-1091994',
#    'evidence-288351']},
#  'claim-298': {'claim_text': 'Only very few peer-reviewed papers even go so far as to say that recent warming is chiefly anthropogenic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-844208',
#    'evidence-265759',
#    'evidence-152784',
#    'evidence-352729',
#    'evidence-1028601']},
#  'claim-338': {'claim_text': 'Rapid assessment of average temperatures in France between 26-28 June showed a “substantial” increase in the likelihood of the heatwave happening as a result of human-caused global warming, experts at the World Weather Attribution group said.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-895823',
#    'evidence-368794',
#    'evidence-417371',
#    'evidence-268112',
#    'evidence-503460']},
#  'claim-1672': {'claim_text': 'Global temperature is still rising and 2010 was the hottest recorded.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-922640',
#    'evidence-614887',
#    'evidence-803739',
#    'evidence-436190']},
#  'claim-2840': {'claim_text': 'Arctic sea ice is also falling at an accelerated rate.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-559069',
#    'evidence-589546',
#    'evidence-869213',
#    'evidence-5732']},
#  'claim-1425': {'claim_text': 'Each year sees the disappearance of thousands of plant and animal species which we will never know, which our children will never see, because they have been lost for ever.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-204609',
#    'evidence-760486',
#    'evidence-925288',
#    'evidence-1016282']},
#  'claim-1985': {'claim_text': 'The North Pole is melting "a bit" but the South Pole is getting bigger.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-232707',
#    'evidence-626530',
#    'evidence-950574',
#    'evidence-770009',
#    'evidence-511609']},
#  'claim-1156': {'claim_text': 'The costs of emissions regulations, which will be paid by everyone, will be punishingly high and will provide no benefits to most people anywhere in the world.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1142116',
#    'evidence-601273',
#    'evidence-720415',
#    'evidence-412094']},
#  'claim-2870': {'claim_text': "Ironically, it's those who are mispresenting Hulme's paper that are the ones being misleading.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1034945',
#    'evidence-1064391',
#    'evidence-883116',
#    'evidence-552391']},
#  'claim-2898': {'claim_text': 'The report suggests significantly smaller overall  ice-mass losses than previous estimates.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-947921',
#    'evidence-591671',
#    'evidence-889507',
#    'evidence-264412',
#    'evidence-1081160']},
#  'claim-2329': {'claim_text': 'We know the Northwest Passage had been open before."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-866503',
#    'evidence-1055581',
#    'evidence-956029',
#    'evidence-723683']},
#  'claim-1998': {'claim_text': 'There is a link between climate change and the NSW bushfires.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-772442',
#    'evidence-72690',
#    'evidence-1087962',
#    'evidence-894452']},
#  'claim-2209': {'claim_text': 'Surface temperatures can show short-term cooling when heat is exchanged between the atmosphere and the ocean, which has a much greater heat capacity than the air.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-763705',
#    'evidence-448636',
#    'evidence-1144500',
#    'evidence-268662',
#    'evidence-493182']},
#  'claim-1582': {'claim_text': "Tuvalu sea level isn't rising.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-988277',
#    'evidence-136458',
#    'evidence-1133838',
#    'evidence-51367']},
#  'claim-3072': {'claim_text': '"a paper...in Science magazine concludes that the climate sensitivity—how much the earth’s average temperature will rise as a result of a doubling of the atmospheric concentration of carbon dioxide—likely (that is, with a 66% probability) lies in the range 1.7°C to 2.6°C, with a median value of 2.3°C.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1196020',
#    'evidence-666859',
#    'evidence-915569',
#    'evidence-852366']},
#  'claim-381': {'claim_text': '[subsidies for wind and solar] add to emissions because coal-fired elec\xadtricity needs to be on standby for when there is no wind or sunshine.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-851967',
#    'evidence-113217',
#    'evidence-1023203',
#    'evidence-1105658']},
#  'claim-398': {'claim_text': 'nothing we can do to stop the Earth’s naturally occurring climate cycles.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-535128',
#    'evidence-1155948',
#    'evidence-239383',
#    'evidence-5587']},
#  'claim-1560': {'claim_text': 'Sea level rise predictions are exaggerated.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-988277',
#    'evidence-1076062',
#    'evidence-65928',
#    'evidence-630900']},
#  'claim-2246': {'claim_text': '"His [Dr Spencer\'s] latest research demonstrates that – in the short term, at any rate –  the temperature feedbacks that the IPCC imagines will greatly amplify  any initial warming caused by CO2 are net-negative, attenuating the  warming they are supposed to enhance.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-338987',
#    'evidence-247680',
#    'evidence-991415',
#    'evidence-448411',
#    'evidence-21628']},
#  'claim-2774': {'claim_text': 'Actual reconstructions "diverge" from the instrumental series in the last part of 20th century.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1131132',
#    'evidence-116909',
#    'evidence-802353',
#    'evidence-751275']},
#  'claim-972': {'claim_text': '“Arctic land stores about twice as much carbon as the atmosphere.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-248795',
#    'evidence-721883',
#    'evidence-22100',
#    'evidence-318220']},
#  'claim-1531': {'claim_text': 'Earth’s climate is now changing faster than at any point in the history of modern civilization, primarily as a result of human activities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-809426',
#    'evidence-1034813',
#    'evidence-756200',
#    'evidence-1023859']},
#  'claim-2592': {'claim_text': '"A July 6, 2007 study published in the journal Science about Greenland by an international team of scientists found DNA “evidence that suggests the frozen shield covering the immense island survived the Earth’s last period of global warming,” according to a Boston Globe Article. \xa0...',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-877733',
#    'evidence-430265',
#    'evidence-583104',
#    'evidence-536079',
#    'evidence-747315']},
#  'claim-2468': {'claim_text': '"Satellite measurements indicate an absence of significant global warming since 1979, the very period that human carbon dioxide emissions have been increasing rapidly.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-1091994',
#    'evidence-1117137',
#    'evidence-855683']},
#  'claim-463': {'claim_text': '“So now we’re able to explain from natural factors how we’ve had the 20th Century warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-957593',
#    'evidence-785914',
#    'evidence-197881',
#    'evidence-616036',
#    'evidence-617787']},
#  'claim-616': {'claim_text': 'The effect of long-term warming is to make it harder to count on snowmelt runoff in wet times',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-999756',
#    'evidence-8063',
#    'evidence-462231',
#    'evidence-276438',
#    'evidence-479593']},
#  'claim-1240': {'claim_text': '“Ice-free means the central basin of the Arctic will be ice-free',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-586254',
#    'evidence-731434',
#    'evidence-39028',
#    'evidence-509944']},
#  'claim-2951': {'claim_text': 'The two most cited composites are PMOD and ACRIM.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-491726',
#    'evidence-1089445',
#    'evidence-655986',
#    'evidence-894648']},
#  'claim-1977': {'claim_text': 'The climate-change agreement between the United States and China "requires the Chinese to do nothing at all for 16 years."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-341698',
#    'evidence-506690',
#    'evidence-541537',
#    'evidence-1202597',
#    'evidence-868071']},
#  'claim-942': {'claim_text': '‘We could be decades too fast, or decades too slow,’said one of them, Robert M. DeConto of the University of Massachusetts, Amherst.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-90819',
#    'evidence-210377',
#    'evidence-955188',
#    'evidence-606195']},
#  'claim-2755': {'claim_text': 'Global warming is an increasingly urgent problem.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-403673',
#    'evidence-57888',
#    'evidence-18613',
#    'evidence-415162']},
#  'claim-1230': {'claim_text': 'On the Pacific Coast, a climate pattern that had pushed billions of gallons of water toward Asia is now ending, so that in coming decades the sea is likely to rise quickly off states like Oregon and California.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-968192',
#    'evidence-426828',
#    'evidence-328554',
#    'evidence-97916',
#    'evidence-372344']},
#  'claim-3123': {'claim_text': 'Given that a doubling of carbon dioxide would change the surface heat flux by only two watts per square meter, it is evident that a small change in cloud cover can strongly affect the response to carbon dioxide."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-725977',
#    'evidence-84444',
#    'evidence-475329',
#    'evidence-873593']},
#  'claim-1684': {'claim_text': 'The 2nd law of thermodynamics is consistent with the greenhouse effect which is directly observed.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-256785',
#    'evidence-685418',
#    'evidence-818530',
#    'evidence-919736',
#    'evidence-990389']},
#  'claim-839': {'claim_text': '“Even if we meet the Paris goals of two degrees warming, cities like Karachi and Kolkata will become close to uninhabitable, annually encountering deadly heat waves like those that crippled them in 2015.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-482130',
#    'evidence-236630',
#    'evidence-465562',
#    'evidence-293137',
#    'evidence-1150951']},
#  'claim-2423': {'claim_text': 'Arctic sea ice has been steadily thinning, even in the last few years while the surface ice (eg - sea ice extent) increased slightly.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-482300',
#    'evidence-869213',
#    'evidence-572376',
#    'evidence-192938',
#    'evidence-1150857']},
#  'claim-1243': {'claim_text': 'by that I mean the central Arctic will be ice-free.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-586254',
#    'evidence-509944',
#    'evidence-731434',
#    'evidence-39028']},
#  'claim-494': {'claim_text': 'The Massachusetts Bay Colony in 1635 experienced a Category 3 or 4 storm, with up to a 20-foot storm surge.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-298897',
#    'evidence-965474',
#    'evidence-1131498',
#    'evidence-474459',
#    'evidence-1028848']},
#  'claim-1458': {'claim_text': 'Glaciers are retreating almost everywhere around the world — including in the Alps, Himalayas, Andes, Rockies, Alaska and Africa.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-603102',
#    'evidence-771265',
#    'evidence-312901',
#    'evidence-1131637']},
#  'claim-461': {'claim_text': 'Temperatures cooled from about 1940 to 1975, and then they rose from about ’75 to about 2005 or so, and since then they’ve been flat or cooling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-634493',
#    'evidence-907695',
#    'evidence-1079843',
#    'evidence-474653']},
#  'claim-1304': {'claim_text': 'in a letter to The Times from Lord Krebs and company, essentially telling the newspaper to stop reporting less-than-negative climate stories.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-717267',
#    'evidence-275844',
#    'evidence-239383',
#    'evidence-333707']},
#  'claim-2564': {'claim_text': 'This small warming is  likely a result of the natural alterations in global ocean currents  which are driven by ocean salinity variations.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-881306',
#    'evidence-1167418',
#    'evidence-384415',
#    'evidence-297323',
#    'evidence-720736']},
#  'claim-2121': {'claim_text': 'Infrared Iris will reduce global warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-106151',
#    'evidence-656338',
#    'evidence-597452',
#    'evidence-509088']},
#  'claim-2631': {'claim_text': 'The temperatures are expected to change by as much as 10 Fahrenheit degrees at different places of the globe.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-547651',
#    'evidence-600294',
#    'evidence-128472',
#    'evidence-401833',
#    'evidence-1196923']},
#  'claim-1141': {'claim_text': '“While record low sea ice is nothing new in the Arctic, this is a surprising turn of events for the Antarctic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1013303',
#    'evidence-869213',
#    'evidence-482300',
#    'evidence-357997',
#    'evidence-1143730']},
#  'claim-2398': {'claim_text': 'While there are direct ways in which CO2 is a pollutant (acidification of the ocean), its primary impact is its greenhouse warming effect.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1167418',
#    'evidence-66273',
#    'evidence-106073',
#    'evidence-499734',
#    'evidence-871201']},
#  'claim-1048': {'claim_text': 'While transient weather variability is playing a key role here, the widespread record warmth across the U.S. so far this year is part of a long-term trend toward more warm temperature records versus cold ones.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-367175',
#    'evidence-417353',
#    'evidence-664185',
#    'evidence-989916',
#    'evidence-508793']},
#  'claim-2783': {'claim_text': 'The study indicates far less future global warming will occur than United Nations computer models have predicted, and supports prior studies indicating increases in atmospheric carbon dioxide trap far less heat than alarmists have claimed.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-669520',
#    'evidence-1104389',
#    'evidence-597084',
#    'evidence-242556',
#    'evidence-547918']},
#  'claim-1003': {'claim_text': 'A recent study in Nature Geoscience, for instance, called into question whether the Arctic’s melting, and in particular its sea ice loss, has been causing winter cooling over Eurasia, another idea that has been swept up in the debate over the jet stream and weather extremes.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-118577',
#    'evidence-290051',
#    'evidence-1043067',
#    'evidence-903119',
#    'evidence-1143730']},
#  'claim-1872': {'claim_text': 'Donald Trump claims Global Warming is a hoax',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1160675',
#    'evidence-580136',
#    'evidence-772258',
#    'evidence-312748']},
#  'claim-1842': {'claim_text': 'A video shows Koko the gorilla spontaneously using sign language to issue a warning about climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-47367',
#    'evidence-570779',
#    'evidence-879915',
#    'evidence-342759']},
#  'claim-2411': {'claim_text': 'Note that computer models are just concatenations of calculations you could do on a hand-held calculator, so they are theoretical and cannot be part of any evidence."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-519547',
#    'evidence-288985',
#    'evidence-187806',
#    'evidence-122619',
#    'evidence-760824']},
#  'claim-2428': {'claim_text': 'It was the post war  industrialization that caused the rapid rise in global CO2 emissions,  but by 1945 when this began, the Earth was already in a cooling phase  that started around 1942 and continued until 1975.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1205623',
#    'evidence-692521',
#    'evidence-668884',
#    'evidence-247680']},
#  'claim-1198': {'claim_text': '” ‘You see, gas in America is incredibly cheap, because of fracking,’ he says.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-658428',
#    'evidence-1065464',
#    'evidence-1087125',
#    'evidence-125961']},
#  'claim-678': {'claim_text': 'In the process, the cows will emit much greenhouse gas, and they will consume far more calories in beans than they will yield in meat, meaning far more clearcutting of forests to farm cattle feed than would be necessary if the beans above were simply eaten by people.”',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-8569',
#    'evidence-15885',
#    'evidence-2791',
#    'evidence-270378',
#    'evidence-143188']},
#  'claim-2105': {'claim_text': 'Excess CO2 from human emissions has a long residence time of over 100 years',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1162945',
#    'evidence-668884',
#    'evidence-743151',
#    'evidence-855820',
#    'evidence-230969']},
#  'claim-648': {'claim_text': '‘there will not be enough nitrogen available to sustain the high carbon uptake scenarios.’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-291276',
#    'evidence-1031082',
#    'evidence-679975',
#    'evidence-994663',
#    'evidence-820593']},
#  'claim-822': {'claim_text': 'Climate policy must compete with other long-term threats for always-scarce resources.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-352226',
#    'evidence-141026',
#    'evidence-187059',
#    'evidence-321319']},
#  'claim-2561': {'claim_text': 'Observed sea levels are actually tracking at the upper range of the IPCC projections.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-284557',
#    'evidence-1115102',
#    'evidence-1164059',
#    'evidence-1652',
#    'evidence-387450']},
#  'claim-2219': {'claim_text': 'The increase in temperatures since 1975 is a consistent feature of all reconstructions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-548766',
#    'evidence-534204',
#    'evidence-97676',
#    'evidence-676605',
#    'evidence-994786']},
#  'claim-1343': {'claim_text': 'roughly three-quarters of the tidal flood days now occurring in towns along the East Coast would not be happening in the absence of the rise in the sea level caused by human emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-667089',
#    'evidence-528349',
#    'evidence-573684',
#    'evidence-192225',
#    'evidence-10207']},
#  'claim-1351': {'claim_text': 'a marginally significant warming trend in the data over the past several years, erasing the temperature plateau that vexed climate alarmists have found difficult to explain.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1174955',
#    'evidence-595420',
#    'evidence-1207279',
#    'evidence-364928']},
#  'claim-2347': {'claim_text': 'In truth, the overwhelming majority of climate-research funding comes from the federal government and left-wing foundations.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-572553',
#    'evidence-260640',
#    'evidence-727479',
#    'evidence-893252']},
#  'claim-293': {'claim_text': 'When the measuring equipment gets old and needs replacing, it often requires re-calibration.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-915220',
#    'evidence-857605',
#    'evidence-1020106',
#    'evidence-966304']},
#  'claim-910': {'claim_text': 'The cement, iron and steel, and petroleum refining industries could see their production cut by 21% 19%, and 11% respectively.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-309027',
#    'evidence-197221',
#    'evidence-117114',
#    'evidence-927638']},
#  'claim-2815': {'claim_text': 'A new peer-reviewed study on Surface Warming and the Solar Cycle found that times of high solar activity are on average 0.2°C warmer than times of low solar activity, and that there is a polar amplification of the warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-700183',
#    'evidence-786294',
#    'evidence-1091884',
#    'evidence-129606']},
#  'claim-1652': {'claim_text': 'The strong CO2 effect has been observed by many different measurements.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-668884',
#    'evidence-1652',
#    'evidence-132348',
#    'evidence-98914']},
#  'claim-1212': {'claim_text': '(In technical lingo, the so-called social cost of carbon would be negative.)”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-162296',
#    'evidence-349727',
#    'evidence-594802',
#    'evidence-78145']}}

# %% [markdown]
# # 3.Testing and Evaluation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
file_path_dev = "Specifications/data/dev-predict.json"

# Write the dictionary to a JSON file
with open(file_path_dev, 'w') as json_file1:
    json.dump(final_dict_dev, json_file1)

file_path_test = "Specifications/data/test-output.json"

# Write the dictionary to a JSON file
with open(file_path_test, 'w') as json_file2:
    json.dump(final_dict_test, json_file2)

# %%
import subprocess

output = subprocess.check_output("python3 Specifications/eval.py --predictions Specifications/data/dev-predict.json --groundtruth Specifications/data/dev-claims.json", shell=True)

print(output)
# Out:
# b'Evidence Retrieval F-score (F)    = 0.08847660276231706\nClaim Classification Accuracy (A) = 0.43506493506493504\nHarmonic Mean of F and A          = 0.1470487617670356\n'

# %% [markdown]
# ## Object Oriented Programming codes here
#
# *You can use multiple code snippets. Just add more if needed*
