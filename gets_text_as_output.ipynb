# %% [markdown]
# # 2024 COMP90042 Project
# *Make sure you change the file name with your group id.*

# %% [markdown]
# # Readme
# *If there is something to be noted for the marker, please mention here.*
#
# *If you are planning to implement a program with Object Oriented Programming style, please put those the bottom of this ipynb file*

# %% [markdown]
# Some things we can try:
# - Ensemble methods, especially for final labelling
# - Different methods of utilizing text created with the transformer (e.g., use cosine similarities to obtain evidences)
# - Compare performance using the text as output vs directly obtaining IDs
# - For classification, usually, transformers might overfit without the use of bigger pre-trained models

# %% [markdown]
# # 1.DataSet Processing
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
## import libraries

# !pip3 install torchtext==0.4.0

# Standard libraries
import math
import string
import pandas as pd
import numpy as np
import json

# Machine learning and deep learning libraries
import tensorflow
import keras
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
from torchtext.data.utils import get_tokenizer
from torchtext.data import Field, LabelField, Example, Dataset
from torchtext.data.utils import get_tokenizer

# Natural Language Processing (NLP) libraries
import nltk
import spacy
from nltk.corpus import stopwords

# Visualization
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: torchtext==0.4.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (0.4.0)
# Requirement already satisfied: tqdm in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (4.66.2)
# Requirement already satisfied: requests in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (2.31.0)
# Requirement already satisfied: torch in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (2.3.0)
# Requirement already satisfied: numpy in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (1.24.3)
# Requirement already satisfied: six in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (4.11.0)
# Requirement already satisfied: sympy in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (1.12)
# Requirement already satisfied: networkx in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.1)
# Requirement already satisfied: jinja2 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from tqdm->torchtext==0.4.0) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchtext==0.4.0) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchtext==0.4.0) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from jinja2->torch->torchtext==0.4.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)

# %%
## reading in json files

"""
Description of json files
* [train-claims,dev-claims].json: JSON files for the labelled training and development set; 
* evidence.json: JSON file containing a large number of evidence passages (i.e. the “knowledge source”); 
* dev-claims-baseline.json: JSON file containing predictions of a baseline system on the development set;
"""

## relative file paths

## baseline system - will not be used for any training/evaluation
devClaimsBaselineFile='./data/dev-claims-baseline.json'
## use this for model training
trainClaimsFile='./data/train-claims.json'
## use this set for hyperparameter tuning and evaluation metric 
devClaimsFile='./data/dev-claims.json'
## evidence files need to be downloaded through https://drive.google.com/file/d/1JlUzRufknsHzKzvrEjgw8D3n_IRpjzo6/view?usp=sharing as it is to big to be uploaded to github
evidenceFile='./data/evidence.json'

testFile='./data/test-claims-unlabelled.json'

tokenizer=get_tokenizer("basic_english")

# %%
# Load the JSON data
with open(trainClaimsFile, 'r') as file:
    trainClaims=json.load(file)
with open(devClaimsFile, 'r') as file:
    devClaims=json.load(file)
with open(evidenceFile, 'r') as file:
    evidenceData=json.load(file)

## Preprocessing data -- lowercase, tokenize, and stopword removal
stopwords=set(nltk.corpus.stopwords.words('english'))
tokenizer=get_tokenizer('basic_english')
punctuations=string.punctuation

def preprocess(text):
    token=tokenizer(text.lower())
    cleanedTokens=[t for t in token if (t not in stopwords) and (t not in punctuations)]
    return ' '.join(cleanedTokens)

for ids, texts in evidenceData.items():
    evidenceData[ids]=preprocess(texts)

# Function to create DataFrame and merge evidence IDs with Text
def createDF(claims, evidence):
    combinedData=[]
    for claimID, claimText in claims.items():
        # Combine the ID with its corresponding evidences
        evidenceID=claimText['evidences']
        evidenceText=(evidence[i] for i in evidenceID if i in evidence)
        combinedData.append({
            'claim_id': claimID,
            'claim_text': preprocess(claimText['claim_text']),
            'evidence_id': evidenceID,
            'evidence_text': " ".join(evidenceText),
            'claim_label': claimText['claim_label']
        })
    # Create DataFrame
    return pd.DataFrame(combinedData)

# Create CSV Files
trainFullMerged=createDF(trainClaims,evidenceData)
devFullMerged=createDF(devClaims,evidenceData)
trainFullMerged.to_csv("data/trainFullMerged.csv", index=False)
devFullMerged.to_csv("data/devFullMerged.csv", index=False)

# Convert evidence into csv as well
evidenceFinal=pd.DataFrame(list(evidenceData.items()),columns=['evidence_id','evidence_text'])
evidenceFinal.to_csv('data/evidencePreprocessed.csv',index=False)

# Convert unlabelled Data into CSV as well
with open(testFile, 'r') as file:
    testData=json.load(file)
for ids, texts in testData.items():
    claim_text = texts['claim_text']
    testData[ids]=preprocess(claim_text)
testFinal=pd.DataFrame(list(testData.items()), columns=['claim_id', 'claim_text'])
testFinal.to_csv('data/testPreprocessed.csv',index=False)

# %%
## use this for model training
trainClaimsFile='./data/trainFullMerged.csv'
## use this set for hyperparameter tuning and evaluation metric 
devClaimsFile='./data/devFullMerged.csv'
## evidence files need to be downloaded through googledrive (https://drive.google.com/file/d/1OyihwdAWfqHIOueCB4bLBkYg4hTN_OKm/view?usp=sharing)
evidenceFile='./data/evidencePreprocessed.csv'
## test unlabelled dataset
testFile='./data/testPreprocessed.csv'

trainDataframe=pd.read_csv(trainClaimsFile)
devDataframe=pd.read_csv(devClaimsFile)
evidenceDataframe=pd.read_csv(evidenceFile)
testDataframe=pd.read_csv(testFile)

trainDataframe['claim_text']=trainDataframe['claim_text']
trainDataframe['evidence_id']=trainDataframe['evidence_id'].astype(str).str.strip('[]').str.strip("'").apply(preprocess)
trainDataframe['combined_evidence']=trainDataframe['evidence_id']+" "+trainDataframe['evidence_text']

devDataframe['claim_text']=devDataframe['claim_text']
devDataframe['evidence_id']=devDataframe['evidence_id'].astype(str).str.strip('[]').str.strip("'").apply(preprocess)
devDataframe['combined_evidence']=devDataframe['evidence_id'] +" "+ devDataframe['evidence_text']

evidenceDataframe['combined_evidence']=evidenceDataframe['evidence_id']+" "+evidenceDataframe['evidence_text']
evidenceDataframe['combined_evidence']=evidenceDataframe['combined_evidence'].astype(str).str.strip("'").apply(preprocess)

# %%
## Preprocessing data -- lowercase, tokenize, and stopword removal
stopwords=set(nltk.corpus.stopwords.words('english'))
tokenizer=get_tokenizer('basic_english')
punctuations=set(string.punctuation)

def preprocess(text):
    tokens=tokenizer(text)
    cleanedTokens = [token for token in tokens if token not in stopwords and token not in punctuations]
    return cleanedTokens

TEXT = Field(tokenize=preprocess, lower=True, init_token='<sos>', eos_token='<eos>', batch_first=False)

def createDatasetEncoderInput(dataframe,textTransform):
    field=[('reviewTextInput',textTransform),('evidenceTextOutput',textTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        reviewTextInput=row['claim_text']
        evidenceTextOutput=row['combined_evidence']
        examples.append(Example.fromlist([reviewTextInput,evidenceTextOutput], field))
    return Dataset(examples,fields=field)

def createDatasetOutput(dataframe,textTransform):
    field=[('evidenceTextOutput',textTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        evidenceTextOutput=row['combined_evidence']
        examples.append(Example.fromlist([evidenceTextOutput], field))
    return Dataset(examples,fields=field)

def createDatasetTest(dataframe,textTransform):
    field=[('reviewTextInput',textTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        reviewTextInput=row['claim_text']
        examples.append(Example.fromlist([reviewTextInput], field))
    return Dataset(examples,fields=field)

## remove LABEL if you want to get the text as predictions instead of ids
trainTensor = createDatasetEncoderInput(trainDataframe, TEXT)
devTensor = createDatasetEncoderInput(devDataframe, TEXT)
evidenceTensor=createDatasetOutput(evidenceDataframe,TEXT)
testTensor=createDatasetTest(testDataframe,TEXT)

# %%
TEXT.build_vocab(trainTensor)

# %%
# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def batchify(dataset, bsz):
    #batchify both text and labels
    data = TEXT.process([getattr(x, 'reviewTextInput') for x in dataset.examples])
    label = TEXT.process([getattr(x, 'evidenceTextOutput') for x in dataset.examples])
    nbatch = min(data.size(0), label.size(0)) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    label = label.narrow(0, 0, nbatch * bsz)
    data = data.view(bsz, -1).t().contiguous()
    label = label.view(bsz, -1).t().contiguous()
    min_seq_len = min(data.size(0), label.size(0))
    data = data[:min_seq_len]
    label = label[:min_seq_len]
    return data.to(device), label.to(device)

## test is used for the final predictions
TEST = Field(tokenize=preprocess, lower=True, init_token='<sos>', eos_token='<eos>', batch_first=True)
TEST.build_vocab(trainTensor)
def processTextOnly(dataset):
    data = TEST.process([getattr(x, 'reviewTextInput') for x in dataset.examples])
    return data.to(device)

# Batch sizes
batch_size = 20
eval_batch_size = 35
        
train_data,train_label = batchify(trainTensor, batch_size)
dev_data,dev_label = batchify(devTensor, eval_batch_size)
test_data=processTextOnly(testTensor)
dev_accuracy_data=processTextOnly(devTensor)

bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

## visually check the vocab for TEXT
print(TEXT.vocab.stoi)
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x00000222B2E78100>>, {'<unk>': 0, '<pad>': 1, '<sos>': 2, '<eos>': 3, 'global': 4, 'climate': 5, 'warming': 6, 'temperature': 7, 'ice': 8, 'change': 9, 'greenhouse': 10, 'sea': 11, 'carbon': 12, 'years': 13, 'temperatures': 14, '2': 15, 'emissions': 16, 'surface': 17, 'earth': 18, 'since': 19, '0': 20, '1': 21, '°c': 22, 'dioxide': 23, 'rise': 24, 'human': 25, 'gases': 26, 'increased': 27, 'atmosphere': 28, 'average': 29, 'level': 30, 'ocean': 31, 'per': 32, 'year': 33, 'co2': 34, 'increase': 35, 'century': 36, 'water': 37, 'gas': 38, 'scientific': 39, 'changes': 40, 'levels': 41, 'co': 42, 'energy': 43, 'due': 44, 'also': 45, 'heat': 46, 'scientists': 47, '°f': 48, 'period': 49, 'arctic': 50, 'caused': 51,

# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
## this is to obtain seq2seq results
class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        #triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output
    
torch.triu(torch.ones(3, 3))

# Masking
def masking():
  sz = 4
  mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
  mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))

  return mask

masking()

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)
    
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 2 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
# Out:
# c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# # 3.Testing and Evaluation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
sos_token_id = TEXT.vocab.stoi['<sos>']
eos_token_id = TEXT.vocab.stoi['<eos>']
pad_token_id = TEXT.vocab.stoi['<pad>']
criterion = nn.CrossEntropyLoss(ignore_index=pad_token_id)
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train():
    model.train() 
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, _ = get_batch(train_data, i) 
        targets, _ = get_batch(train_label, i) 
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets.view(-1))
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

best_val_loss = float("inf")
epochs = 150# The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, dev_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  3.17s | valid loss  7.93 | valid ppl  2782.43
# -----------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 57
#      55 for epoch in range(1, epochs + 1):
#      56     epoch_start_time = time.time()
# ---> 57     train()
#      58     val_loss = evaluate(model, dev_data)
#      59     print('-' * 89)
#
# Cell In[19], line 20, in train()
#      18 optimizer.zero_grad()
#      19 output = model(data)
# ---> 20 loss = criterion(output.view(-1, ntokens), targets.view(-1))
#      21 loss.backward()
#      22 torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
#
# File c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\modules\loss.py:1185, in CrossEntropyLoss.forward(self, input, target)
#    1184 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1185     return F.cross_entropy(input, target, weight=self.weight,
#    1186                            ignore_index=self.ignore_index, reduction=self.reduction,
#    1187                            label_smoothing=self.label_smoothing)
#
# File c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\functional.py:3086, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3084 if size_average is not None or reduce is not None:
#    3085     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3086 return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
#
# KeyboardInterrupt:

# %%
test_loss = evaluate(best_model, dev_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

model.eval()
output=model(dev_data)
probabilities=torch.nn.functional.softmax(output,dim=-1)
_,predictedIndex=torch.max(probabilities,dim=-1)

vocab = TEXT.vocab.stoi 
reverseVocab = {index: word for word, index in vocab.items()} 
def tensor_to_text(tensor, index_to_word):
    words = [index_to_word[index.item()] for index in tensor if index in index_to_word]
    return ' '.join(words)
# Out:
# =========================================================================================
# | End of training | test loss 12.72 | test ppl 335795.92
# =========================================================================================

# %%
## save the model
PATH='./runs/model2.pt'
torch.save(model.state_dict(),PATH)

# %%
model=TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
model.load_state_dict(torch.load(PATH))
model.eval()
# Out:
# c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# TransformerModel(
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.2, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=200, out_features=200, bias=True)
#         )
#         (linear1): Linear(in_features=200, out_features=200, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=200, out_features=200, bias=True)
#         (norm1): LayerNorm((200,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((200,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (encoder): Embedding(14716, 200)
#   (decoder): Linear(in_features=200, out_features=14716, bias=True)
# )

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

model.eval()
pred=model(dev_accuracy_data)
def create_id_dictionary(dataframe):
    unique_id_per_claim={}
    for claim_id in dataframe['claim_id']:
        unique_id_per_claim[claim_id]=[]
    return unique_id_per_claim

unique_evidence_id=create_id_dictionary(devDataframe)
#print(predicted_text['claim-752'])
# use softmax
probabilities = torch.softmax(pred, dim=-1)
_, predicted_indices = torch.max(probabilities, dim=-1)
predicted_words = [[TEXT.vocab.itos[index] for index in example] for example in predicted_indices]
print(predicted_indices)
predicted_single_words={}
for claim_id in unique_evidence_id:
    predicted_single_words[claim_id] = []
if len(predicted_words) == len(unique_evidence_id):
    for claim_text, sentence in zip(unique_evidence_id, predicted_words):
        formatted_sentence =[word for word in sentence if word not in ("<pad>", "<unk>", "<eos>", "<sos>")]
        predicted_single_words[claim_text].extend(formatted_sentence)

for claim_id in predicted_single_words:
    for word in predicted_single_words[claim_id]:
        if 'evidence-' in word:
            predicted_single_words[claim_id].remove(word)
            unique_evidence_id[claim_id].append(word)

predicted_whole_sentences={}
for claim_id, words in predicted_single_words.items():
    predicted_whole_sentences[claim_id] = ' '.join(words)
    
newDf=evidenceDataframe.fillna(value=' ', inplace=False)
predicted_texts_list = list(predicted_whole_sentences.values())
tfidf_vectorizer = TfidfVectorizer()
evidence_tfidf = tfidf_vectorizer.fit_transform(newDf['evidence_text'])
predicted_tfidf = tfidf_vectorizer.transform(predicted_texts_list)
similarity_matrix = cosine_similarity(predicted_tfidf, evidence_tfidf)

for i, sentence in enumerate(predicted_words):
    print(f"Sentence {i+1}: {' '.join(sentence)}")

##similarity threshold - edit as wanted
threshold = 0.2

selected_evidence = {}
for idx, claim_id in enumerate(predicted_whole_sentences.keys()):
    above_threshold_indices = np.where(similarity_matrix[idx] > threshold)[0]
    above_threshold_scores = similarity_matrix[idx][above_threshold_indices]
    sorted_indices_scores = sorted(zip(above_threshold_indices, above_threshold_scores), key=lambda x: x[1], reverse=True)
    ## can edit this to get more top similarity scores if you want
    top_indices = [index for index, score in sorted_indices_scores[:5]]
    similar_docs = newDf['evidence_id'].iloc[top_indices].tolist()
    selected_evidence[claim_id] = similar_docs

for claim, evidences in selected_evidence.items():
    unique_evidence_id[claim].extend(evidences)
    print(f"{claim} has cosine similarity of more than {threshold} with: {evidences}")
# Out:
# tensor([[    2,  1264,  1264,  ...,   136,   136,   136],
#         [    2,  9586,  9586,  ...,     6,     6,     6],
#         [    2,  9586,  9586,  ...,     6,     6,     6],
#         ...,
#         [    2, 10616, 10616,  ...,    48,    48,     9],
#         [    2, 10616, 10616,  ...,     4,     4,     9],
#         [    2, 10616, 10616,  ...,     4,     4,     9]])
# Sentence 1: <sos> isotope isotope isotope isotope isotope instrumental decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade
# Sentence 2: <sos> evidence-55727 evidence-55727 evidence-55727 evidence-55727 evidence-55727 warmest atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic last warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming
# Sentence 3: <sos> evidence-55727 evidence-55727 evidence-55727 evidence-55727 evidence-55727 dioxide southern intense intense intense intense intense intense intense intense intense intense intense intense intense intense intense intense intense intense global warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming
# Sentence 4: <sos> evidence-55727 evidence-55727 evidence-55727 evidence-55727 evidence-55727 dioxide dioxide power power power power power power power intense intense intense intense intense intense intense intense intense intense intense global warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming
# Sentence 5: <sos> average average average average average average power carbon carbon carbon carbon carbon carbon intense intense intense intense intense intense intense intense intense intense intense intense warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming
# Sentence 6: <sos> average average average average average carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon change warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming warming
# Sentence 7: <sos> evidence-683543 evidence-683543 evidence-683543 evidence-683543 average average oxide average average trace carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon change cold cold cold cold cold cold cold cold cold cold cold cold cold cold cold cold cold cold
# Sentence 8: <sos> evidence-683543 evidence-683543 evidence-683543 evidence-683543 average antarctica oxide average average trace carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon carbon change global global global global global global global global global global global global global global global global global global
# Sentence 9: <sos> evidence-683543 evidence-683543 evidence-683543 evidence-683543 antarctica antarctica antarctica atlantic atlantic warmest atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic atlantic military since since since since since since since since since since since since since since
# Sentence 10: <sos> evidence-829081 evidence-829081 evidence-829081 evidence-829081 antarctica antarctica nations warmest warmest warmest carbon carbon carbon warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest warmest global global global global global global global global global global global global global global global
# Sentence 11: <sos> evidence-829081 evidence-829081 evidence-829081 evidence-829081 antarctica antarctica antarctica atlantic atlantic atlantic atlantic atlantic atlantic natural natural natural natural 30 warmest warmest warmest warmest warmest warmest warmest warmest atlantic atlantic atlantic global global global global global global global global global global global global global global global
# Sentence 12: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 antarctica antarctica antarctica antarctica antarctica reduced nations generally generally generally generally generally generally generally generally generally generally generally generally generally generally atlantic atlantic atlantic atlantic decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade
# Sentence 13: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 historical reduced reduced reduced reduced reduced reduced feedback nations generally generally generally generally generally generally generally generally generally generally generally generally reduced reduced reduced reduced decade decade decade decade decade decade decade decade decade decade decade decade decade decade decade
# Sentence 14: <sos> evidence-402691 evidence-402691 evidence-402691 evidence-402691 reduced reduced reduced reduced reduced reduced reduced nations generally generally generally generally generally generally generally generally generally generally generally generally generally reduced reduced reduced reduced global global global global global global global global global global global global global global global
# Sentence 15: <sos> evidence-402691 evidence-402691 evidence-402691 evidence-402691 shown shown shown shown shown shown shown shown shown data average average average average billion billion billion billion billion billion billion billion billion billion billion global global global global global global global global global global global global global global global
# Sentence 16: <sos> evidence-402691 evidence-402691 evidence-402691 evidence-402691 shown shown shown shown shown shown shown shown shown shown shown precipitation record average average average average average average average average billion billion billion billion years global global global global global global global global global global global global global global
# Sentence 17: <sos> evidence-464939 evidence-464939 evidence-464939 evidence-464939 shown shown shown shown shown shown shown nations record record record record record remarkably remarkably remarkably remarkably remarkably remarkably remarkably remarkably remarkably correspondingly correspondingly correspondingly °f °f °f °f °f °f °f °f °f °f °f °f °f °f °f
# Sentence 18: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 shown shown shown shown shown nations record record record record record record record remarkably remarkably remarkably remarkably remarkably remarkably remarkably remarkably correspondingly correspondingly correspondingly correspondingly °f °f °f °f °f °f °f °f °f °f °f °f °f °f °f
# Sentence 19: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 antarctica antarctica nations record record record record record record record record record record record record record record record record record record correspondingly correspondingly correspondingly correspondingly climate climate climate climate climate climate climate climate climate climate climate climate climate climate climate
# Sentence 20: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 antarctica antarctica antarctica antarctica antarctica antarctica far far far shown strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened precipitation record record record record record record climate climate climate climate climate climate climate climate climate climate climate climate climate climate climate
# Sentence 21: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 antarctica antarctica antarctica antarctica antarctica antarctica antarctica antarctica nations record record record record record record record record record record record record record record record record climate climate climate climate climate climate climate climate climate climate climate climate climate climate climate
# Sentence 22: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 antarctica antarctica antarctica around record record record record record record record record record record record record record record co2 co2 co2 heavy heavy heavy heavy point warming warming warming warming warming warming warming warming warming warming warming warming warming warming
# Sentence 23: <sos> evidence-683543 evidence-683543 evidence-683543 evidence-683543 average antarctica antarctica antarctica antarctica antarctica antarctica antarctica uncertainty co2 average co2 average average average average average average average average average heavy heavy heavy heavy point point point point point point point point point point point point point point point
# Sentence 24: <sos> evidence-683543 evidence-683543 evidence-683543 evidence-683543 evidence-683543 antarctica around average average average average average average average average average average average average average average average average average average billion average average average point point point point point point point point point point point point point point point
# Sentence 25: <sos> evidence-683543 evidence-683543 evidence-683543 evidence-683543 antarctica antarctica antarctica antarctica antarctica antarctica antarctica average average average strengthened strengthened strengthened uncertainty average average average average average average average billion billion billion billion global global global global global global global global global global global global global global global
# Sentence 26: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 antarctica antarctica antarctica antarctica antarctica antarctica uncertainty start record record record record record average average average average average carbon carbon carbon billion strengthened strengthened strengthened global global global global global global global global global global global global global global global
# Sentence 27: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 antarctica antarctica antarctica atmospheric start start start start start co2 co2 co2 co2 co2 co co co co co co co co2 co2 co2 co2 global global global global global global global global global global global global global global global
# Sentence 28: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 average antarctica antarctica antarctica strengthened atmospheric start start start start start co2 co2 co2 co2 co2 co2 co2 co co2 co2 co2 co2 co2 co2 global global global global global global global global global global global global global global global
# Sentence 29: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 average average oxide oxide strengthened oxide strengthened atmospheric start start start start start start start start start start average average average correspondingly correspondingly correspondingly correspondingly global global global global global global global global global global global global global global global
# Sentence 30: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 average average oxide strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened power average average average average correspondingly correspondingly correspondingly correspondingly since since since since since since since since since since since since since since since
# Sentence 31: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 average average oxide strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened power average average average correspondingly correspondingly correspondingly correspondingly since since since since since since since since since since since since since since since
# Sentence 32: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 common power start start start record start record record record record record record average average average average average precipitation precipitation precipitation correspondingly correspondingly correspondingly correspondingly since since since since since since since since since since since since since since since
# Sentence 33: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 common antarctica record record record record record record record record record record record record record record record precipitation precipitation precipitation precipitation precipitation precipitation precipitation precipitation since since since since since since since since since since since since since since since
# Sentence 34: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 common antarctica antarctica shown shown shown shown shown shown shown power record record average average average average precipitation precipitation precipitation precipitation precipitation precipitation precipitation precipitation since since since since since since since since since since since since since since since
# Sentence 35: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 average antarctica record average average average average average average average average average average average average average average average average average average average average average average since since since since since since since since since since since since since since since
# Sentence 36: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 common antarctica antarctica shown shown shown atmospheric average average average average average average average average average average average average average average average average average average since since since since since since since since since since since since since since since
# Sentence 37: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 common average antarctica shown shown shown shown shown shown strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened power average average average average since since since since since since since since since since since since since since since
# Sentence 38: <sos> common common common common common reduced reduced reduced strengthened reduced strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened power average average average average average average average average average since since since since since since since since since since since since since since since
# Sentence 39: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 common start start start start start start average average average average average average average average average average average average precipitation precipitation precipitation precipitation precipitation precipitation since since since since since since since since since since since since since since since
# Sentence 40: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 average antarctica reduced strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened precipitation average precipitation precipitation precipitation precipitation precipitation precipitation precipitation since since since since since since since since since since since since since since since
# Sentence 41: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 average average average power power power strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened foreseeable foreseeable foreseeable foreseeable foreseeable 198 since since since since since since since since since since since since since
# Sentence 42: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 average average nations average average average average average average average average average average average average average average average average average average average average average average average since since since since since since since since since since since since since since
# Sentence 43: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396 average average average average limit average average power average average average average average average average average average average average average average average average average average human since since since since since since since since since since since since since since
# Sentence 44: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 average antarctica antarctica antarctica limit antarctica limit limit strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened data average average average average average average average average human since since since since since since since since since since since since since since
# Sentence 45: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 antarctica antarctica antarctica antarctica antarctica antarctica human human human strengthened strengthened strengthened strengthened strengthened data record average average average average average average average average average human since since since since since since since since since since since since since since
# Sentence 46: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 common antarctica human antarctica antarctica human human nations record record record record record record average average average average average average average average average average average human since since since since since since since since since since since since since since
# Sentence 47: <sos> evidence-318640 evidence-318640 evidence-318640 evidence-318640 common human human human strengthened nations start average average average average average average average average average average precipitation precipitation precipitation precipitation precipitation precipitation precipitation precipitation level since since since since since since since since since since since since since since
# Sentence 48: <sos> evidence-1105558 evidence-1105558 evidence-1105558 evidence-1105558 average human human human strengthened human strengthened strengthened strengthened strengthened strengthened strengthened precipitation average average average average average precipitation precipitation precipitation average average average average level since since since since since since since since since since since since since since
# Sentence 49: <sos> common common common common common average human strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened precipitation average average average average average level since since since since since since since since since since since since since since
# Sentence 50: <sos> common common common common common average human strengthened strengthened strengthened strengthened strengthened power average average average average average average average average average average average average average average average average human since since since since since since since since since since since since since since
# Sentence 51: <sos> common common common common common common human common strengthened strengthened strengthened power start start start average average average average average average average average average average strengthened strengthened strengthened strengthened amount since since since since since since since since since since since since since since
# Sentence 52: <sos> common common common common common common reduced common common reduced strengthened strengthened strengthened precipitation start record record start carbon carbon record carbon carbon carbon precipitation correspondingly correspondingly correspondingly correspondingly cooling since since since since since since since since since since since since since since
# Sentence 53: <sos> common common common common common antarctica antarctica antarctica strengthened reduced strengthened strengthened strengthened strengthened strengthened strengthened strengthened precipitation record record record record first precipitation precipitation correspondingly correspondingly correspondingly correspondingly cooling since since since since since since since since since since since since since since
# Sentence 54: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396
<sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 around human human human human human human human data first first first first first first first first first first 7 7 strengthened strengthened strengthened strengthened human °f °f °f °f °f °f change 0 0 0 0 0 0 0
# Sentence 92: <sos> evidence-829081 evidence-829081 evidence-829081 evidence-829081 human human human human human human human human human data 7 7 7 7 7 7 7 7 7 7 7 7 human human human human °f °f °f °f °f °f change 0 0 0 0 0 0 0
# Sentence 93: <sos> evidence-88825 evidence-88825 evidence-88825 evidence-88825 evidence-683543 human human human human human southern 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 human human human human human human human human human human human human human human human human human human
# Sentence 94: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 evidence-683543 human human human human intense 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 human human human human human human human human human human human human human human human
# Sentence 95: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 evidence-510852 around human human human human intense 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 7 human human human human human human human change change change change change change change change
# Sentence 96: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 evidence-510852 around around around human human human human data 7 7 7 7 7 7 7 7 7 7 7 7 7 human human human human human human human human human human change global global global global global global global
# Sentence 97: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 evidence-423643 first first first first recent recent recent data first first first first first first first first first first first first rise human human human human °f °f °f °f °f °f global global global global global global global global
# Sentence 98: <sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 evidence-423643 first human recent recent ice start start start first first first first first first first first first first first first rise strengthened strengthened strengthened human °f °f °f °f °f °f global global global global global global global global
# Sentence 99: <sos> evidence-631347 evidence-631347 evidence-631347 evidence-631347 evidence-631347 human human recent recent recent recent recent intense start start start start start average average average average first average first strengthened strengthened strengthened strengthened °f °f °f °f °f °f °f global global global global global global global global
# Sentence 100: <sos> evidence-88825 evidence-88825 evidence-88825 evidence-88825 evidence-631347 human human intense start start start start start start start start start start start start start start start start 7 strengthened strengthened strengthened strengthened strengthened °f °f °f °f °f °f change change change change change change change change
# Sentence 101: <sos> evidence-829081 evidence-829081 evidence-829081 evidence-829081 evidence-423643 human human human human human human human intense start start start start start start start start start start start 7 strengthened strengthened strengthened strengthened human °f °f °f °f °f °f change change change change change change change change
# Sentence 102: <sos> evidence-423643 evidence-423643 evidence-423643 evidence-423643 evidence-423643 evidence-423643 human human human human human human human human human human precipitation start start start start start start start 7 strengthened strengthened strengthened strengthened human °f °f °f °f °f °f change change change change change change change change
# Sentence 103: <sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 evidence-423643 evidence-423643 feedback feedback feedback feedback feedback feedback feedback data start start start start start start start start 7 7 7 said said said said human °f °f °f °f °f °f change change change change change change change change
# Sentence 104: <sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 evidence-954557 evidence-423643 feedback feedback feedback intense start start start start start start average average average average average average average average data data data data data human °f °f °f °f °f °f change since since since since since since since
# Sentence 105: <sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 evidence-954557 common shown shown shown shown shown shown shown strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened strengthened data average average average average average °f °f °f °f °f °f °f since since since since since since since since
# Sentence 106: <sos> evidence-510852 evidence-510852 evidence-510852 evidence-510852 common common average start start average average average average average average average average average average average average average average average average average strengthened strengthened strengthened °f °f °f °f °f °f °f since since since since since since since since
# Sentence 107: <sos> common common common common common common common shown shown southern start record record record record record record record record record record record record record record strengthened strengthened strengthened strengthened °f °f 0 0 0 0 0 since since since since since since since since
# Sentence 108: <sos> common common common common common common common historical shown ice southern record record record record record record record record record record record record record record strengthened strengthened strengthened strengthened °f 0 0 0 0 0 0 change change change change change change change change
# Sentence 109: <sos> common common common common common common record historical historical ice ice celsius celsius celsius celsius celsius celsius celsius celsius celsius celsius celsius celsius celsius celsius celsius per celsius precipitation human change change change change change change change change change change change change change change
# Sentence 110: <sos> evidence-464396 evidence-464396 evidence-464396 evidence-464396
<sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 shown shown southern start start start start start start start start start start start record record record record record radiation radiation strengthened strengthened strengthened strengthened human °f °f °f °f °f °f °f °f °f °f °f °f °f change
# Sentence 125: <sos> evidence-954557 evidence-954557 evidence-954557 evidence-954557 shown shown shown shown shown shown shown shown shown shown shown power start start start record record record radiation radiation radiation unit strengthened strengthened strengthened human °f °f °f °f °f °f °f °f °f °f °f °f °f change
# Sentence 126: <sos> evidence-1054050 evidence-1054050 evidence-1054050 evidence-1054050 shown shown shown shown power start start start start start start start start start start record record record radiation radiation radiation radiation strengthened strengthened strengthened human °f °f °f °f °f °f °f °f °f °f °f °f °f change
# Sentence 127: <sos> common common common common common shown shown shown shown shown shown shown taxes start start start start start record record record record record radiation radiation rise strengthened strengthened strengthened human °f °f °f °f °f °f °f °f °f °f °f °f °f change
# ...
# claim-677 has cosine similarity of more than 0.2 with: ['evidence-296324', 'evidence-1039837', 'evidence-242277', 'evidence-322986', 'evidence-705395']
# claim-765 has cosine similarity of more than 0.2 with: ['evidence-705395', 'evidence-98543', 'evidence-296324', 'evidence-1039837', 'evidence-894791']
# claim-2275 has cosine similarity of more than 0.2 with: ['evidence-762704', 'evidence-1023749', 'evidence-395351', 'evidence-649965', 'evidence-1134182']
# claim-1113 has cosine similarity of more than 0.2 with: ['evidence-470688', 'evidence-556278', 'evidence-1023749', 'evidence-1206612', 'evidence-395351']
# claim-2611 has cosine similarity of more than 0.2 with: ['evidence-988581', 'evidence-98543', 'evidence-604980', 'evidence-493179', 'evidence-367096']
# claim-2060 has cosine similarity of more than 0.2 with: ['evidence-98543', 'evidence-988581', 'evidence-493179', 'evidence-705395', 'evidence-697238']
# claim-2326 has cosine similarity of more than 0.2 with: ['evidence-322303', 'evidence-72690', 'evidence-233177', 'evidence-570183', 'evidence-625611']
# claim-1087 has cosine similarity of more than 0.2 with: ['evidence-322303', 'evidence-72690', 'evidence-233177', 'evidence-570183', 'evidence-625611']
# claim-2867 has cosine similarity of more than 0.2 with: ['evidence-322303', 'evidence-570183', 'evidence-625611', 'evidence-72690', 'evidence-233177']
# claim-2300 has cosine similarity of more than 0.2 with: ['evidence-322303', 'evidence-570183', 'evidence-625611', 'evidence-72690', 'evidence-233177']
# claim-2250 has cosine similarity of more than 0.2 with: ['evidence-470688', 'evidence-1206612', 'evidence-787573', 'evidence-121356', 'evidence-876661']
# claim-2429 has cosine similarity of more than 0.2 with: ['evidence-470688', 'evidence-1206612', 'evidence-787573', 'evidence-121356', 'evidence-876661']
# claim-3051 has cosine similarity of more than 0.2 with: ['evidence-779876', 'evidence-470688', 'evidence-140462', 'evidence-989499', 'evidence-304264']
# claim-1549 has cosine similarity of more than 0.2 with: ['evidence-988581', 'evidence-911164', 'evidence-98543', 'evidence-913057', 'evidence-412217']
# claim-261 has cosine similarity of more than 0.2 with: ['evidence-655299', 'evidence-241252', 'evidence-1146637', 'evidence-906755', 'evidence-534435']
# claim-2230 has cosine similarity of more than 0.2 with: ['evidence-241252', 'evidence-655299', 'evidence-1146637', 'evidence-906755', 'evidence-534435']
# claim-2579 has cosine similarity of more than 0.2 with: ['evidence-211687', 'evidence-655299', 'evidence-241252', 'evidence-1146637', 'evidence-1151809']
# claim-1416 has cosine similarity of more than 0.2 with: ['evidence-470688', 'evidence-1206612', 'evidence-787573', 'evidence-646656', 'evidence-121356']
# claim-2497 has cosine similarity of more than 0.2 with: ['evidence-103643', 'evidence-647331', 'evidence-416258', 'evidence-252399', 'evidence-779569']
# claim-811 has cosine similarity of more than 0.2 with: ['evidence-1124376', 'evidence-643127', 'evidence-1161845', 'evidence-303113', 'evidence-407969']
# claim-1896 has cosine similarity of more than 0.2 with: ['evidence-1124376', 'evidence-643127', 'evidence-1161845', 'evidence-303113', 'evidence-407969']
# claim-2819 has cosine similarity of more than 0.2 with: ['evidence-911164', 'evidence-913057', 'evidence-412217', 'evidence-985118', 'evidence-