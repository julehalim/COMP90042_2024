# %% [markdown]
# # 2024 COMP90042 Project
# *Make sure you change the file name with your group id.*

# %% [markdown]
# # Readme
# *If there is something to be noted for the marker, please mention here.*
#
# *If you are planning to implement a program with Object Oriented Programming style, please put those the bottom of this ipynb file*

# %% [markdown]
# # 1.DataSet Processing
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
## import libraries

# !pip3 install torchtext==0.4.0

# Standard libraries
import math
import string
import pandas as pd
import numpy as np
import json

# Machine learning and deep learning libraries
import tensorflow
import keras
from sklearn.feature_extraction.text import TfidfVectorizer
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
from torchtext.data.utils import get_tokenizer
from torchtext.data import Field, LabelField, Example, Dataset
from torchtext.data.utils import get_tokenizer

# Natural Language Processing (NLP) libraries
import nltk
import spacy
from nltk.corpus import stopwords

# Visualization
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: torchtext==0.4.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (0.4.0)
# Requirement already satisfied: tqdm in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (4.66.2)
# Requirement already satisfied: requests in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (2.31.0)
# Requirement already satisfied: torch in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (2.3.0)
# Requirement already satisfied: numpy in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (1.24.3)
# Requirement already satisfied: six in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torchtext==0.4.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from requests->torchtext==0.4.0) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (4.11.0)
# Requirement already satisfied: sympy in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (1.12)
# Requirement already satisfied: networkx in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.1)
# Requirement already satisfied: jinja2 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from torch->torchtext==0.4.0) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from tqdm->torchtext==0.4.0) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchtext==0.4.0) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch->torchtext==0.4.0) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from jinja2->torch->torchtext==0.4.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\julev\anaconda3\envs\python-3-8\lib\site-packages (from sympy->torch->torchtext==0.4.0) (1.3.0)

# %%
## reading in json files

"""
Description of json files
* [train-claims,dev-claims].json: JSON files for the labelled training and development set; 
* evidence.json: JSON file containing a large number of evidence passages (i.e. the “knowledge source”); 
* dev-claims-baseline.json: JSON file containing predictions of a baseline system on the development set;
"""

## relative file paths

## baseline system - will not be used for any training/evaluation
devClaimsBaselineFile='./data/dev-claims-baseline.json'
## use this for model training
trainClaimsFile='./data/train-claims.json'
## use this set for hyperparameter tuning and evaluation metric 
devClaimsFile='./data/dev-claims.json'
## evidence files need to be downloaded through https://drive.google.com/file/d/1JlUzRufknsHzKzvrEjgw8D3n_IRpjzo6/view?usp=sharing as it is to big to be uploaded to github
evidenceFile='./data/evidence.json'

testFile='./data/test-claims-unlabelled.json'

tokenizer=get_tokenizer("basic_english")

# %%
# Load the JSON data
with open(trainClaimsFile, 'r') as file:
    trainClaims=json.load(file)
with open(devClaimsFile, 'r') as file:
    devClaims=json.load(file)
with open(evidenceFile, 'r') as file:
    evidenceData=json.load(file)

## Preprocessing data -- lowercase, tokenize, and stopword removal
stopwords=set(nltk.corpus.stopwords.words('english'))
tokenizer=get_tokenizer('basic_english')
punctuations=string.punctuation

def preprocess(text):
    token=tokenizer(text.lower())
    cleanedTokens=[t for t in token if (t not in stopwords) and (t not in punctuations)]
    return ' '.join(cleanedTokens)

for ids, texts in evidenceData.items():
    evidenceData[ids]=preprocess(texts)

# Function to create DataFrame and merge evidence IDs with Text
def createDF(claims, evidence):
    combinedData=[]
    for claimID, claimText in claims.items():
        # Combine the ID with its corresponding evidences
        evidenceID=claimText['evidences']
        evidenceText=(evidence[i] for i in evidenceID if i in evidence)
        combinedData.append({
            'claim_id': claimID,
            'claim_text': preprocess(claimText['claim_text']),
            'evidence_id': evidenceID,
            'evidence_text': " ".join(evidenceText),
            'claim_label': claimText['claim_label']
        })
    # Create DataFrame
    return pd.DataFrame(combinedData)

# Create CSV Files
trainFullMerged=createDF(trainClaims,evidenceData)
devFullMerged=createDF(devClaims,evidenceData)
trainFullMerged.to_csv("data/trainFullMerged.csv", index=False)
devFullMerged.to_csv("data/devFullMerged.csv", index=False)

# Convert evidence into csv as well
# evidenceFinal=pd.DataFrame(list(evidenceData.items()),columns=['evidence_id','evidence_text'])
# evidenceFinal.to_csv('data/evidencePreprocessed.csv',index=False)

# Convert unlabelled Data into CSV as well
with open(testFile, 'r') as file:
    testData=json.load(file)
for ids, texts in testData.items():
    claim_text = texts['claim_text']
    testData[ids]=preprocess(claim_text)
testFinal=pd.DataFrame(list(testData.items()), columns=['claim_id', 'claim_text'])
testFinal.to_csv('data/testPreprocessed.csv',index=False)

# %%
## use this for model training
trainClaimsFile='./data/trainFullMerged.csv'
## use this set for hyperparameter tuning and evaluation metric 
devClaimsFile='./data/devFullMerged.csv'
## evidence files need to be downloaded through googledrive (https://drive.google.com/file/d/1OyihwdAWfqHIOueCB4bLBkYg4hTN_OKm/view?usp=sharing)
evidenceFile='./data/evidencePreprocessed.csv'
## test unlabelled dataset
testFile='./data/testPreprocessed.csv'

trainDataframe=pd.read_csv(trainClaimsFile)
devDataframe=pd.read_csv(devClaimsFile)
evidenceDataframe=pd.read_csv(evidenceFile)
testDataframe=pd.read_csv(testFile)

trainDataframe['claim_text']=trainDataframe['claim_text']
trainDataframe['evidence_id']=trainDataframe['evidence_id'].astype(str).str.strip('[]').str.strip("'").apply(preprocess)
trainDataframe['combined_evidence']=trainDataframe['evidence_id']+" "+trainDataframe['evidence_text']

devDataframe['claim_text']=devDataframe['claim_text']
devDataframe['evidence_id']=devDataframe['evidence_id'].astype(str).str.strip('[]').str.strip("'").apply(preprocess)
devDataframe['combined_evidence']=devDataframe['evidence_id'] +" "+ devDataframe['evidence_text']

evidenceDataframe['combined_evidence']=evidenceDataframe['evidence_id']+" "+evidenceDataframe['evidence_text']
evidenceDataframe['combined_evidence']=evidenceDataframe['combined_evidence'].astype(str).str.strip("'").apply(preprocess)

# %%
## Preprocessing data -- lowercase, tokenize, and stopword removal
stopwords=set(nltk.corpus.stopwords.words('english'))
tokenizer=get_tokenizer('basic_english')
punctuations=set(string.punctuation)

def preprocess(text):
    tokens=tokenizer(text)
    cleanedTokens = [token for token in tokens if token not in stopwords and token not in punctuations]
    return cleanedTokens

def createDatasetEncoderInput(dataframe,textTransform):
    field=[('reviewTextInput',textTransform),('evidenceTextOutput',textTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        reviewTextInput=row['claim_text']
        evidenceTextOutput=row['combined_evidence']
        examples.append(Example.fromlist([reviewTextInput,evidenceTextOutput], field))
    return Dataset(examples,fields=field)

def createDatasetOutput(dataframe,textTransform):
    field=[('evidenceTextOutput',textTransform)]
    examples=[]
    for _, row in dataframe.iterrows():
        evidenceTextOutput=row['combined_evidence']
        examples.append(Example.fromlist([evidenceTextOutput], field))
    return Dataset(examples,fields=field)

TEXT = Field(tokenize=preprocess, lower=True, init_token='<sos>', eos_token='<eos>', batch_first=True)
trainTensor = createDatasetEncoderInput(trainDataframe, TEXT)
devTensor = createDatasetEncoderInput(devDataframe, TEXT)
evidenceTensor=createDatasetOutput(evidenceDataframe,TEXT)

TEXT.build_vocab(trainTensor)

# %%
print(TEXT.vocab.stoi)
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x0000022A029B7DC0>>, {'<unk>': 0, '<pad>': 1, '<sos>': 2, '<eos>': 3, 'global': 4, 'climate': 5, 'warming': 6, 'temperature': 7, 'ice': 8, 'change': 9, 'greenhouse': 10, 'sea': 11, 'carbon': 12, 'years': 13, 'temperatures': 14, '2': 15, 'emissions': 16, 'surface': 17, 'earth': 18, 'since': 19, '0': 20, '1': 21, '°c': 22, 'dioxide': 23, 'rise': 24, 'human': 25, 'gases': 26, 'increased': 27, 'atmosphere': 28, 'average': 29, 'level': 30, 'ocean': 31, 'per': 32, 'year': 33, 'co2': 34, 'increase': 35, 'century': 36, 'water': 37, 'gas': 38, 'scientific': 39, 'changes': 40, 'levels': 41, 'co': 42, 'energy': 43, 'due': 44, 'also': 45, 'heat': 46, 'scientists': 47, '°f': 48, 'period': 49, 'arctic': 50, 'caused': 51, 'data': 52, 'solar': 53, 'would': 54, 'last': 55, '3': 56, 'natural': 57, 'recent': 58, 'effect': 59, 'ipcc': 60, 'report': 61, 'record': 62, '000': 63, 'cause': 64, 'likely': 65, 'may': 66, 'increases': 67, 'rate': 68, 'air': 69, 'trend': 70, '5': 71, 'evidence': 72, 'past': 73, 'atmospheric': 74, 'much': 75, 'consensus': 76, 'methane': 77, 'could': 78, 'effects': 79, 'world': 80, 'weather': 81, 'decades': 82, 'activity': 83, 'fossil': 84, 'rising': 85, 'time': 86, 'concentrations': 87, 'models': 88, 'high': 89, 'increasing': 90, 'one': 91, '4': 92, '–': 93, 'anthropogenic': 94, 'mean': 95, 'observed': 96, 'new': 97, 'system': 98, 'melting': 99, 'causing': 100, 'million': 101, 'degrees': 102, 'cooling': 103, 'events': 104, 'warm': 105, 'extreme': 106, 'higher': 107, 'warmer': 108, 'many': 109, 'states': 110, '7': 111, 'land': 112, 'said': 113, '8': 114, 'fuels': 115, 'united': 116, 'study': 117, '6': 118, 'around': 119, 'oceans': 120, 'activities': 121, 'amount': 122, 'glaciers': 123, 'less': 124, 'power': 125, 'sun': 126, 'current': 127, 'found': 128, 'future': 129, 'research': 130, 'planet': 131, 'result': 132, 'two': 133, 'feedback': 134, 'greenland': 135, 'decade': 136, 'cold': 137, 'mass': 138, 'show': 139, 'significant': 140, 'use': 141, 'influence': 142, 'large': 143, 'including': 144, '2007': 145, 'loss': 146, 'times': 147, 'burning': 148, 'leading': 149, 'major': 150, 'percent': 151, 'radiation': 152, 'sheet': 153, '2017': 154, 'assessment': 155, 'summer': 156, 'used': 157, 'based': 158, '100': 159, 'antarctica': 160, 'area': 161, 'known': 162, 'measurements': 163, 'well': 164, 'antarctic': 165, 'coral': 166, 'human-induced': 167, '50': 168, 'even': 169, 'el': 170, 'satellite': 171, 'ago': 172, 'billion': 173, '30': 174, 'humans': 175, 'low': 176, 'lower': 177, '20th': 178, 'first': 179, 'industrial': 180, 'polar': 181, 'warmest': 182, 'include': 183, 'mainly': 184, 'pacific': 185, 'predicted': 186, 'regions': 187, '10': 188, 'become': 189, 'concentration': 190, 'national': 191, 'science': 192, 'age': 193, 'u': 194, 'areas': 195, 'cm': 196, 'estimated': 197, 'growth': 198, 'northern': 199, '2016': 200, 'however': 201, 'long-term': 202, 'published': 203, 'waves': 204, '9': 205, 'according': 206, 'days': 207, 'north': 208, 'positive': 209, 'records': 210, 'several': 211, 'studies': 212, 'within': 213, '20': 214, 'example': 215, 'tropical': 216, 'great': 217, 'impact': 218, 'reduce': 219, '2012': 220, 'long': 221, 'concluded': 222, 'currently': 223, 'ozone': 224, 'part': 225, 'pollution': 226, 'total': 227, 'cycle': 228, 'parts': 229, 'approximately': 230, 'countries': 231, 'hemisphere': 232, 'impacts': 233, 'occurred': 234, 'panel': 235, 'primarily': 236, 'sheets': 237, 'winter': 238, 'celsius': 239, 'conditions': 240, 'forcing': 241, 'sources': 242, 'state': 243, '2010': 244, 'absorption': 245, 'emission': 246, 'extent': 247, 'literature': 248, 'precipitation': 249, 'rapid': 250, 'intergovernmental': 251, 'ppm': 252, 'release': 253, 'health': 254, 'least': 255, 'little': 256, 'number': 257, 'variability': 258, 'wind': 259, 'annual': 260, 'deforestation': 261, 'expected': 262, 'important': 263, 'like': 264, 'reef': 265, 'region': ...

# %%
# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Batchify function
def batchify(dataset, bsz):
    # Process text and labels to tensors
    data = TEXT.process([getattr(x, 'reviewTextInput') for x in dataset.examples])
    label = TEXT.process([getattr(x, 'evidenceTextOutput') for x in dataset.examples])

    # Calculate number of complete batches
    nbatch = min(data.size(0), label.size(0)) // bsz
    data = data.narrow(0, 0, nbatch * bsz)
    label = label.narrow(0, 0, nbatch * bsz)

    # Reshape data into batches
    data = data.view(bsz, -1).t().contiguous()
    label = label.view(bsz, -1).t().contiguous()
    
    # Ensure each has the same number of sequences
    min_seq_len = min(data.size(0), label.size(0))
    data = data[:min_seq_len]
    label = label[:min_seq_len]

    return data.to(device), label.to(device)

# Batch sizes
batch_size = 20
eval_batch_size = 10

# Process the datasets
for i, example in enumerate(trainTensor.examples):
    if i < 5:
        print(vars(example))
        
train_data,train_label = batchify(trainTensor, batch_size)
dev_data,dev_label = batchify(devTensor, eval_batch_size)

bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target
print(len(train_data),len(train_label))
# Out:
# {'reviewTextInput': ['scientific', 'evidence', 'co2', 'pollutant', 'higher', 'co2', 'concentrations', 'actually', 'help', 'ecosystems', 'support', 'plant', 'animal', 'life'], 'evidenceTextOutput': ['evidence-442946', 'evidence-1194317', 'evidence-12171', 'high', 'concentrations', '100', 'times', 'atmospheric', 'concentration', 'greater', 'carbon', 'dioxide', 'toxic', 'animal', 'life', 'raising', 'concentration', '10', '000', 'ppm', '1%', 'higher', 'several', 'hours', 'eliminate', 'pests', 'whiteflies', 'spider', 'mites', 'greenhouse', 'plants', 'grow', 'much', '50', 'percent', 'faster', 'concentrations', '1', '000', 'ppm', 'co', '2', 'compared', 'ambient', 'conditions', 'though', 'assumes', 'change', 'climate', 'limitation', 'nutrients', 'higher', 'carbon', 'dioxide', 'concentrations', 'favourably', 'affect', 'plant', 'growth', 'demand', 'water']}
# {'reviewTextInput': ['el', 'niño', 'drove', 'record', 'highs', 'global', 'temperatures', 'suggesting', 'rise', 'may', 'man-made', 'emissions'], 'evidenceTextOutput': ['evidence-338219', 'evidence-1127398', '‘climate', 'change’', 'due', 'natural', 'forces', 'human', 'activity', 'substantial', 'evidence', 'indicate', 'human', 'activity', '–', 'specifically', 'increased', 'greenhouse', 'gas', 'ghgs', 'emissions', '–', 'key', 'factor', 'pace', 'extent', 'global', 'temperature', 'increases', 'acceleration', 'due', 'mostly', 'human-caused', 'global', 'warming', 'driving', 'thermal', 'expansion', 'seawater', 'melting', 'land-based', 'ice', 'sheets', 'glaciers']}
# {'reviewTextInput': ['1946', 'pdo', 'switched', 'cool', 'phase'], 'evidenceTextOutput': ['evidence-530063', 'evidence-984887', 'evidence', 'reversals', 'prevailing', 'polarity', 'meaning', 'changes', 'cool', 'surface', 'waters', 'versus', 'warm', 'surface', 'waters', 'within', 'region', 'oscillation', 'occurring', 'around', '1925', '1947', '1977', 'last', 'two', 'reversals', 'corresponded', 'dramatic', 'shifts', 'salmon', 'production', 'regimes', 'north', 'pacific', 'ocean', '1945/1946', 'pdo', 'changed', 'cool', 'phase', 'pattern', 'regime', 'shift', 'similar', '1970s', 'episode', 'maximum', 'amplitude', 'subarctic', 'subtropical', 'front', 'greater', 'signature', 'near', 'japan', '1970s', 'shift', 'stronger', 'near', 'american', 'west', 'coast']}
# {'reviewTextInput': ['weather', 'channel', 'co-founder', 'john', 'coleman', 'provided', 'evidence', 'convincingly', 'refutes', 'concept', 'anthropogenic', 'global', 'warming'], 'evidenceTextOutput': ['evidence-1177431', 'evidence-782448', 'evidence-540069', 'evidence-352655', 'evidence-1007867', 'convincing', 'scientific', 'evidence', 'human', 'release', 'carbon', 'dioxide', 'methane', 'greenhouse', 'gases', 'causing', 'foreseeable', 'future', 'cause', 'catastrophic', 'heating', 'earth', 'atmosphere', 'disruption', 'earth', 'climate', 'called', 'global', 'warming', 'greatest', 'scam', 'history', 'made', 'numerous', 'false', 'misleading', 'claims', 'climate', 'science', 'international', 'council', 'academies', 'engineering', 'technological', 'sciences', 'caets', '2007', 'issued', 'statement', 'environment', 'sustainable', 'growth', 'reported', 'intergovernmental', 'panel', 'climate', 'change', 'ipcc', 'observed', 'global', 'warming', 'since', 'mid-20th', 'century', 'likely', 'due', 'human-produced', 'emission', 'greenhouse', 'gases', 'warming', 'continue', 'unabated', 'present', 'anthropogenic', 'emissions', 'continue', 'worse', 'expand', 'without', 'control', 'climate', 'scientists', 'virtually', 'unanimous', 'anthropogenic', 'global', 'warming', 'true', 'scientists', 'reach', '100%', 'consensus', 'anthropogenic', 'global', 'warming']}
# {'reviewTextInput': ['january', '2008', 'capped', '12', 'month', 'period', 'global', 'temperature', 'drops', 'major', 'well', 'respected', 'indicators'], 'evidenceTextOutput': ['evidence-1010750', 'evidence-91661', 'evidence-722725', 'evidence-554161', 'evidence-430839', 'average', 'temperature', '+8', '1', '°c', '47', '°f', 'iranian', 'persian', 'calendar', 'currently', 'used', 'iran', 'afghanistan', 'also', '12', 'months', 'events', 'wide', 'variations', 'month', 'year', 'year', 'average', 'duration', '365', '256363004', 'days', '365', '6', 'h', '9', 'min', '9', '76', 'epoch', 'j2000', '0', 'january', '1', '2000', '12', '00', '00', 'tt', 'duration', 'approximately', '354', '37', 'days']}
# 2379 2379

# %% [markdown]
# # 2. Model Implementation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        #triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output

# %%
#triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
torch.triu(torch.ones(3, 3))
# Out:
# tensor([[1., 1., 1.],
#         [0., 1., 1.],
#         [0., 0., 1.]])

# %%
# Masking
def masking():
  sz = 4
  mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
  mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))

  return mask

masking()
# Out:
# tensor([[0., -inf, -inf, -inf],
#         [0., 0., -inf, -inf],
#         [0., 0., 0., -inf],
#         [0., 0., 0., 0.]])

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term) #0::2 means starting with index 0, step = 2
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)
    
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 2 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
# Out:
# c:\Users\julev\anaconda3\envs\Python-3-8\lib\site-packages\torch\nn\modules\transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# # 3.Testing and Evaluation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
criterion = nn.CrossEntropyLoss()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train():
    model.train()  # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    ntokens = len(TEXT.vocab.stoi)
    # The data and targets need to be loaded differently now
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, _ = get_batch(train_data, i)  # Load data batch
        targets, _ = get_batch(train_label, i)  # Load targets from train_label
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets.view(-1))  # Ensure targets are properly shaped
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = 200
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    ntokens = len(TEXT.vocab.stoi)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

best_val_loss = float("inf")
epochs = 3 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train()
    val_loss = evaluate(model, dev_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  5.55s | valid loss  5.14 | valid ppl   170.89
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  5.50s | valid loss  4.38 | valid ppl    80.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  5.57s | valid loss  3.50 | valid ppl    33.21
# -----------------------------------------------------------------------------------------

# %%
test_loss = evaluate(best_model, dev_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)

model.eval()
output=model(dev_data)
probabilities=torch.nn.functional.softmax(output,dim=-1)
_,predictedIndex=torch.max(probabilities,dim=-1)
# for i in predictedIndex:
#     print(predictedIndex[i])

# print(LABEL.vocab.stoi)
from sklearn.metrics import accuracy_score

vocab = TEXT.vocab.stoi 
reverseVocab = {index: word for word, index in vocab.items()} 
def tensor_to_text(tensor, index_to_word):
    words = [index_to_word[index.item()] for index in tensor if index in index_to_word]
    return ' '.join(words)

print(reverseVocab)

# for i in predictedIndex:
#     #print(i)
#     words = list(set([reverseVocab[index.item()] for index in i]))
#     print(words)


#accuracyScore=accuracy_score()
# Out:
# =========================================================================================
# | End of training | test loss  3.50 | test ppl    33.21
# =========================================================================================
# {0: 'circumvent', 1: '<pad>', 2: '<sos>', 3: '<eos>', 4: 'global', 5: 'climate', 6: 'warming', 7: 'temperature', 8: 'ice', 9: 'change', 10: 'greenhouse', 11: 'sea', 12: 'carbon', 13: 'years', 14: 'temperatures', 15: '2', 16: 'emissions', 17: 'surface', 18: 'earth', 19: 'since', 20: '0', 21: '1', 22: '°c', 23: 'dioxide', 24: 'rise', 25: 'human', 26: 'gases', 27: 'increased', 28: 'atmosphere', 29: 'average', 30: 'level', 31: 'ocean', 32: 'per', 33: 'year', 34: 'co2', 35: 'increase', 36: 'century', 37: 'water', 38: 'gas', 39: 'scientific', 40: 'changes', 41: 'levels', 42: 'co', 43: 'energy', 44: 'due', 45: 'also', 46: 'heat', 47: 'scientists', 48: '°f', 49: 'period', 50: 'arctic', 51: 'caused', 52: 'data', 53: 'solar', 54: 'would', 55: 'last', 56: '3', 57: 'natural', 58: 'recent', 59: 'effect', 60: 'ipcc', 61: 'report', 62: 'record', 63: '000', 64: 'cause', 65: 'likely', 66: 'may', 67: 'increases', 68: 'rate', 69: 'air', 70: 'trend', 71: '5', 72: 'evidence', 73: 'past', 74: 'atmospheric', 75: 'much', 76: 'consensus', 77: 'methane', 78: 'could', 79: 'effects', 80: 'world', 81: 'weather', 82: 'decades', 83: 'activity', 84: 'fossil', 85: 'rising', 86: 'time', 87: 'concentrations', 88: 'models', 89: 'high', 90: 'increasing', 91: 'one', 92: '4', 93: '–', 94: 'anthropogenic', 95: 'mean', 96: 'observed', 97: 'new', 98: 'system', 99: 'melting', 100: 'causing', 101: 'million', 102: 'degrees', 103: 'cooling', 104: 'events', 105: 'warm', 106: 'extreme', 107: 'higher', 108: 'warmer', 109: 'many', 110: 'states', 111: '7', 112: 'land', 113: 'said', 114: '8', 115: 'fuels', 116: 'united', 117: 'study', 118: '6', 119: 'around', 120: 'oceans', 121: 'activities', 122: 'amount', 123: 'glaciers', 124: 'less', 125: 'power', 126: 'sun', 127: 'current', 128: 'found', 129: 'future', 130: 'research', 131: 'planet', 132: 'result', 133: 'two', 134: 'feedback', 135: 'greenland', 136: 'decade', 137: 'cold', 138: 'mass', 139: 'show', 140: 'significant', 141: 'use', 142: 'influence', 143: 'large', 144: 'including', 145: '2007', 146: 'loss', 147: 'times', 148: 'burning', 149: 'leading', 150: 'major', 151: 'percent', 152: 'radiation', 153: 'sheet', 154: '2017', 155: 'assessment', 156: 'summer', 157: 'used', 158: 'based', 159: '100', 160: 'antarctica', 161: 'area', 162: 'known', 163: 'measurements', 164: 'well', 165: 'antarctic', 166: 'coral', 167: 'human-induced', 168: '50', 169: 'even', 170: 'el', 171: 'satellite', 172: 'ago', 173: 'billion', 174: '30', 175: 'humans', 176: 'low', 177: 'lower', 178: '20th', 179: 'first', 180: 'industrial', 181: 'polar', 182: 'warmest', 183: 'include', 184: 'mainly', 185: 'pacific', 186: 'predicted', 187: 'regions', 188: '10', 189: 'become', 190: 'concentration', 191: 'national', 192: 'science', 193: 'age', 194: 'u', 195: 'areas', 196: 'cm', 197: 'estimated', 198: 'growth', 199: 'northern', 200: '2016', 201: 'however', 202: 'long-term', 203: 'published', 204: 'waves', 205: '9', 206: 'according', 207: 'days', 208: 'north', 209: 'positive', 210: 'records', 211: 'several', 212: 'studies', 213: 'within', 214: '20', 215: 'example', 216: 'tropical', 217: 'great', 218: 'impact', 219: 'reduce', 220: '2012', 221: 'long', 222: 'concluded', 223: 'currently', 224: 'ozone', 225: 'part', 226: 'pollution', 227: 'total', 228: 'cycle', 229: 'parts', 230: 'approximately', 231: 'countries', 232: 'hemisphere', 233: 'impacts', 234: 'occurred', 235: 'panel', 236: 'primarily', 237: 'sheets', 238: 'winter', 239: 'celsius', 240: 'conditions', 241: 'forcing', 242: 'sources', 243: 'state', 244: '2010', 245: 'absorption', 246: 'emission', 247: 'extent', 248: 'literature', 249: 'precipitation', 250: 'rapid', 251: 'intergovernmental', 252: 'ppm', 253: 'release', 254: 'health', 255: 'least', 256: 'little', 257: 'number', 258: 'variability', 259: 'wind', 260: 'annual', 261: 'deforestation', 262: 'expected', 263: 'important', 264: 'like', 265: 'reef', 266: 'region', 267: 'renewable', 268: 'see', 269: 'acidification', 270: 'different', 271: 'end', 272: 'model', 27 ...
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']
# ['<pad>']

# %%
pred=model(dev_data)
print(pred)
import torch

# Assuming 'pred' is your model's output tensor
# Convert logits to probabilities (optional, for better interpretation)
probabilities = torch.softmax(pred, dim=-1)

# Get the indices of the maximum values along the last dimension (word dimension)
_, predicted_indices = torch.max(probabilities, dim=-1)

# Assuming 'TEXT.vocab.itos' is your index-to-string mapping from the vocabulary
predicted_words = [[TEXT.vocab.itos[index] for index in example] for example in predicted_indices]

# Print the words
for i, sentence in enumerate(predicted_words):
    print(f"Sentence {i+1}: {' '.join(sentence)}")
# Out:
# tensor([[[ 0.1754, 11.1056,  2.5887,  ...,  0.2457, -0.2442,  0.0912],
#          [ 0.1754, 11.1056,  2.5887,  ...,  0.2457, -0.2442,  0.0912],
#          [ 0.1754, 11.1056,  2.5887,  ...,  0.2457, -0.2442,  0.0912],
#          ...,
#          [ 0.1754, 11.1056,  2.5887,  ...,  0.2457, -0.2442,  0.0912],
#          [ 0.1754, 11.1056,  2.5887,  ...,  0.2457, -0.2442,  0.0912],
#          [ 0.1754, 11.1056,  2.5887,  ...,  0.2457, -0.2442,  0.0912]],
#
#         [[ 0.1867, 11.1078,  2.5490,  ...,  0.2393, -0.2416,  0.0787],
#          [ 0.1819, 11.1066,  2.5262,  ...,  0.2460, -0.2434,  0.0800],
#          [ 0.1855, 11.1035,  2.5449,  ...,  0.2397, -0.2396,  0.0783],
#          ...,
#          [ 0.1893, 11.1011,  2.5504,  ...,  0.2403, -0.2445,  0.0928],
#          [ 0.1920, 11.1007,  2.5526,  ...,  0.2357, -0.2414,  0.0908],
#          [ 0.1821, 11.1039,  2.5475,  ...,  0.2421, -0.2392,  0.0890]],
#
#         [[ 0.1854, 11.1082,  2.5416,  ...,  0.2380, -0.2401,  0.0757],
#          [ 0.1829, 11.1033,  2.5341,  ...,  0.2433, -0.2473,  0.0828],
#          [ 0.1849, 11.1077,  2.5468,  ...,  0.2400, -0.2376,  0.0763],
#          ...,
#          [ 0.1778, 11.1073,  2.5348,  ...,  0.2382, -0.2410,  0.0908],
#          [ 0.1835, 11.1123,  2.5438,  ...,  0.2365, -0.2449,  0.0911],
#          [ 0.1803, 11.1053,  2.5422,  ...,  0.2383, -0.2402,  0.0845]],
#
#         ...,
#
#         [[ 0.1859, 11.1021,  2.5261,  ...,  0.2408, -0.2409,  0.0954],
#          [ 0.1859, 11.1020,  2.5261,  ...,  0.2407, -0.2409,  0.0955],
#          [ 0.1859, 11.1022,  2.5260,  ...,  0.2409, -0.2409,  0.0954],
#          ...,
#          [ 0.1859, 11.1021,  2.5260,  ...,  0.2409, -0.2409,  0.0955],
#          [ 0.1860, 11.1020,  2.5261,  ...,  0.2408, -0.2409,  0.0955],
#          [ 0.1859, 11.1020,  2.5260,  ...,  0.2408, -0.2409,  0.0954]],
#
#         [[ 0.1848, 11.1022,  2.5260,  ...,  0.2406, -0.2415,  0.0956],
#          [ 0.1848, 11.1021,  2.5260,  ...,  0.2406, -0.2416,  0.0957],
#          [ 0.1847, 11.1023,  2.5260,  ...,  0.2407, -0.2415,  0.0955],
#          ...,
#          [ 0.1848, 11.1022,  2.5259,  ...,  0.2407, -0.2416,  0.0956],
#          [ 0.1849, 11.1021,  2.5260,  ...,  0.2406, -0.2416,  0.0956],
#          [ 0.1848, 11.1021,  2.5260,  ...,  0.2406, -0.2415,  0.0956]],
#
#         [[ 0.1839, 11.1024,  2.5256,  ...,  0.2404, -0.2419,  0.0959],
#          [ 0.1838, 11.1024,  2.5256,  ...,  0.2404, -0.2419,  0.0959],
#          [ 0.1838, 11.1025,  2.5256,  ...,  0.2405, -0.2419,  0.0958],
#          ...,
#          [ 0.1838, 11.1025,  2.5256,  ...,  0.2405, -0.2419,  0.0959],
#          [ 0.1840, 11.1024,  2.5257,  ...,  0.2404, -0.2419,  0.0959],
#          [ 0.1839, 11.1024,  2.5256,  ...,  0.2404, -0.2419,  0.0958]]],
#        grad_fn=<ViewBackward0>)
# Sentence 1: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 2: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 3: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 4: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 5: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 6: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 7: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 8: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 9: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 10: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 11: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 12: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 13: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 14: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 15: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 16: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 17: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 18: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 19: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 20: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 21: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 22: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 23: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 24: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 25: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 26: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 27: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 28: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 29: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 30: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 31: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 32: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 33: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 34: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 35: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 36: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 37: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 38: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 39: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 40: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 41: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 42: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 43: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 44: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 45: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 46: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 47: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 48: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 49: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 50: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 51: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 52: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 53: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 54: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 55: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 56: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 57: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 58: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 59: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 60: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 61: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 62: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 63: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 64: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 65: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 66: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 67: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 68: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 69: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 70: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 71: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 72: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 73: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 74: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 75: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 76: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 77: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 78: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 79: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 80: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 81: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 82: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 83: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 84: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 85: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 86: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 87: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 88: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 89: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 90: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 91: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 92: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 93: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 94: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 95: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 96: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 97: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 98: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 99: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 100: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 101: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 102: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 103: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 104: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 105: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 106: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 107: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 108: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 109: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 110: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 111: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 112: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 113: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 114: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 115: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 116: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 117: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 118: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 119: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 120: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 121: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 122: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 123: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 124: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 125: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 126: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 127: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 128: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 129: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 130: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 131: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 132: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 133: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 134: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 135: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 136: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 137: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 138: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 139: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 140: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 141: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 142: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 143: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 144: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 145: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 146: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 147: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 148: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 149: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 150: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 151: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 152: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 153: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 154: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 155: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 156: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 157: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 158: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 159: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 160: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 161: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 162: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 163: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 164: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 165: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 166: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 167: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 168: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 169: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 170: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 171: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 172: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 173: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 174: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 175: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 176: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 177: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 178: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 179: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 180: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 181: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 182: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 183: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 184: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 185: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 186: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 187: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 188: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 189: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 190: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 191: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 192: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 193: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 194: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 195: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 196: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 197: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 198: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 199: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 200: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 201: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 202: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 203: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 204: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 205: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 206: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 207: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 208: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 209: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 210: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 211: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 212: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 213: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 214: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 215: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 216: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 217: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 218: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 219: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 220: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 221: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 222: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 223: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 224: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 225: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 226: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 227: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 228: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 229: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 230: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 231: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 232: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 233: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 234: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 235: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 236: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 237: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 238: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 239: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 240: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 241: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 242: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 243: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 244: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 245: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 246: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 247: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 248: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 249: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 250: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 251: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 252: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 253: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 254: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 255: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 256: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 257: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 258: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 259: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 260: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 261: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 262: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 263: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 264: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 265: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 266: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 267: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 268: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 269: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 270: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 271: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 272: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 273: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 274: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 275: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 276: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 277: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 278: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 279: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 280: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 281: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 282: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 283: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 284: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 285: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 286: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 287: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 288: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 289: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 290: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 291: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 292: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 293: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 294: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 295: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 296: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 297: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 298: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 299: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 300: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 301: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 302: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 303: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 304: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 305: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 306: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 307: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 308: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 309: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 310: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 311: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 312: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 313: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 314: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 315: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 316: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 317: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 318: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 319: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 320: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 321: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 322: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 323: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 324: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 325: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 326: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 327: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 328: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 329: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 330: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 331: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 332: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 333: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 334: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 335: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 336: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 337: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 338: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 339: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 340: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 341: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 342: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 343: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 344: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 345: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 346: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 347: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 348: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 349: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 350: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 351: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 352: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 353: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 354: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 355: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 356: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 357: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 358: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 359: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 360: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 361: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 362: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 363: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 364: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 365: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 366: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 367: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 368: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 369: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 370: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 371: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 372: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 373: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 374: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 375: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 376: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 377: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 378: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 379: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 380: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 381: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 382: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 383: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 384: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 385: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 386: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 387: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 388: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 389: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 390: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 391: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 392: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 393: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 394: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 395: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 396: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 397: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 398: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 399: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 400: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 401: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 402: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 403: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 404: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 405: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 406: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 407: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 408: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 409: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 410: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 411: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 412: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 413: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 414: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 415: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 416: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 417: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 418: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 419: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 420: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 421: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 422: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 423: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 424: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 425: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 426: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 427: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 428: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 429: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 430: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 431: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 432: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 433: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 434: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 435: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 436: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 437: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 438: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 439: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 440: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 441: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 442: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 443: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 444: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 445: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 446: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 447: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 448: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 449: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 450: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 451: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 452: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 453: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 454: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 455: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 456: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 457: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 458: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 459: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 460: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 461: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 462: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 463: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 464: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 465: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 466: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 467: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 468: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 469: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 470: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 471: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 472: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 473: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 474: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 475: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 476: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 477: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 478: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 479: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 480: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 481: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 482: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 483: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 484: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 485: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 486: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 487: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 488: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 489: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 490: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 491: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 492: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 493: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 494: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 495: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 496: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 497: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 498: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 499: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 500: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 501: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 502: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 503: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 504: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 505: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 506: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 507: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 508: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 509: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 510: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 511: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 512: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 513: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 514: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 515: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 516: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 517: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 518: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 519: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 520: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 521: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 522: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 523: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 524: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 525: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 526: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 527: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 528: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 529: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 530: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 531: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 532: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 533: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 534: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 535: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 536: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 537: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 538: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 539: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 540: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 541: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 542: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 543: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 544: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 545: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 546: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 547: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 548: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 549: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 550: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 551: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 552: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 553: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 554: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 555: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 556: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 557: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 558: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 559: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 560: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 561: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 562: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 563: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 564: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 565: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 566: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 567: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 568: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 569: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 570: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 571: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 572: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 573: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 574: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 575: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 576: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 577: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 578: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 579: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 580: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 581: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 582: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 583: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 584: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 585: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 586: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 587: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 588: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 589: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 590: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 591: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 592: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 593: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 594: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 595: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 596: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 597: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 598: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 599: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 600: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 601: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 602: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 603: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 604: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 605: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 606: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 607: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 608: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 609: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 610: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 611: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 612: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 613: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 614: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 615: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 616: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 617: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 618: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 619: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 620: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 621: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 622: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 623: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 624: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 625: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 626: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 627: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 628: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 629: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 630: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 631: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 632: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 633: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 634: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 635: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 636: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 637: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 638: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 639: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 640: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 641: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 642: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 643: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 644: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 645: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 646: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 647: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 648: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 649: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 650: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 651: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 652: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 653: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 654: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 655: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 656: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 657: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 658: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 659: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 660: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 661: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 662: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 663: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 664: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 665: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 666: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 667: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 668: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 669: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 670: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 671: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 672: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 673: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 674: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Sentence 675: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>

# %% [markdown]
# ## Object Oriented Programming codes here
#
# *You can use multiple code snippets. Just add more if needed*
